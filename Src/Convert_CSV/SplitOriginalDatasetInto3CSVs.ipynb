# %%
import csv
import pandas as pd

# %%
csvFilePath = r"C:\Users\Yash\Desktop\Courses\CS411\Project Track 1\Src\Convert_CSV\Data"
csvList = ["2013new.csv", "2014new.csv", "2015new.csv", "2016new.csv", "2017new.csv", "2018new.csv", "2019new.csv"]

# %%
csvData = pd.DataFrame()
for csvName in csvList:
    csvDataTemp = pd.read_csv(csvFilePath+"\\"+csvName)
    csvData = pd.concat([csvData,csvDataTemp])
listOfcsvDataColumns = list(csvData.columns)
csvData
# Out:
#       Incident Date reported   Time reported Date occurred   Time occurred  \
# 0    II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1    II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2    II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3    II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4    II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ..         ...           ...             ...           ...             ...
# 877  CC1909074      11/14/19            7:00      11/14/19            2:37
# 878  IF1901488      11/14/19           16:56      11/14/19           16:56
# 879  II1901441      11/14/19           16:52      11/14/19           16:00
# 880  II1901442      11/14/19           20:10      11/14/19           20:05
# 881  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#               General Location                  Crime Description  \
# 0     500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1           600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                     CIRCLE K            DRIVING UNDER THE INFL-
# 3    COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                 KIRK / GERTY                 THEFT FROM COIN-OP
# ..                         ...                                ...
# 877    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 878  IUB ADMINISTRATIVE SUITES                            THREATS
# 879        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 880      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 881   102 N GREGORY ST, URBANA                           BURGLARY
#
#                   Disposition  BlockId
# 0                      ARREST        0
# 1                      ARREST       14
# 2                      ARREST        0
# 3                      ARREST        9
# 4                ADMIN. CLOSE        0
# ..                        ...      ...
# 877  REPORTED TO OTHER AGENCY       25
# 878              ADMIN CLOSED       50
# 879              ADMIN. CLOSE        0
# 880              ADMIN. CLOSE        0
# 881  REPORTED TO OTHER AGENCY       36
#
# [7617 rows x 9 columns]

# %%
# csvData = pd.read_csv(csvFilePath+"\\"+csvName)
# listOfcsvDataColumns = list(csvData.columns)
# csvData

# %%
# Drop NaN rows
csvData = csvData.dropna()
csvData = csvData.reset_index(drop=True)

# Drop row which has "nan" value
for col in listOfcsvDataColumns:
    csvData = csvData[~csvData[col].isin(["nan", "UNKNOWN", "unknown"])]

csvData
# Out:
#        Incident Date reported   Time reported Date occurred   Time occurred  \
# 0     II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1     II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2     II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3     II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4     II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ...         ...           ...             ...           ...             ...
# 7609  CC1909074      11/14/19            7:00      11/14/19            2:37
# 7610  IF1901488      11/14/19           16:56      11/14/19           16:56
# 7611  II1901441      11/14/19           16:52      11/14/19           16:00
# 7612  II1901442      11/14/19           20:10      11/14/19           20:05
# 7613  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#                General Location                  Crime Description  \
# 0      500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1            600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                      CIRCLE K            DRIVING UNDER THE INFL-
# 3     COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                  KIRK / GERTY                 THEFT FROM COIN-OP
# ...                         ...                                ...
# 7609    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 7610  IUB ADMINISTRATIVE SUITES                            THREATS
# 7611        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 7612      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 7613   102 N GREGORY ST, URBANA                           BURGLARY
#
#                    Disposition  BlockId
# 0                       ARREST        0
# 1                       ARREST       14
# 2                       ARREST        0
# 3                       ARREST        9
# 4                 ADMIN. CLOSE        0
# ...                        ...      ...
# 7609  REPORTED TO OTHER AGENCY       25
# 7610              ADMIN CLOSED       50
# 7611              ADMIN. CLOSE        0
# 7612              ADMIN. CLOSE        0
# 7613  REPORTED TO OTHER AGENCY       36
#
# [7443 rows x 9 columns]

# %% [markdown]
# ## Flush the curated and compiled data into CSV

# %%
#Flush the dataframe to CSV file

processedDatasetCSVName = "processedDatset.csv"
    
happensAtDF.to_csv(csvFilePath+"\\"+happensAtCSVName, encoding='utf-8', index=False)

# %% [markdown]
# # Create CrimeType CSV

# %%
#Get unique types of crime
crimeTypeSet = set()
for x in csvData["Crime Description"]:
    crimeTypeSet.add(x.upper().strip())
crimeTypeList = list(crimeTypeSet)
crimeTypeList
# Out:
# ['ASSIST CPD',
#  'DECPT PRACT',
#  'TRESPASS-STATE SUPPORTED',
#  'DRUG PARAPHERNALIA-SALE/DELIVERY',
#  'THROW DANGEROUS MATERIALS',
#  'CRIMINAL DAMAGE GOVT SUPPORT',
#  'DECEPT PRACT',
#  'EAVESDROPPING',
#  'LIQUOR-PURCH/POSS/CONSUMP BY MINORS',
#  'ASSIST CPD W/ROBBERY',
#  'THROW DANG MATERIAL',
#  'ASSIST DOMESTIC',
#  'MIP; POSS LIQUOR-PUBLIC PROP',
#  'TRESPASS-RESIDENCE',
#  'PUBLIC POSSESSION OF ALCOHOL',
#  'PIMPING - PROMOTING PROSTITUTION',
#  'ACCIDENT INVOLVING OTHER CITY PROP',
#  'AGG DISCHARGE OF FIREARM',
#  'WARRANT',
#  'FIGHTING',
#  'ACCIDENT INVOLVING NON-INJURY',
#  'LIQUOR-PURCH/POSS/CONSUMP BY',
#  'ILLEGAL TRANSPORTATION OF LIQUOR',
#  'DISORDERLY CONDUCT-ALL',
#  'MANUFACTURE CONTROLLED SUB',
#  'CREDIT CARD FRAUD',
#  'THEFT OF SERVICES',
#  'TERRORIST THREATS',
#  'ASSIST W/K-9',
#  'ASSIST K9',
#  'UNLAWFUL USE OF I.D.',
#  'HOME INVASION',
#  'THEFT/DECCEPTION',
#  'THEFT-RETAIL',
#  'DAMAGING PROPERTY',
#  'NOISE PROHIBITED',
#  'ASSAULT',
#  'LIQUOR-ILLEGAL CONSUMPTION',
#  'PREDATORY CRIM SEX ASSAULT OF CHILD',
#  'ASSIST TOW TRUCK',
#  'DRUG',
#  'ASSIST CPD W/BANK ROBBERY',
#  'TRANSPORTING ALCOHOL/LIQ IN VEHICLE',
#  'ACCIDENT HIT AND RUN',
#  'SEARCH WARRANT ASSIST',
#  'SEX OFFENSE, FORCIBLE',
#  'ASSIST/CHECK WELFARE',
#  'THEFT-IDENTITY',
#  'RECOVERED PROPERTY ONLY',
#  'DISOBEY STOP',
#  'HARASSMENT BY TX',
#  'CANNABIS-POSSESSION OVER 30GM',
#  'AGG ASSAULT',
#  'DECEPTIVE PRACTICES/EXTORTION',
#  'OTHER MISC/CPD ORDINANCE',
#  'TELEPHONE THREAT',
#  'DOMESTIC BATTERY/UNLAWFUL',
#  'STALKING BY ELECTRONIC COMMUNICATIO',
#  'LIQUOR - ADULT RESPONSIBILITY/UNDERAGE',
#  'DRUGS; COUNTERFEIT MONEY',
#  'ASSIST/DOMESTIC BATTERY',
#  'ASSIST/CPD WITH ACCIDENT',
#  'RESIST OFFICER',
#  'TRESPASS TO HOME',
#  'STALKING',
#  'DECEPTIVE PRACTICE',
#  'ASSIST/SHOTS FIRED',
#  'SEARCH WARRANT',
#  'NOISE PROHIBITION',
#  'LIQUOR-PUBLIC PROP',
#  'CONTRIBUTING CRIM DELINQUENCY JUV',
#  'POSSESSION OF DRUG PARAPHERNALIA',
#  'PEEPING TOM (DISORDERLY CONDUCT)',
#  'BURNING PROHIBITED',
#  'SEXUAL HARASSMENT',
#  'INDECENT EXPOSURE',
#  'WARRANT ARREST',
#  'ASSIST/K-9',
#  'IMPOUNDED VEHICLE',
#  'POSS OF DRUG PARAPHERNALIA -ORD',
#  'BONFIRES PROHIBITED',
#  'WARRANT-OUT OF STATE',
#  'BATTERY-AGG DOMESTIC',
#  'FIGHT',
#  'ASSIST CPD W/ARMED SUBJECT',
#  'ABANDONED JUNK VEHICLES',
#  'RESISTING/OBSTRUCTING',
#  'RECOVERED STOLEN VEHICLE',
#  'MENTAL CASE-TRANSPORTATION',
#  'THEFT-LOST/MISLAID PROPERTY',
#  'ALCOHOL/LIQUOR LICENSE REQUIRED',
#  'DEFACING IDENTI.MARKS OF FIREARMS',
#  'LIQUOR-UNDERAGE; FIGHT',
#  'ASSIST CPD W/THEFT',
#  'OBSTRUCTING IDENTIFICATION',
#  'LIQUOR-OPEN CONTAINER/PUBLIC PROP.',
#  'ALCOHOL/LIQ SALES INTOX SUBJ OR',
#  'ASSIST UPD W/DETAIN SUBJECT',
#  'DECEPTIVE PRACTCIES',
#  'HARASSMENT BY ELECTRONIC',
#  'ASSIST/BURGLARY',
#  'HYPODERMIC NEEDLE/SYRINGE-POSS/SALE',
#  'ASSIST UPD W/ROBBERY',
#  'OTHER INVESTIGATION QUASI-CRIMINAL',
#  'ASSIST K9 SEARCH',
#  'SALES OF TOBACCO',
#  'ARSON',
#  'DOMESTIC - UNLAWFUL RESTRAINT',
#  'PUBLIC URINATION (C)',
#  'THROW DANG MATERIALS',
#  'LIQUOR-UNDERAGE; DISORDERLY CONDUCT',
#  'ALCOHOL/LIQUOR BASSET LICENSE REQ',
#  'SUICIDAL SUBJECT',
#  'ALCOHOL',
#  'CYBERSTALKING',
#  'DISPOSAL ON PUBLIC WAYS',
#  'ASSIST CPD WITH BATTERY',
#  'ASSIST CPD W/TRAFFIC STOP',
#  'ASSIST UPD W/THEFT',
#  'LIQOUR',
#  'ASSIST/TRANSLATOR',
#  'CRIMINAL DAMAGE GOVT SUPPORT PROP',
#  'ASSIST CCSO TRAF STOP',
#  'BURGLARY FROM MOTOR',
#  'DISOBEY TRAFFIC (BIKE)',
#  'NO DRIVERS LICENSE; OPERATING',
#  'ASSIST/DOMESTIC',
#  'ASSIST/DISORDERLY SUBJ',
#  'NO REAR REGISTRATION LIGHT',
#  'ALLOWING A NUISANCE PARTY',
#  'RESIST/OBSTRUCT/DISARM AN OFFICER',
#  'RUNAWAY - MINOR REQUIRE AUTH INTER',
#  'BURGLARY OF MOTOR VEHICLE',
#  'MIP ALCOHOL/LIQUOR',
#  'DRUG EQUIPMENT-POSSESSION',
#  'LIQUOR - UNDERAGE',
#  'UNLAWFUL RESTRAINT-AGGRAVATED',
#  'NOISE',
#  'POSS OF CANNABIS UNDER 10 GM &',
#  'RECKLESS CONDUCT',
#  'SEXUAL ABUSE-AGGRAVATED',
#  'ASSIST/SEACH WARRANT',
#  'BOMB THREAT',
#  'DEATH INVESTIGATION/ASSIST UPD',
#  'MINOR PRESENT',
#  'DOEMSTIC VIOLENCE',
#  'REVENGE PORNOGRAPHY',
#  'ASSIST ISP W/SEARCH',
#  'UNLAWFUL POSSESSION OF ID',
#  'MINOR IN POSSESSION',
#  'RESIST/OBSTRUCT/DISARM AN',
#  'CANINE SWEEP - IDOT',
#  'UNLAWFUL TRESPASS',
#  'ASSIST/CRIMINAL DAMAGE',
#  'ASSIST BATTERY',
#  'POSSESSION OF STOLEN PROP',
#  'FONDLING',
#  'FALSE POLICE REPORT',
#  'SEX OFFENDER REGISTRATION',
#  'ASSIST/ACCIDENT UPD',
#  'ASSIST COUNTY PD W/K9 SWEEP',
#  'THREATS',
#  'CONTROLLED SUBSTANCE-LOOK-ALIKE',
#  'THEFT',
#  'ASSIST/SHOPLIFTER',
#  'THEFT $500 AND UNDER',
#  'PURSE SNATCHING',
#  'DISOBEY BIKE CODE',
#  'STOLEN PROP RECOVERED',
#  'SEX OFFENDER-FAIL TO REGISTER',
#  'ASSIST CPD W/MEDICAL',
#  'TERRORISM-MAKE FALSE TERROR',
#  'ASSIST K-9',
#  'HARRASSMENT',
#  'PEDESTRIAN STOPS',
#  'UNLAW USE ID',
#  'CANNABIS-POSSESSION OVER',
#  'VISITATION INTERFERENCE',
#  'THROWING ITEMS',
#  'PUBLIC POSSESSION',
#  'ENDANG LIFE/HEALTH OF CHILD',
#  'NON-FORCIBLE SEX OFFENSE',
#  'PEEPING TOM',
#  'MURDER-FIRST DEGREE',
#  'ASSIST/ARMED SUBJ',
#  'DOMESTIC OFFENSE',
#  'DRIVING UNDER THE INFL-',
#  'DELIVERY OF ALCOHOL/LIQ TO A MINOR',
#  'POSS DRUG PARAPHERNALIA',
#  'DEL/MANUF CANNABIS UNDER 10 G -MISD',
#  'LIQUOR-ILLEGAL CONSUMPTION BY',
#  'RESIST/OBS CORRECT/POLICE/FIRE',
#  'PUBLIC INTOXICATION',
#  'FRAUD-CREDIT CARD',
#  'TRANSIENT MERCHANT/LICENSE REQUIRED',
#  'CANNABIS-POSS 30 GM & UNDER',
#  'LIQUOR - UNDERAGE CONSUMPTION',
#  'ASST CPD/ARMED SUBJECT',
#  'CANNABIS-DELIVERY OVER 30GM',
#  'ASSIST/HARRESSMENT',
#  'FELONY - ARREST',
#  'THEFT UNDER',
#  'TRESPASS TO RESIDENCE',
#  'VIOL BAIL BOND',
#  'ZERO TOLERANCE',
#  'SUICIDE ATTEMPT/DRUGS',
#  'CHILD PORNOGRAPHY',
#  'OBSTRUCTING JUSTICE',
#  'FIREWORKS',
#  'POSS ALCOHOL PUB PROP /',
#  'FORGERY/CREDIT CARD FRAUD',
#  'NOISE & VIBRATIONS',
#  'CRIMINAL DAMAGE TO PROPERTY',
#  'ASSIST UIPD W/BATTERY',
#  'DOMESTIC',
#  'THEFT FROM MOTOR VEHICLE',
#  'ASSIST/NO TRESPASS',
#  'MUTUAL COMBATANTS',
#  'ASSIST CCSO W/TRAFFIC STOP',
#  'RESIST/OBSTRUCT OFFICER',
#  'BURGLARY FROM MOTOR VEHICLE',
#  'TRESPASS-STATE SUPPORTED LAND',
#  'DOMESTIC VIOLENCE',
#  'ROBBERY-AGGRAVATED',
#  'SRO - YAC REFERRAL',
#  'DISORDERLY CONDUCT-ALL OTHER',
#  'ELECTRONIC HARASSMENT',
#  'RESISTING/OBSTR OFFICER',
#  'TRAFFIC CITATION/VOP',
#  'SAFEKEEPING',
#  'SEX OFFENSE',
#  'IMPROPER LANE USAGE-ONE-WAY ST',
#  'RESISTING/OBSTR. OFFICER',
#  'CONTROLLED SUBSTANCE-MANUF-INTENT',
#  'ACCIDENT INVOLVING PEDESTRIAN',
#  'COMPUTER TAMPERING',
#  'ASSIST UPD WITH K-9',
#  'CURFEW VIOLATION',
#  'RAPE',
#  'LIQUOR-UNDERAGE/PUBLIC POSSESSION',
#  'ALCOHOL/LIQUOR CONSUMPTION EMPLOYEE',
#  'HIT AND RUN',
#  'POSSESSION OF CANNABIS',
#  'MOTOR VEHICLE THEFT',
#  'SIMPLE ASSAULT',
#  'ASSIST CCSO W/TRANSLATION',
#  'LIQUOR-ILLEGAL CONSUMPTION BY MINOR',
#  'DRIVING UNDER THE INFLUENCE',
#  'BIKE VIOLATION',
#  'K9 ASSIST',
#  'BURGLARY RESIDENTIAL',
#  'ASSIST CPD W/BATTERY',
#  'DOMESTIC-INTERFERENCE WITH REPORT',
#  'RESIST OBS OFC',
#  'TRAFFIC OFFENSE',
#  'EXCITED DELIRIUM',
#  'PUBLIC DRUNKENNEESS & TRESPASS',
#  'HARBOURING A RUNAWAY',
#  'ASSIST COUNTY POLICE W/ARMED SUBJ',
#  'SPEEDING (RADAR)',
#  'OTHER CRIMINAL OFFENSES',
#  'ASSIST UPD W/K-9',
#  'TRESPASS LAND',
#  'ASSIST CPD/ROBBERY',
#  'TRESPASS TO LAND/REAL PROPERTY',
#  'FORGERY',
#  'PANHANDLE',
#  'POSSESSION OF STOLEN FIREARM',
#  'THEFT FROM COIN-OP',
#  'FIGHT/DISORDERLY',
#  'ASSIST/ARMED SUBJECT',
#  'CONTROLLED SUBSTANCE-POSSESSION',
#  'AGGR UNLAWFUL USE OF WEAPON',
#  'MURDER/NON-NEG. MANSSL.',
#  'VIOLATION OF ORDER OF PROTECTION',
#  'IMPROPER USE OF SIGNAL',
#  'BATTERY-DOMESTIC',
#  'METRO',
#  'WEAPON',
#  'AGG BATTERY',
#  'RESIST/OBSTRUCT/DISARM OFFICER',
#  'POSSESSION STOLEN PROPERTY',
#  'ASSIST ATT BURG F/MV',
#  'HARASSMENT BY TELEPHONE',
#  'CURFEW',
#  'CRIMINAL DEFACEMENT OF PROPERTY',
#  'ASSIST/ROBBERY DETAIL',
#  'DUI',
#  'ASSIST CPD W/RETAIL THEFT',
#  'CANNABIS POSS OVER 10 - 100 G -MISD',
#  'RESIST/OBSTRUCT',
#  'TREPASS',
#  'DRIVING UNDER INFLUENCE-',
#  'CRIMINAL DEFACEMENT OF',
#  'NARCOTICS UNIT',
#  'LIQUOR-SALE TO MINORS,DRUNKS,ETC',
#  'ASSIST OTHER GOVT AGENCY/EOD',
#  'ASSIST CPD W/SHOTS FIRED',
#  'BRINGING CONTRABAND INTO PENAL INST',
#  'DECEPTIVE PRACTICES/HARASSMENT BY T',
#  'NOISE VIOLATION',
#  'RESISTING ARREST',
#  'ASSIST/THEFT',
#  'TRAFFIC',
#  'DIS CONDUCT',
#  'RECKLESS DRIVING',
#  'DECEPTIVE PRACTICES',
#  'K9 ASSIST CPD',
#  'PUBLIC INDECENCY',
#  'DEC PRACTICE',
#  'STATUTORY RAPE',
#  'THEFT OF MOTOR VEH PARTS & ACCESS',
#  'DRIVING UNDER INFLUENCE-DRUGS',
#  'POSS LIQUOR-PUBLIC PROP',
#  'CRIMINAL DAMAGE GOVT',
#  'OBSTRUCTIN JUSTICE',
#  'OTHER TROUBLE/INFO RPT',
#  'ASSIST OTHER PD',
#  'DOMESTIC BATTERY',
#  'STALKING/CYBERSTALKING',
#  'CARRYING ALCOHOL/LIQ OUT OF PREMISE',
#  'ASSIST UPD W/DOMESTIC',
#  'COUNTED STALKING UNDER C16-0886',
#  'UNLAWFUL POSS/USE WEAPON BY',
#  'DOMESTICE VIOLENCE',
#  'SALE OF TOBACCO',
#  'DEL/MANUF CANNABIS OVER 30 G -FEL',
#  'LEAVING THE SCENE OF AN ACCIDENT',
#  'DISORDERLY/PANDELING',
#  'TRESPASS-VEHICLE',
#  'UNAUTHORIZED ENTRY',
#  'SEXUAL ASSAULT-AGG CRIMINAL',
#  'ASSAULT-AGGRAVATED',
#  'ADULT RESPONSIBILITY',
#  'EOD; ASSIST OTHER',
#  'HEROIN OVERDOSE',
#  'ASSIST/ACCIDENT',
#  'EXTORTION',
#  'FRAUD-DECEPTION',
#  'ASSIST PD W/ACCIDENT',
#  'HARRASMENT BY ELECTRONIC',
#  'CONTROLLED SUBSTANCE-',
#  'ASSIST SICK & INJURED',
#  'THEFT OF MOTOR VEH PARTS &',
#  'ASSIST W/MENTAL HEALTH',
#  'VANDALISM-INSTITUTIONAL',
#  'CREDIT CARD FRAUD/FORGERY',
#  'DRUGS/LIQUOR',
#  'ASSIST CCSO W/ARMED SUBJECT',
#  'ASSIST UPD W/DISORDERLY',
#  'FALSE PERSONATION OF PEACE OFFICER',
#  'VEHICULAR NOISE',
#  'ARMED VIOLENCE',
#  'SEXUAL-ASSAULT-CRIMINAL',
#  'THROWING DANGEROUS MATERIALS',
#  'MISSING PERSON ADULT/FEMALE',
#  'ASSIST UPD/SHOOTING',
#  'LIQUOR - PUBLIC PROPERTY',
#  'CANNABIS POSS 10 GM OR LESS -ORD',
#  'DOGS RUNNING AT LARGE',
#  'SEXUAL ABUSE-CRIMINAL',
#  'THEFT OF LOST/MISLAID PROP',
#  'TRAFFIC SIGN VIOLATION',
#  'WARRANT ARREST/TRAFFIC CITATIONS',
#  'BATTERY-AGGRAVATED',
#  'DISORDERLY CONDUCT',
#  'LARCENY',
#  'UNLAWFUL RESTRAINT',
#  'DECPTIVE PRACTICE',
#  'THROWING DANGEROUS',
#  'SPECIFIC NOISE PROHIBITED',
#  'DATING VIOLENCE',
#  'UNLAWFUL USE ID',
#  'FORCIBLE SEX OFFENSE',
#  'ATTEMPTED RAPE',
#  'AGG FLEE/ATTEMPT ELUDE OFFICER',
#  'IDENTITY THEFT',
#  'HARASSMENT BY ELECTRONIC COMM',
#  'DELIVERY CONTROLLED SUB',
#  'LIQUOR-ILLEGAL POSS. BY MINOR',
#  'CANNABIS POSS OVER 30 G - OLD',
#  'AGGRAVATGED ASSAULT',
#  'MOB ACTION',
#  'DECPT PRACTICE',
#  'FALSE ID-POSS (MISC)',
#  'STALKING/ELECTRONIC HARRASMENT',
#  'VIOLATION OF ORDER PROTECTION',
#  'ASSIST COUNTY POLICE',
#  'HARASSMENT BY ELECTRONIC COMMUNICAT',
#  'UNLAWFUL USE OF WEAPONS',
#  'POSSESSION W/INTENT TO DELIVER',
#  'THEFT OVER $500',
#  'LOST ARTICLES',
#  'IMPROPER LANE USAGE',
#  'COMPUTER FRAUD',
#  'DISOBEY LIGHT (BIKE)',
#  'THEFT BY LESSEE',
#  'ALCOHOL/LIQUOR SERVER NAME TAG REQ',
#  'BURGLARY MOTOR VEH PARTS & ACCESS',
#  'DOMESTIC DISPUTE',
#  'TRESPASSIN',
#  'CANNABIS-DELIVERY 30GM &',
#  'MIP',
#  'ALCOHO/LIQ MINOR PRESENT/TEEN EVENT',
#  'TELEPHONE THREATS',
#  'FURNISHING ALCOHOL TO MINOR',
#  'POSS OF CANNABIS',
#  'DRIVING UNDER THE INFL-ALCOHOL',
#  'MISSING PERSON',
#  'ENDANG CHILD',
#  'HAZING',
#  'LIQUOR - ILLEGAL TRANSPORTATION',
#  'DRUGS - ILLEGAL TRANSPORTATION OF',
#  'NO DRIVERS LICENSE',
#  'RUNAWAY - MINOR REQUIRE AUTH',
#  'ASSIST CCSO W/K-9',
#  'TRESPASS TO PROPERTY',
#  'FUGITIVE FROM JUSTICE',
#  'UPD ACCIDENT (FATAL)',
#  'CONTROLLED SUBSTANCE-POSS',
#  'HARASS BY TX',
#  'DISORDERLY',
#  'CONTROLLED SUBSTANCE-POSS W/INTENT',
#  'DECP PRACTICE',
#  'USE OF FORCE BY OFFICER',
#  'THEFT-LABOR OR SERVICES',
#  'ASSIST/U OF I FOUND PROPERTY',
#  'THEFT-MOTOR VEHICLE',
#  'SUSPICIOUS ACTIVITIES',
#  'ASSIST STATE POLICE',
#  'VERBAL DOMESTIC',
#  'ASSIST/STABBING',
#  'POSS ALCOHOL/LIQ PUBLIC PROP/PARKIN',
#  'UNLAWFUL POSS/USE WEAPON BY FELON',
#  'ASSIST UPD ON ROBBERY',
#  'SEX HARASSMENT',
#  'DEL/MANUF CANNABIS UNDER 30 G -',
#  'ASSIST/TRAFFIC STOP',
#  'SUSPENDED LICENSE/WARRANT',
#  'BATTERY-DOMESTIC & LARCENY',
#  'TRAFFIC STOP',
#  'CARRYING OUT OF PREMISE',
#  'TRAFFIC CITATIONS',
#  'ASSIST/UNCOOPERATIVE SUBJ',
#  'LIQUOR-SALE TO MINORS/DRUNKARDS',
#  'HARASSMENT',
#  'OPERATE UNINSURED MOTOR VEHICLE',
#  'DUI - ALCOHOL',
#  'THEFT GENERALLY',
#  'BATTERY',
#  'THEFT FROM COIN-OP MACHINE/DEVICE',
#  'CANNABIS POSS 30 G AND UNDER - OLD',
#  'ASSIST FIGHT',
#  'ASSIST/SEARCH SUBJ',
#  'ASSIST UPD W/RETAIL THEFT',
#  'CONTROLLED SUBSTANCE-MANUF-',
#  'ASSIST CPD W/K-9',
#  'RESISTING',
#  'AGGRAVATED BATTERY',
#  'ASSIST W/SEARCH WARRANT',
#  'OTHER EQUIPMENT VIOLATIONS',
#  'HINDERING POLICE OFFCR',
#  'LIQUOR',
#  'POSS OF DRUG PARAPHENALIA',
#  'AGGRAVATED ASSAULT',
#  'TRESPASS',
#  'TRESPASS NOTICE',
#  'SEARCH WARRANT SERVICE',
#  'ASSIST UPD',
#  'METRO/ASSIST OTHER',
#  'HAZING - FRAT/SORORITY',
#  'LIQUOR - CARRYING IN PUBLIC PLACE',
#  'PUBLIC URINATION',
#  'CRISIS INTERVEN. - OTHER',
#  'DRUGS',
#  'UNLAWFUL USE OF ID',
#  'INTIMIDATION',
#  'DECEPT PRACTICE',
#  'SALES OF TOBACCO TO MINORS',
#  'DOMESTIC DISPUTE - VERBAL ONLY',
#  'ASSIST ROBBERY',
#  'THEFT-CITY',
#  'SIMPLE BATTERY',
#  'ASSIST URBANA THEFT',
#  'LIQUOR - OPEN ALCOHOL',
#  'ACCIDENT W/NON-VEH PROP DAMAGE',
#  'ELECTRICAL FIRE',
#  'STALKING-AGGRAVATED',
#  'EOD CALLOUT',
#  'OFFICIAL MISCONDUCT',
#  'RIDING BIKE ON ROAD',
#  'BIKE VIOLATIONS',
#  'BATTERY -CITY',
#  'UNAUTHORIZED VIDEOTAPING/LIVE VIDEO',
#  'K9 ASSIST CCSO',
#  'FALSE FIRE ALARM',
#  'AGG AGASSULT',
#  'DEL/MANUF CANNABIS UNDER 30 G -MISD',
#  'CRUELTY TO ANIMALS',
#  'POSS ALCOHOL PUB PROP / PARKING',
#  'FLEEING/ELUDING',
#  'ASSIST/BUILDING CHECK',
#  'THEFT FROM BUILDING',
#  'WARRANT-IN STATE',
#  'THROW DANGEROUS MATERIAL',
#  'MISSING PERSON ADULT/MALE',
#  'BIKE ENFORCEMENT',
#  'LIQUOR-UNDERAGE',
#  'SEXUAL ASSAULT',
#  'TRESPASSING',
#  'FRAUD - DECEPTION',
#  'HYPODERMIC NEEDLE/SYRINGE-',
#  'LIQUOR/THEFT',
#  'ASSIST UPD W/K9 SWEEP',
#  'LIQUOR - PUBLIC POSSESSION',
#  'VIOLATION ORDER PROTECTION',
#  'ASSIST CPD ROBBERY',
#  'ASSIST CCSO',
#  'DESTR/DAMAG/VAND',
#  'BEGGERS PROHIBITED',
#  'BREATH ALCOHOL OVER LIMIT',
#  'ATTEMPTED THEFT',
#  'ROBBERY',
#  'ASSIST OTHER POLICE DEPT',
#  'EXPIRED REGISTRATION',
#  'ASSIST CCSO W/BMV',
#  'THEFT OVER',
#  'DRIVING UNDER SUSPENDED LICENSE',
#  'METRO ACTIVATION',
#  'ASSIST/K9 SEARCH',
#  'DEPETIVE PRACTICE/COUNTERFIT',
#  'ASSIST W/K9 SWEEP',
#  'ROBBERY-ARMED',
#  'LEAVING SCENE PROPERTY DAMAGE',
#  'DOMESTIC BATTERY/AGG ASSAULT',
#  'CANNABIS POSS MORE THAN 10 LESS',
#  'FRAUD/DECEPTION',
#  'UNLAWFUL POSS FIREARM & AMMUNITION',
#  'CANNABIS-DELIVERY 30GM & UNDER',
#  'THEFT OF LOST/MISLAID PROPERTY',
#  'PUBLIC URINATION-CITY',
#  'BURGLARY',
#  'BICYCLE VIOLATION',
#  'TRESPASS/RESISTING ARREST',
#  'VERBAL DISPUTE',
#  'ASSIST STATE/ACCIDENT',
#  'CRIMINAL DAMAGE',
#  'THEFT-RETAIL-CITY',
#  'LOUD NOISE',
#  'RETAIL THEFT',
#  'DISORDERLY SUBJECT',
#  'DUI - DRUGS',
#  'CRISIS INTERVEN. - ALCOHOL',
#  'ASSIST/K9',
#  'VOOP']

# %%
#Convert the set of crime types into a list of dictionary
crimeTypeListOfDicts = []
crimeTypeStartIndex = 300
for type in crimeTypeList:
    crimeTypeDict = {}
    crimeTypeDict["crimeTypeID"] = crimeTypeStartIndex
    crimeTypeDict["type"] = type
    crimeTypeStartIndex += 1
    crimeTypeListOfDicts.append(crimeTypeDict)
crimeTypeListOfDicts
# Out:
# [{'crimeTypeID': 300, 'type': 'ASSIST CPD'},
#  {'crimeTypeID': 301, 'type': 'DECPT PRACT'},
#  {'crimeTypeID': 302, 'type': 'TRESPASS-STATE SUPPORTED'},
#  {'crimeTypeID': 303, 'type': 'DRUG PARAPHERNALIA-SALE/DELIVERY'},
#  {'crimeTypeID': 304, 'type': 'THROW DANGEROUS MATERIALS'},
#  {'crimeTypeID': 305, 'type': 'CRIMINAL DAMAGE GOVT SUPPORT'},
#  {'crimeTypeID': 306, 'type': 'DECEPT PRACT'},
#  {'crimeTypeID': 307, 'type': 'EAVESDROPPING'},
#  {'crimeTypeID': 308, 'type': 'LIQUOR-PURCH/POSS/CONSUMP BY MINORS'},
#  {'crimeTypeID': 309, 'type': 'ASSIST CPD W/ROBBERY'},
#  {'crimeTypeID': 310, 'type': 'THROW DANG MATERIAL'},
#  {'crimeTypeID': 311, 'type': 'ASSIST DOMESTIC'},
#  {'crimeTypeID': 312, 'type': 'MIP; POSS LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 313, 'type': 'TRESPASS-RESIDENCE'},
#  {'crimeTypeID': 314, 'type': 'PUBLIC POSSESSION OF ALCOHOL'},
#  {'crimeTypeID': 315, 'type': 'PIMPING - PROMOTING PROSTITUTION'},
#  {'crimeTypeID': 316, 'type': 'ACCIDENT INVOLVING OTHER CITY PROP'},
#  {'crimeTypeID': 317, 'type': 'AGG DISCHARGE OF FIREARM'},
#  {'crimeTypeID': 318, 'type': 'WARRANT'},
#  {'crimeTypeID': 319, 'type': 'FIGHTING'},
#  {'crimeTypeID': 320, 'type': 'ACCIDENT INVOLVING NON-INJURY'},
#  {'crimeTypeID': 321, 'type': 'LIQUOR-PURCH/POSS/CONSUMP BY'},
#  {'crimeTypeID': 322, 'type': 'ILLEGAL TRANSPORTATION OF LIQUOR'},
#  {'crimeTypeID': 323, 'type': 'DISORDERLY CONDUCT-ALL'},
#  {'crimeTypeID': 324, 'type': 'MANUFACTURE CONTROLLED SUB'},
#  {'crimeTypeID': 325, 'type': 'CREDIT CARD FRAUD'},
#  {'crimeTypeID': 326, 'type': 'THEFT OF SERVICES'},
#  {'crimeTypeID': 327, 'type': 'TERRORIST THREATS'},
#  {'crimeTypeID': 328, 'type': 'ASSIST W/K-9'},
#  {'crimeTypeID': 329, 'type': 'ASSIST K9'},
#  {'crimeTypeID': 330, 'type': 'UNLAWFUL USE OF I.D.'},
#  {'crimeTypeID': 331, 'type': 'HOME INVASION'},
#  {'crimeTypeID': 332, 'type': 'THEFT/DECCEPTION'},
#  {'crimeTypeID': 333, 'type': 'THEFT-RETAIL'},
#  {'crimeTypeID': 334, 'type': 'DAMAGING PROPERTY'},
#  {'crimeTypeID': 335, 'type': 'NOISE PROHIBITED'},
#  {'crimeTypeID': 336, 'type': 'ASSAULT'},
#  {'crimeTypeID': 337, 'type': 'LIQUOR-ILLEGAL CONSUMPTION'},
#  {'crimeTypeID': 338, 'type': 'PREDATORY CRIM SEX ASSAULT OF CHILD'},
#  {'crimeTypeID': 339, 'type': 'ASSIST TOW TRUCK'},
#  {'crimeTypeID': 340, 'type': 'DRUG'},
#  {'crimeTypeID': 341, 'type': 'ASSIST CPD W/BANK ROBBERY'},
#  {'crimeTypeID': 342, 'type': 'TRANSPORTING ALCOHOL/LIQ IN VEHICLE'},
#  {'crimeTypeID': 343, 'type': 'ACCIDENT HIT AND RUN'},
#  {'crimeTypeID': 344, 'type': 'SEARCH WARRANT ASSIST'},
#  {'crimeTypeID': 345, 'type': 'SEX OFFENSE, FORCIBLE'},
#  {'crimeTypeID': 346, 'type': 'ASSIST/CHECK WELFARE'},
#  {'crimeTypeID': 347, 'type': 'THEFT-IDENTITY'},
#  {'crimeTypeID': 348, 'type': 'RECOVERED PROPERTY ONLY'},
#  {'crimeTypeID': 349, 'type': 'DISOBEY STOP'},
#  {'crimeTypeID': 350, 'type': 'HARASSMENT BY TX'},
#  {'crimeTypeID': 351, 'type': 'CANNABIS-POSSESSION OVER 30GM'},
#  {'crimeTypeID': 352, 'type': 'AGG ASSAULT'},
#  {'crimeTypeID': 353, 'type': 'DECEPTIVE PRACTICES/EXTORTION'},
#  {'crimeTypeID': 354, 'type': 'OTHER MISC/CPD ORDINANCE'},
#  {'crimeTypeID': 355, 'type': 'TELEPHONE THREAT'},
#  {'crimeTypeID': 356, 'type': 'DOMESTIC BATTERY/UNLAWFUL'},
#  {'crimeTypeID': 357, 'type': 'STALKING BY ELECTRONIC COMMUNICATIO'},
#  {'crimeTypeID': 358, 'type': 'LIQUOR - ADULT RESPONSIBILITY/UNDERAGE'},
#  {'crimeTypeID': 359, 'type': 'DRUGS; COUNTERFEIT MONEY'},
#  {'crimeTypeID': 360, 'type': 'ASSIST/DOMESTIC BATTERY'},
#  {'crimeTypeID': 361, 'type': 'ASSIST/CPD WITH ACCIDENT'},
#  {'crimeTypeID': 362, 'type': 'RESIST OFFICER'},
#  {'crimeTypeID': 363, 'type': 'TRESPASS TO HOME'},
#  {'crimeTypeID': 364, 'type': 'STALKING'},
#  {'crimeTypeID': 365, 'type': 'DECEPTIVE PRACTICE'},
#  {'crimeTypeID': 366, 'type': 'ASSIST/SHOTS FIRED'},
#  {'crimeTypeID': 367, 'type': 'SEARCH WARRANT'},
#  {'crimeTypeID': 368, 'type': 'NOISE PROHIBITION'},
#  {'crimeTypeID': 369, 'type': 'LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 370, 'type': 'CONTRIBUTING CRIM DELINQUENCY JUV'},
#  {'crimeTypeID': 371, 'type': 'POSSESSION OF DRUG PARAPHERNALIA'},
#  {'crimeTypeID': 372, 'type': 'PEEPING TOM (DISORDERLY CONDUCT)'},
#  {'crimeTypeID': 373, 'type': 'BURNING PROHIBITED'},
#  {'crimeTypeID': 374, 'type': 'SEXUAL HARASSMENT'},
#  {'crimeTypeID': 375, 'type': 'INDECENT EXPOSURE'},
#  {'crimeTypeID': 376, 'type': 'WARRANT ARREST'},
#  {'crimeTypeID': 377, 'type': 'ASSIST/K-9'},
#  {'crimeTypeID': 378, 'type': 'IMPOUNDED VEHICLE'},
#  {'crimeTypeID': 379, 'type': 'POSS OF DRUG PARAPHERNALIA -ORD'},
#  {'crimeTypeID': 380, 'type': 'BONFIRES PROHIBITED'},
#  {'crimeTypeID': 381, 'type': 'WARRANT-OUT OF STATE'},
#  {'crimeTypeID': 382, 'type': 'BATTERY-AGG DOMESTIC'},
#  {'crimeTypeID': 383, 'type': 'FIGHT'},
#  {'crimeTypeID': 384, 'type': 'ASSIST CPD W/ARMED SUBJECT'},
#  {'crimeTypeID': 385, 'type': 'ABANDONED JUNK VEHICLES'},
#  {'crimeTypeID': 386, 'type': 'RESISTING/OBSTRUCTING'},
#  {'crimeTypeID': 387, 'type': 'RECOVERED STOLEN VEHICLE'},
#  {'crimeTypeID': 388, 'type': 'MENTAL CASE-TRANSPORTATION'},
#  {'crimeTypeID': 389, 'type': 'THEFT-LOST/MISLAID PROPERTY'},
#  {'crimeTypeID': 390, 'type': 'ALCOHOL/LIQUOR LICENSE REQUIRED'},
#  {'crimeTypeID': 391, 'type': 'DEFACING IDENTI.MARKS OF FIREARMS'},
#  {'crimeTypeID': 392, 'type': 'LIQUOR-UNDERAGE; FIGHT'},
#  {'crimeTypeID': 393, 'type': 'ASSIST CPD W/THEFT'},
#  {'crimeTypeID': 394, 'type': 'OBSTRUCTING IDENTIFICATION'},
#  {'crimeTypeID': 395, 'type': 'LIQUOR-OPEN CONTAINER/PUBLIC PROP.'},
#  {'crimeTypeID': 396, 'type': 'ALCOHOL/LIQ SALES INTOX SUBJ OR'},
#  {'crimeTypeID': 397, 'type': 'ASSIST UPD W/DETAIN SUBJECT'},
#  {'crimeTypeID': 398, 'type': 'DECEPTIVE PRACTCIES'},
#  {'crimeTypeID': 399, 'type': 'HARASSMENT BY ELECTRONIC'},
#  {'crimeTypeID': 400, 'type': 'ASSIST/BURGLARY'},
#  {'crimeTypeID': 401, 'type': 'HYPODERMIC NEEDLE/SYRINGE-POSS/SALE'},
#  {'crimeTypeID': 402, 'type': 'ASSIST UPD W/ROBBERY'},
#  {'crimeTypeID': 403, 'type': 'OTHER INVESTIGATION QUASI-CRIMINAL'},
#  {'crimeTypeID': 404, 'type': 'ASSIST K9 SEARCH'},
#  {'crimeTypeID': 405, 'type': 'SALES OF TOBACCO'},
#  {'crimeTypeID': 406, 'type': 'ARSON'},
#  {'crimeTypeID': 407, 'type': 'DOMESTIC - UNLAWFUL RESTRAINT'},
#  {'crimeTypeID': 408, 'type': 'PUBLIC URINATION (C)'},
#  {'crimeTypeID': 409, 'type': 'THROW DANG MATERIALS'},
#  {'crimeTypeID': 410, 'type': 'LIQUOR-UNDERAGE; DISORDERLY CONDUCT'},
#  {'crimeTypeID': 411, 'type': 'ALCOHOL/LIQUOR BASSET LICENSE REQ'},
#  {'crimeTypeID': 412, 'type': 'SUICIDAL SUBJECT'},
#  {'crimeTypeID': 413, 'type': 'ALCOHOL'},
#  {'crimeTypeID': 414, 'type': 'CYBERSTALKING'},
#  {'crimeTypeID': 415, 'type': 'DISPOSAL ON PUBLIC WAYS'},
#  {'crimeTypeID': 416, 'type': 'ASSIST CPD WITH BATTERY'},
#  {'crimeTypeID': 417, 'type': 'ASSIST CPD W/TRAFFIC STOP'},
#  {'crimeTypeID': 418, 'type': 'ASSIST UPD W/THEFT'},
#  {'crimeTypeID': 419, 'type': 'LIQOUR'},
#  {'crimeTypeID': 420, 'type': 'ASSIST/TRANSLATOR'},
#  {'crimeTypeID': 421, 'type': 'CRIMINAL DAMAGE GOVT SUPPORT PROP'},
#  {'crimeTypeID': 422, 'type': 'ASSIST CCSO TRAF STOP'},
#  {'crimeTypeID': 423, 'type': 'BURGLARY FROM MOTOR'},
#  {'crimeTypeID': 424, 'type': 'DISOBEY TRAFFIC (BIKE)'},
#  {'crimeTypeID': 425, 'type': 'NO DRIVERS LICENSE; OPERATING'},
#  {'crimeTypeID': 426, 'type': 'ASSIST/DOMESTIC'},
#  {'crimeTypeID': 427, 'type': 'ASSIST/DISORDERLY SUBJ'},
#  {'crimeTypeID': 428, 'type': 'NO REAR REGISTRATION LIGHT'},
#  {'crimeTypeID': 429, 'type': 'ALLOWING A NUISANCE PARTY'},
#  {'crimeTypeID': 430, 'type': 'RESIST/OBSTRUCT/DISARM AN OFFICER'},
#  {'crimeTypeID': 431, 'type': 'RUNAWAY - MINOR REQUIRE AUTH INTER'},
#  {'crimeTypeID': 432, 'type': 'BURGLARY OF MOTOR VEHICLE'},
#  {'crimeTypeID': 433, 'type': 'MIP ALCOHOL/LIQUOR'},
#  {'crimeTypeID': 434, 'type': 'DRUG EQUIPMENT-POSSESSION'},
#  {'crimeTypeID': 435, 'type': 'LIQUOR - UNDERAGE'},
#  {'crimeTypeID': 436, 'type': 'UNLAWFUL RESTRAINT-AGGRAVATED'},
#  {'crimeTypeID': 437, 'type': 'NOISE'},
#  {'crimeTypeID': 438, 'type': 'POSS OF CANNABIS UNDER 10 GM &'},
#  {'crimeTypeID': 439, 'type': 'RECKLESS CONDUCT'},
#  {'crimeTypeID': 440, 'type': 'SEXUAL ABUSE-AGGRAVATED'},
#  {'crimeTypeID': 441, 'type': 'ASSIST/SEACH WARRANT'},
#  {'crimeTypeID': 442, 'type': 'BOMB THREAT'},
#  {'crimeTypeID': 443, 'type': 'DEATH INVESTIGATION/ASSIST UPD'},
#  {'crimeTypeID': 444, 'type': 'MINOR PRESENT'},
#  {'crimeTypeID': 445, 'type': 'DOEMSTIC VIOLENCE'},
#  {'crimeTypeID': 446, 'type': 'REVENGE PORNOGRAPHY'},
#  {'crimeTypeID': 447, 'type': 'ASSIST ISP W/SEARCH'},
#  {'crimeTypeID': 448, 'type': 'UNLAWFUL POSSESSION OF ID'},
#  {'crimeTypeID': 449, 'type': 'MINOR IN POSSESSION'},
#  {'crimeTypeID': 450, 'type': 'RESIST/OBSTRUCT/DISARM AN'},
#  {'crimeTypeID': 451, 'type': 'CANINE SWEEP - IDOT'},
#  {'crimeTypeID': 452, 'type': 'UNLAWFUL TRESPASS'},
#  {'crimeTypeID': 453, 'type': 'ASSIST/CRIMINAL DAMAGE'},
#  {'crimeTypeID': 454, 'type': 'ASSIST BATTERY'},
#  {'crimeTypeID': 455, 'type': 'POSSESSION OF STOLEN PROP'},
#  {'crimeTypeID': 456, 'type': 'FONDLING'},
#  {'crimeTypeID': 457, 'type': 'FALSE POLICE REPORT'},
#  {'crimeTypeID': 458, 'type': 'SEX OFFENDER REGISTRATION'},
#  {'crimeTypeID': 459, 'type': 'ASSIST/ACCIDENT UPD'},
#  {'crimeTypeID': 460, 'type': 'ASSIST COUNTY PD W/K9 SWEEP'},
#  {'crimeTypeID': 461, 'type': 'THREATS'},
#  {'crimeTypeID': 462, 'type': 'CONTROLLED SUBSTANCE-LOOK-ALIKE'},
#  {'crimeTypeID': 463, 'type': 'THEFT'},
#  {'crimeTypeID': 464, 'type': 'ASSIST/SHOPLIFTER'},
#  {'crimeTypeID': 465, 'type': 'THEFT $500 AND UNDER'},
#  {'crimeTypeID': 466, 'type': 'PURSE SNATCHING'},
#  {'crimeTypeID': 467, 'type': 'DISOBEY BIKE CODE'},
#  {'crimeTypeID': 468, 'type': 'STOLEN PROP RECOVERED'},
#  {'crimeTypeID': 469, 'type': 'SEX OFFENDER-FAIL TO REGISTER'},
#  {'crimeTypeID': 470, 'type': 'ASSIST CPD W/MEDICAL'},
#  {'crimeTypeID': 471, 'type': 'TERRORISM-MAKE FALSE TERROR'},
#  {'crimeTypeID': 472, 'type': 'ASSIST K-9'},
#  {'crimeTypeID': 473, 'type': 'HARRASSMENT'},
#  {'crimeTypeID': 474, 'type': 'PEDESTRIAN STOPS'},
#  {'crimeTypeID': 475, 'type': 'UNLAW USE ID'},
#  {'crimeTypeID': 476, 'type': 'CANNABIS-POSSESSION OVER'},
#  {'crimeTypeID': 477, 'type': 'VISITATION INTERFERENCE'},
#  {'crimeTypeID': 478, 'type': 'THROWING ITEMS'},
#  {'crimeTypeID': 479, 'type': 'PUBLIC POSSESSION'},
#  {'crimeTypeID': 480, 'type': 'ENDANG LIFE/HEALTH OF CHILD'},
#  {'crimeTypeID': 481, 'type': 'NON-FORCIBLE SEX OFFENSE'},
#  {'crimeTypeID': 482, 'type': 'PEEPING TOM'},
#  {'crimeTypeID': 483, 'type': 'MURDER-FIRST DEGREE'},
#  {'crimeTypeID': 484, 'type': 'ASSIST/ARMED SUBJ'},
#  {'crimeTypeID': 485, 'type': 'DOMESTIC OFFENSE'},
#  {'crimeTypeID': 486, 'type': 'DRIVING UNDER THE INFL-'},
#  {'crimeTypeID': 487, 'type': 'DELIVERY OF ALCOHOL/LIQ TO A MINOR'},
#  {'crimeTypeID': 488, 'type': 'POSS DRUG PARAPHERNALIA'},
#  {'crimeTypeID': 489, 'type': 'DEL/MANUF CANNABIS UNDER 10 G -MISD'},
#  {'crimeTypeID': 490, 'type': 'LIQUOR-ILLEGAL CONSUMPTION BY'},
#  {'crimeTypeID': 491, 'type': 'RESIST/OBS CORRECT/POLICE/FIRE'},
#  {'crimeTypeID': 492, 'type': 'PUBLIC INTOXICATION'},
#  {'crimeTypeID': 493, 'type': 'FRAUD-CREDIT CARD'},
#  {'crimeTypeID': 494, 'type': 'TRANSIENT MERCHANT/LICENSE REQUIRED'},
#  {'crimeTypeID': 495, 'type': 'CANNABIS-POSS 30 GM & UNDER'},
#  {'crimeTypeID': 496, 'type': 'LIQUOR - UNDERAGE CONSUMPTION'},
#  {'crimeTypeID': 497, 'type': 'ASST CPD/ARMED SUBJECT'},
#  {'crimeTypeID': 498, 'type': 'CANNABIS-DELIVERY OVER 30GM'},
#  {'crimeTypeID': 499, 'type': 'ASSIST/HARRESSMENT'},
#  {'crimeTypeID': 500, 'type': 'FELONY - ARREST'},
#  {'crimeTypeID': 501, 'type': 'THEFT UNDER'},
#  {'crimeTypeID': 502, 'type': 'TRESPASS TO RESIDENCE'},
#  {'crimeTypeID': 503, 'type': 'VIOL BAIL BOND'},
#  {'crimeTypeID': 504, 'type': 'ZERO TOLERANCE'},
#  {'crimeTypeID': 505, 'type': 'SUICIDE ATTEMPT/DRUGS'},
#  {'crimeTypeID': 506, 'type': 'CHILD PORNOGRAPHY'},
#  {'crimeTypeID': 507, 'type': 'OBSTRUCTING JUSTICE'},
#  {'crimeTypeID': 508, 'type': 'FIREWORKS'},
#  {'crimeTypeID': 509, 'type': 'POSS ALCOHOL PUB PROP /'},
#  {'crimeTypeID': 510, 'type': 'FORGERY/CREDIT CARD FRAUD'},
#  {'crimeTypeID': 511, 'type': 'NOISE & VIBRATIONS'},
#  {'crimeTypeID': 512, 'type': 'CRIMINAL DAMAGE TO PROPERTY'},
#  {'crimeTypeID': 513, 'type': 'ASSIST UIPD W/BATTERY'},
#  {'crimeTypeID': 514, 'type': 'DOMESTIC'},
#  {'crimeTypeID': 515, 'type': 'THEFT FROM MOTOR VEHICLE'},
#  {'crimeTypeID': 516, 'type': 'ASSIST/NO TRESPASS'},
#  {'crimeTypeID': 517, 'type': 'MUTUAL COMBATANTS'},
#  {'crimeTypeID': 518, 'type': 'ASSIST CCSO W/TRAFFIC STOP'},
#  {'crimeTypeID': 519, 'type': 'RESIST/OBSTRUCT OFFICER'},
#  {'crimeTypeID': 520, 'type': 'BURGLARY FROM MOTOR VEHICLE'},
#  {'crimeTypeID': 521, 'type': 'TRESPASS-STATE SUPPORTED LAND'},
#  {'crimeTypeID': 522, 'type': 'DOMESTIC VIOLENCE'},
#  {'crimeTypeID': 523, 'type': 'ROBBERY-AGGRAVATED'},
#  {'crimeTypeID': 524, 'type': 'SRO - YAC REFERRAL'},
#  {'crimeTypeID': 525, 'type': 'DISORDERLY CONDUCT-ALL OTHER'},
#  {'crimeTypeID': 526, 'type': 'ELECTRONIC HARASSMENT'},
#  {'crimeTypeID': 527, 'type': 'RESISTING/OBSTR OFFICER'},
#  {'crimeTypeID': 528, 'type': 'TRAFFIC CITATION/VOP'},
#  {'crimeTypeID': 529, 'type': 'SAFEKEEPING'},
#  {'crimeTypeID': 530, 'type': 'SEX OFFENSE'},
#  {'crimeTypeID': 531, 'type': 'IMPROPER LANE USAGE-ONE-WAY ST'},
#  {'crimeTypeID': 532, 'type': 'RESISTING/OBSTR. OFFICER'},
#  {'crimeTypeID': 533, 'type': 'CONTROLLED SUBSTANCE-MANUF-INTENT'},
#  {'crimeTypeID': 534, 'type': 'ACCIDENT INVOLVING PEDESTRIAN'},
#  {'crimeTypeID': 535, 'type': 'COMPUTER TAMPERING'},
#  {'crimeTypeID': 536, 'type': 'ASSIST UPD WITH K-9'},
#  {'crimeTypeID': 537, 'type': 'CURFEW VIOLATION'},
#  {'crimeTypeID': 538, 'type': 'RAPE'},
#  {'crimeTypeID': 539, 'type': 'LIQUOR-UNDERAGE/PUBLIC POSSESSION'},
#  {'crimeTypeID': 540, 'type': 'ALCOHOL/LIQUOR CONSUMPTION EMPLOYEE'},
#  {'crimeTypeID': 541, 'type': 'HIT AND RUN'},
#  {'crimeTypeID': 542, 'type': 'POSSESSION OF CANNABIS'},
#  {'crimeTypeID': 543, 'type': 'MOTOR VEHICLE THEFT'},
#  {'crimeTypeID': 544, 'type': 'SIMPLE ASSAULT'},
#  {'crimeTypeID': 545, 'type': 'ASSIST CCSO W/TRANSLATION'},
#  {'crimeTypeID': 546, 'type': 'LIQUOR-ILLEGAL CONSUMPTION BY MINOR'},
#  {'crimeTypeID': 547, 'type': 'DRIVING UNDER THE INFLUENCE'},
#  {'crimeTypeID': 548, 'type': 'BIKE VIOLATION'},
#  {'crimeTypeID': 549, 'type': 'K9 ASSIST'},
#  {'crimeTypeID': 550, 'type': 'BURGLARY RESIDENTIAL'},
#  {'crimeTypeID': 551, 'type': 'ASSIST CPD W/BATTERY'},
#  {'crimeTypeID': 552, 'type': 'DOMESTIC-INTERFERENCE WITH REPORT'},
#  {'crimeTypeID': 553, 'type': 'RESIST OBS OFC'},
#  {'crimeTypeID': 554, 'type': 'TRAFFIC OFFENSE'},
#  {'crimeTypeID': 555, 'type': 'EXCITED DELIRIUM'},
#  {'crimeTypeID': 556, 'type': 'PUBLIC DRUNKENNEESS & TRESPASS'},
#  {'crimeTypeID': 557, 'type': 'HARBOURING A RUNAWAY'},
#  {'crimeTypeID': 558, 'type': 'ASSIST COUNTY POLICE W/ARMED SUBJ'},
#  {'crimeTypeID': 559, 'type': 'SPEEDING (RADAR)'},
#  {'crimeTypeID': 560, 'type': 'OTHER CRIMINAL OFFENSES'},
#  {'crimeTypeID': 561, 'type': 'ASSIST UPD W/K-9'},
#  {'crimeTypeID': 562, 'type': 'TRESPASS LAND'},
#  {'crimeTypeID': 563, 'type': 'ASSIST CPD/ROBBERY'},
#  {'crimeTypeID': 564, 'type': 'TRESPASS TO LAND/REAL PROPERTY'},
#  {'crimeTypeID': 565, 'type': 'FORGERY'},
#  {'crimeTypeID': 566, 'type': 'PANHANDLE'},
#  {'crimeTypeID': 567, 'type': 'POSSESSION OF STOLEN FIREARM'},
#  {'crimeTypeID': 568, 'type': 'THEFT FROM COIN-OP'},
#  {'crimeTypeID': 569, 'type': 'FIGHT/DISORDERLY'},
#  {'crimeTypeID': 570, 'type': 'ASSIST/ARMED SUBJECT'},
#  {'crimeTypeID': 571, 'type': 'CONTROLLED SUBSTANCE-POSSESSION'},
#  {'crimeTypeID': 572, 'type': 'AGGR UNLAWFUL USE OF WEAPON'},
#  {'crimeTypeID': 573, 'type': 'MURDER/NON-NEG. MANSSL.'},
#  {'crimeTypeID': 574, 'type': 'VIOLATION OF ORDER OF PROTECTION'},
#  {'crimeTypeID': 575, 'type': 'IMPROPER USE OF SIGNAL'},
#  {'crimeTypeID': 576, 'type': 'BATTERY-DOMESTIC'},
#  {'crimeTypeID': 577, 'type': 'METRO'},
#  {'crimeTypeID': 578, 'type': 'WEAPON'},
#  {'crimeTypeID': 579, 'type': 'AGG BATTERY'},
#  {'crimeTypeID': 580, 'type': 'RESIST/OBSTRUCT/DISARM OFFICER'},
#  {'crimeTypeID': 581, 'type': 'POSSESSION STOLEN PROPERTY'},
#  {'crimeTypeID': 582, 'type': 'ASSIST ATT BURG F/MV'},
#  {'crimeTypeID': 583, 'type': 'HARASSMENT BY TELEPHONE'},
#  {'crimeTypeID': 584, 'type': 'CURFEW'},
#  {'crimeTypeID': 585, 'type': 'CRIMINAL DEFACEMENT OF PROPERTY'},
#  {'crimeTypeID': 586, 'type': 'ASSIST/ROBBERY DETAIL'},
#  {'crimeTypeID': 587, 'type': 'DUI'},
#  {'crimeTypeID': 588, 'type': 'ASSIST CPD W/RETAIL THEFT'},
#  {'crimeTypeID': 589, 'type': 'CANNABIS POSS OVER 10 - 100 G -MISD'},
#  {'crimeTypeID': 590, 'type': 'RESIST/OBSTRUCT'},
#  {'crimeTypeID': 591, 'type': 'TREPASS'},
#  {'crimeTypeID': 592, 'type': 'DRIVING UNDER INFLUENCE-'},
#  {'crimeTypeID': 593, 'type': 'CRIMINAL DEFACEMENT OF'},
#  {'crimeTypeID': 594, 'type': 'NARCOTICS UNIT'},
#  {'crimeTypeID': 595, 'type': 'LIQUOR-SALE TO MINORS,DRUNKS,ETC'},
#  {'crimeTypeID': 596, 'type': 'ASSIST OTHER GOVT AGENCY/EOD'},
#  {'crimeTypeID': 597, 'type': 'ASSIST CPD W/SHOTS FIRED'},
#  {'crimeTypeID': 598, 'type': 'BRINGING CONTRABAND INTO PENAL INST'},
#  {'crimeTypeID': 599, 'type': 'DECEPTIVE PRACTICES/HARASSMENT BY T'},
#  {'crimeTypeID': 600, 'type': 'NOISE VIOLATION'},
#  {'crimeTypeID': 601, 'type': 'RESISTING ARREST'},
#  {'crimeTypeID': 602, 'type': 'ASSIST/THEFT'},
#  {'crimeTypeID': 603, 'type': 'TRAFFIC'},
#  {'crimeTypeID': 604, 'type': 'DIS CONDUCT'},
#  {'crimeTypeID': 605, 'type': 'RECKLESS DRIVING'},
#  {'crimeTypeID': 606, 'type': 'DECEPTIVE PRACTICES'},
#  {'crimeTypeID': 607, 'type': 'K9 ASSIST CPD'},
#  {'crimeTypeID': 608, 'type': 'PUBLIC INDECENCY'},
#  {'crimeTypeID': 609, 'type': 'DEC PRACTICE'},
#  {'crimeTypeID': 610, 'type': 'STATUTORY RAPE'},
#  {'crimeTypeID': 611, 'type': 'THEFT OF MOTOR VEH PARTS & ACCESS'},
#  {'crimeTypeID': 612, 'type': 'DRIVING UNDER INFLUENCE-DRUGS'},
#  {'crimeTypeID': 613, 'type': 'POSS LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 614, 'type': 'CRIMINAL DAMAGE GOVT'},
#  {'crimeTypeID': 615, 'type': 'OBSTRUCTIN JUSTICE'},
#  {'crimeTypeID': 616, 'type': 'OTHER TROUBLE/INFO RPT'},
#  {'crimeTypeID': 617, 'type': 'ASSIST OTHER PD'},
#  {'crimeTypeID': 618, 'type': 'DOMESTIC BATTERY'},
#  {'crimeTypeID': 619, 'type': 'STALKING/CYBERSTALKING'},
#  {'crimeTypeID': 620, 'type': 'CARRYING ALCOHOL/LIQ OUT OF PREMISE'},
#  {'crimeTypeID': 621, 'type': 'ASSIST UPD W/DOMESTIC'},
#  {'crimeTypeID': 622, 'type': 'COUNTED STALKING UNDER C16-0886'},
#  {'crimeTypeID': 623, 'type': 'UNLAWFUL POSS/USE WEAPON BY'},
#  {'crimeTypeID': 624, 'type': 'DOMESTICE VIOLENCE'},
#  {'crimeTypeID': 625, 'type': 'SALE OF TOBACCO'},
#  {'crimeTypeID': 626, 'type': 'DEL/MANUF CANNABIS OVER 30 G -FEL'},
#  {'crimeTypeID': 627, 'type': 'LEAVING THE SCENE OF AN ACCIDENT'},
#  {'crimeTypeID': 628, 'type': 'DISORDERLY/PANDELING'},
#  {'crimeTypeID': 629, 'type': 'TRESPASS-VEHICLE'},
#  {'crimeTypeID': 630, 'type': 'UNAUTHORIZED ENTRY'},
#  {'crimeTypeID': 631, 'type': 'SEXUAL ASSAULT-AGG CRIMINAL'},
#  {'crimeTypeID': 632, 'type': 'ASSAULT-AGGRAVATED'},
#  {'crimeTypeID': 633, 'type': 'ADULT RESPONSIBILITY'},
#  {'crimeTypeID': 634, 'type': 'EOD; ASSIST OTHER'},
#  {'crimeTypeID': 635, 'type': 'HEROIN OVERDOSE'},
#  {'crimeTypeID': 636, 'type': 'ASSIST/ACCIDENT'},
#  {'crimeTypeID': 637, 'type': 'EXTORTION'},
#  {'crimeTypeID': 638, 'type': 'FRAUD-DECEPTION'},
#  {'crimeTypeID': 639, 'type': 'ASSIST PD W/ACCIDENT'},
#  {'crimeTypeID': 640, 'type': 'HARRASMENT BY ELECTRONIC'},
#  {'crimeTypeID': 641, 'type': 'CONTROLLED SUBSTANCE-'},
#  {'crimeTypeID': 642, 'type': 'ASSIST SICK & INJURED'},
#  {'crimeTypeID': 643, 'type': 'THEFT OF MOTOR VEH PARTS &'},
#  {'crimeTypeID': 644, 'type': 'ASSIST W/MENTAL HEALTH'},
#  {'crimeTypeID': 645, 'type': 'VANDALISM-INSTITUTIONAL'},
#  {'crimeTypeID': 646, 'type': 'CREDIT CARD FRAUD/FORGERY'},
#  {'crimeTypeID': 647, 'type': 'DRUGS/LIQUOR'},
#  {'crimeTypeID': 648, 'type': 'ASSIST CCSO W/ARMED SUBJECT'},
#  {'crimeTypeID': 649, 'type': 'ASSIST UPD W/DISORDERLY'},
#  {'crimeTypeID': 650, 'type': 'FALSE PERSONATION OF PEACE OFFICER'},
#  {'crimeTypeID': 651, 'type': 'VEHICULAR NOISE'},
#  {'crimeTypeID': 652, 'type': 'ARMED VIOLENCE'},
#  {'crimeTypeID': 653, 'type': 'SEXUAL-ASSAULT-CRIMINAL'},
#  {'crimeTypeID': 654, 'type': 'THROWING DANGEROUS MATERIALS'},
#  {'crimeTypeID': 655, 'type': 'MISSING PERSON ADULT/FEMALE'},
#  {'crimeTypeID': 656, 'type': 'ASSIST UPD/SHOOTING'},
#  {'crimeTypeID': 657, 'type': 'LIQUOR - PUBLIC PROPERTY'},
#  {'crimeTypeID': 658, 'type': 'CANNABIS POSS 10 GM OR LESS -ORD'},
#  {'crimeTypeID': 659, 'type': 'DOGS RUNNING AT LARGE'},
#  {'crimeTypeID': 660, 'type': 'SEXUAL ABUSE-CRIMINAL'},
#  {'crimeTypeID': 661, 'type': 'THEFT OF LOST/MISLAID PROP'},
#  {'crimeTypeID': 662, 'type': 'TRAFFIC SIGN VIOLATION'},
#  {'crimeTypeID': 663, 'type': 'WARRANT ARREST/TRAFFIC CITATIONS'},
#  {'crimeTypeID': 664, 'type': 'BATTERY-AGGRAVATED'},
#  {'crimeTypeID': 665, 'type': 'DISORDERLY CONDUCT'},
#  {'crimeTypeID': 666, 'type': 'LARCENY'},
#  {'crimeTypeID': 667, 'type': 'UNLAWFUL RESTRAINT'},
#  {'crimeTypeID': 668, 'type': 'DECPTIVE PRACTICE'},
#  {'crimeTypeID': 669, 'type': 'THROWING DANGEROUS'},
#  {'crimeTypeID': 670, 'type': 'SPECIFIC NOISE PROHIBITED'},
#  {'crimeTypeID': 671, 'type': 'DATING VIOLENCE'},
#  {'crimeTypeID': 672, 'type': 'UNLAWFUL USE ID'},
#  {'crimeTypeID': 673, 'type': 'FORCIBLE SEX OFFENSE'},
#  {'crimeTypeID': 674, 'type': 'ATTEMPTED RAPE'},
#  {'crimeTypeID': 675, 'type': 'AGG FLEE/ATTEMPT ELUDE OFFICER'},
#  {'crimeTypeID': 676, 'type': 'IDENTITY THEFT'},
#  {'crimeTypeID': 677, 'type': 'HARASSMENT BY ELECTRONIC COMM'},
#  {'crimeTypeID': 678, 'type': 'DELIVERY CONTROLLED SUB'},
#  {'crimeTypeID': 679, 'type': 'LIQUOR-ILLEGAL POSS. BY MINOR'},
#  {'crimeTypeID': 680, 'type': 'CANNABIS POSS OVER 30 G - OLD'},
#  {'crimeTypeID': 681, 'type': 'AGGRAVATGED ASSAULT'},
#  {'crimeTypeID': 682, 'type': 'MOB ACTION'},
#  {'crimeTypeID': 683, 'type': 'DECPT PRACTICE'},
#  {'crimeTypeID': 684, 'type': 'FALSE ID-POSS (MISC)'},
#  {'crimeTypeID': 685, 'type': 'STALKING/ELECTRONIC HARRASMENT'},
#  {'crimeTypeID': 686, 'type': 'VIOLATION OF ORDER PROTECTION'},
#  {'crimeTypeID': 687, 'type': 'ASSIST COUNTY POLICE'},
#  {'crimeTypeID': 688, 'type': 'HARASSMENT BY ELECTRONIC COMMUNICAT'},
#  {'crimeTypeID': 689, 'type': 'UNLAWFUL USE OF WEAPONS'},
#  {'crimeTypeID': 690, 'type': 'POSSESSION W/INTENT TO DELIVER'},
#  {'crimeTypeID': 691, 'type': 'THEFT OVER $500'},
#  {'crimeTypeID': 692, 'type': 'LOST ARTICLES'},
#  {'crimeTypeID': 693, 'type': 'IMPROPER LANE USAGE'},
#  {'crimeTypeID': 694, 'type': 'COMPUTER FRAUD'},
#  {'crimeTypeID': 695, 'type': 'DISOBEY LIGHT (BIKE)'},
#  {'crimeTypeID': 696, 'type': 'THEFT BY LESSEE'},
#  {'crimeTypeID': 697, 'type': 'ALCOHOL/LIQUOR SERVER NAME TAG REQ'},
#  {'crimeTypeID': 698, 'type': 'BURGLARY MOTOR VEH PARTS & ACCESS'},
#  {'crimeTypeID': 699, 'type': 'DOMESTIC DISPUTE'},
#  {'crimeTypeID': 700, 'type': 'TRESPASSIN'},
#  {'crimeTypeID': 701, 'type': 'CANNABIS-DELIVERY 30GM &'},
#  {'crimeTypeID': 702, 'type': 'MIP'},
#  {'crimeTypeID': 703, 'type': 'ALCOHO/LIQ MINOR PRESENT/TEEN EVENT'},
#  {'crimeTypeID': 704, 'type': 'TELEPHONE THREATS'},
#  {'crimeTypeID': 705, 'type': 'FURNISHING ALCOHOL TO MINOR'},
#  {'crimeTypeID': 706, 'type': 'POSS OF CANNABIS'},
#  {'crimeTypeID': 707, 'type': 'DRIVING UNDER THE INFL-ALCOHOL'},
#  {'crimeTypeID': 708, 'type': 'MISSING PERSON'},
#  {'crimeTypeID': 709, 'type': 'ENDANG CHILD'},
#  {'crimeTypeID': 710, 'type': 'HAZING'},
#  {'crimeTypeID': 711, 'type': 'LIQUOR - ILLEGAL TRANSPORTATION'},
#  {'crimeTypeID': 712, 'type': 'DRUGS - ILLEGAL TRANSPORTATION OF'},
#  {'crimeTypeID': 713, 'type': 'NO DRIVERS LICENSE'},
#  {'crimeTypeID': 714, 'type': 'RUNAWAY - MINOR REQUIRE AUTH'},
#  {'crimeTypeID': 715, 'type': 'ASSIST CCSO W/K-9'},
#  {'crimeTypeID': 716, 'type': 'TRESPASS TO PROPERTY'},
#  {'crimeTypeID': 717, 'type': 'FUGITIVE FROM JUSTICE'},
#  {'crimeTypeID': 718, 'type': 'UPD ACCIDENT (FATAL)'},
#  {'crimeTypeID': 719, 'type': 'CONTROLLED SUBSTANCE-POSS'},
#  {'crimeTypeID': 720, 'type': 'HARASS BY TX'},
#  {'crimeTypeID': 721, 'type': 'DISORDERLY'},
#  {'crimeTypeID': 722, 'type': 'CONTROLLED SUBSTANCE-POSS W/INTENT'},
#  {'crimeTypeID': 723, 'type': 'DECP PRACTICE'},
#  {'crimeTypeID': 724, 'type': 'USE OF FORCE BY OFFICER'},
#  {'crimeTypeID': 725, 'type': 'THEFT-LABOR OR SERVICES'},
#  {'crimeTypeID': 726, 'type': 'ASSIST/U OF I FOUND PROPERTY'},
#  {'crimeTypeID': 727, 'type': 'THEFT-MOTOR VEHICLE'},
#  {'crimeTypeID': 728, 'type': 'SUSPICIOUS ACTIVITIES'},
#  {'crimeTypeID': 729, 'type': 'ASSIST STATE POLICE'},
#  {'crimeTypeID': 730, 'type': 'VERBAL DOMESTIC'},
#  {'crimeTypeID': 731, 'type': 'ASSIST/STABBING'},
#  {'crimeTypeID': 732, 'type': 'POSS ALCOHOL/LIQ PUBLIC PROP/PARKIN'},
#  {'crimeTypeID': 733, 'type': 'UNLAWFUL POSS/USE WEAPON BY FELON'},
#  {'crimeTypeID': 734, 'type': 'ASSIST UPD ON ROBBERY'},
#  {'crimeTypeID': 735, 'type': 'SEX HARASSMENT'},
#  {'crimeTypeID': 736, 'type': 'DEL/MANUF CANNABIS UNDER 30 G -'},
#  {'crimeTypeID': 737, 'type': 'ASSIST/TRAFFIC STOP'},
#  {'crimeTypeID': 738, 'type': 'SUSPENDED LICENSE/WARRANT'},
#  {'crimeTypeID': 739, 'type': 'BATTERY-DOMESTIC & LARCENY'},
#  {'crimeTypeID': 740, 'type': 'TRAFFIC STOP'},
#  {'crimeTypeID': 741, 'type': 'CARRYING OUT OF PREMISE'},
#  {'crimeTypeID': 742, 'type': 'TRAFFIC CITATIONS'},
#  {'crimeTypeID': 743, 'type': 'ASSIST/UNCOOPERATIVE SUBJ'},
#  {'crimeTypeID': 744, 'type': 'LIQUOR-SALE TO MINORS/DRUNKARDS'},
#  {'crimeTypeID': 745, 'type': 'HARASSMENT'},
#  {'crimeTypeID': 746, 'type': 'OPERATE UNINSURED MOTOR VEHICLE'},
#  {'crimeTypeID': 747, 'type': 'DUI - ALCOHOL'},
#  {'crimeTypeID': 748, 'type': 'THEFT GENERALLY'},
#  {'crimeTypeID': 749, 'type': 'BATTERY'},
#  {'crimeTypeID': 750, 'type': 'THEFT FROM COIN-OP MACHINE/DEVICE'},
#  {'crimeTypeID': 751, 'type': 'CANNABIS POSS 30 G AND UNDER - OLD'},
#  {'crimeTypeID': 752, 'type': 'ASSIST FIGHT'},
#  {'crimeTypeID': 753, 'type': 'ASSIST/SEARCH SUBJ'},
#  {'crimeTypeID': 754, 'type': 'ASSIST UPD W/RETAIL THEFT'},
#  {'crimeTypeID': 755, 'type': 'CONTROLLED SUBSTANCE-MANUF-'},
#  {'crimeTypeID': 756, 'type': 'ASSIST CPD W/K-9'},
#  {'crimeTypeID': 757, 'type': 'RESISTING'},
#  {'crimeTypeID': 758, 'type': 'AGGRAVATED BATTERY'},
#  {'crimeTypeID': 759, 'type': 'ASSIST W/SEARCH WARRANT'},
#  {'crimeTypeID': 760, 'type': 'OTHER EQUIPMENT VIOLATIONS'},
#  {'crimeTypeID': 761, 'type': 'HINDERING POLICE OFFCR'},
#  {'crimeTypeID': 762, 'type': 'LIQUOR'},
#  {'crimeTypeID': 763, 'type': 'POSS OF DRUG PARAPHENALIA'},
#  {'crimeTypeID': 764, 'type': 'AGGRAVATED ASSAULT'},
#  {'crimeTypeID': 765, 'type': 'TRESPASS'},
#  {'crimeTypeID': 766, 'type': 'TRESPASS NOTICE'},
#  {'crimeTypeID': 767, 'type': 'SEARCH WARRANT SERVICE'},
#  {'crimeTypeID': 768, 'type': 'ASSIST UPD'},
#  {'crimeTypeID': 769, 'type': 'METRO/ASSIST OTHER'},
#  {'crimeTypeID': 770, 'type': 'HAZING - FRAT/SORORITY'},
#  {'crimeTypeID': 771, 'type': 'LIQUOR - CARRYING IN PUBLIC PLACE'},
#  {'crimeTypeID': 772, 'type': 'PUBLIC URINATION'},
#  {'crimeTypeID': 773, 'type': 'CRISIS INTERVEN. - OTHER'},
#  {'crimeTypeID': 774, 'type': 'DRUGS'},
#  {'crimeTypeID': 775, 'type': 'UNLAWFUL USE OF ID'},
#  {'crimeTypeID': 776, 'type': 'INTIMIDATION'},
#  {'crimeTypeID': 777, 'type': 'DECEPT PRACTICE'},
#  {'crimeTypeID': 778, 'type': 'SALES OF TOBACCO TO MINORS'},
#  {'crimeTypeID': 779, 'type': 'DOMESTIC DISPUTE - VERBAL ONLY'},
#  {'crimeTypeID': 780, 'type': 'ASSIST ROBBERY'},
#  {'crimeTypeID': 781, 'type': 'THEFT-CITY'},
#  {'crimeTypeID': 782, 'type': 'SIMPLE BATTERY'},
#  {'crimeTypeID': 783, 'type': 'ASSIST URBANA THEFT'},
#  {'crimeTypeID': 784, 'type': 'LIQUOR - OPEN ALCOHOL'},
#  {'crimeTypeID': 785, 'type': 'ACCIDENT W/NON-VEH PROP DAMAGE'},
#  {'crimeTypeID': 786, 'type': 'ELECTRICAL FIRE'},
#  {'crimeTypeID': 787, 'type': 'STALKING-AGGRAVATED'},
#  {'crimeTypeID': 788, 'type': 'EOD CALLOUT'},
#  {'crimeTypeID': 789, 'type': 'OFFICIAL MISCONDUCT'},
#  {'crimeTypeID': 790, 'type': 'RIDING BIKE ON ROAD'},
#  {'crimeTypeID': 791, 'type': 'BIKE VIOLATIONS'},
#  {'crimeTypeID': 792, 'type': 'BATTERY -CITY'},
#  {'crimeTypeID': 793, 'type': 'UNAUTHORIZED VIDEOTAPING/LIVE VIDEO'},
#  {'crimeTypeID': 794, 'type': 'K9 ASSIST CCSO'},
#  {'crimeTypeID': 795, 'type': 'FALSE FIRE ALARM'},
#  {'crimeTypeID': 796, 'type': 'AGG AGASSULT'},
#  {'crimeTypeID': 797, 'type': 'DEL/MANUF CANNABIS UNDER 30 G -MISD'},
#  {'crimeTypeID': 798, 'type': 'CRUELTY TO ANIMALS'},
#  {'crimeTypeID': 799, 'type': 'POSS ALCOHOL PUB PROP / PARKING'},
#  {'crimeTypeID': 800, 'type': 'FLEEING/ELUDING'},
#  {'crimeTypeID': 801, 'type': 'ASSIST/BUILDING CHECK'},
#  {'crimeTypeID': 802, 'type': 'THEFT FROM BUILDING'},
#  {'crimeTypeID': 803, 'type': 'WARRANT-IN STATE'},
#  {'crimeTypeID': 804, 'type': 'THROW DANGEROUS MATERIAL'},
#  {'crimeTypeID': 805, 'type': 'MISSING PERSON ADULT/MALE'},
#  {'crimeTypeID': 806, 'type': 'BIKE ENFORCEMENT'},
#  {'crimeTypeID': 807, 'type': 'LIQUOR-UNDERAGE'},
#  {'crimeTypeID': 808, 'type': 'SEXUAL ASSAULT'},
#  {'crimeTypeID': 809, 'type': 'TRESPASSING'},
#  {'crimeTypeID': 810, 'type': 'FRAUD - DECEPTION'},
#  {'crimeTypeID': 811, 'type': 'HYPODERMIC NEEDLE/SYRINGE-'},
#  {'crimeTypeID': 812, 'type': 'LIQUOR/THEFT'},
#  {'crimeTypeID': 813, 'type': 'ASSIST UPD W/K9 SWEEP'},
#  {'crimeTypeID': 814, 'type': 'LIQUOR - PUBLIC POSSESSION'},
#  {'crimeTypeID': 815, 'type': 'VIOLATION ORDER PROTECTION'},
#  {'crimeTypeID': 816, 'type': 'ASSIST CPD ROBBERY'},
#  {'crimeTypeID': 817, 'type': 'ASSIST CCSO'},
#  {'crimeTypeID': 818, 'type': 'DESTR/DAMAG/VAND'},
#  {'crimeTypeID': 819, 'type': 'BEGGERS PROHIBITED'},
#  {'crimeTypeID': 820, 'type': 'BREATH ALCOHOL OVER LIMIT'},
#  {'crimeTypeID': 821, 'type': 'ATTEMPTED THEFT'},
#  {'crimeTypeID': 822, 'type': 'ROBBERY'},
#  {'crimeTypeID': 823, 'type': 'ASSIST OTHER POLICE DEPT'},
#  {'crimeTypeID': 824, 'type': 'EXPIRED REGISTRATION'},
#  {'crimeTypeID': 825, 'type': 'ASSIST CCSO W/BMV'},
#  {'crimeTypeID': 826, 'type': 'THEFT OVER'},
#  {'crimeTypeID': 827, 'type': 'DRIVING UNDER SUSPENDED LICENSE'},
#  {'crimeTypeID': 828, 'type': 'METRO ACTIVATION'},
#  {'crimeTypeID': 829, 'type': 'ASSIST/K9 SEARCH'},
#  {'crimeTypeID': 830, 'type': 'DEPETIVE PRACTICE/COUNTERFIT'},
#  {'crimeTypeID': 831, 'type': 'ASSIST W/K9 SWEEP'},
#  {'crimeTypeID': 832, 'type': 'ROBBERY-ARMED'},
#  {'crimeTypeID': 833, 'type': 'LEAVING SCENE PROPERTY DAMAGE'},
#  {'crimeTypeID': 834, 'type': 'DOMESTIC BATTERY/AGG ASSAULT'},
#  {'crimeTypeID': 835, 'type': 'CANNABIS POSS MORE THAN 10 LESS'},
#  {'crimeTypeID': 836, 'type': 'FRAUD/DECEPTION'},
#  {'crimeTypeID': 837, 'type': 'UNLAWFUL POSS FIREARM & AMMUNITION'},
#  {'crimeTypeID': 838, 'type': 'CANNABIS-DELIVERY 30GM & UNDER'},
#  {'crimeTypeID': 839, 'type': 'THEFT OF LOST/MISLAID PROPERTY'},
#  {'crimeTypeID': 840, 'type': 'PUBLIC URINATION-CITY'},
#  {'crimeTypeID': 841, 'type': 'BURGLARY'},
#  {'crimeTypeID': 842, 'type': 'BICYCLE VIOLATION'},
#  {'crimeTypeID': 843, 'type': 'TRESPASS/RESISTING ARREST'},
#  {'crimeTypeID': 844, 'type': 'VERBAL DISPUTE'},
#  {'crimeTypeID': 845, 'type': 'ASSIST STATE/ACCIDENT'},
#  {'crimeTypeID': 846, 'type': 'CRIMINAL DAMAGE'},
#  {'crimeTypeID': 847, 'type': 'THEFT-RETAIL-CITY'},
#  {'crimeTypeID': 848, 'type': 'LOUD NOISE'},
#  {'crimeTypeID': 849, 'type': 'RETAIL THEFT'},
#  {'crimeTypeID': 850, 'type': 'DISORDERLY SUBJECT'},
#  {'crimeTypeID': 851, 'type': 'DUI - DRUGS'},
#  {'crimeTypeID': 852, 'type': 'CRISIS INTERVEN. - ALCOHOL'},
#  {'crimeTypeID': 853, 'type': 'ASSIST/K9'},
#  {'crimeTypeID': 854, 'type': 'VOOP'}]

# %%
#Flush the list of dictionary to CSV file
crimeTypeColumns = ['crimeTypeID','type']

crimeTypeCSVName = "CrimeType.csv"

try:
    with open(csvFilePath+"\\"+crimeTypeCSVName, 'w', newline="") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=crimeTypeColumns)
        writer.writeheader()
        for data in crimeTypeListOfDicts:
            writer.writerow(data)
except IOError:
    print("I/O error")

# %% [markdown]
# # Create Crime CSV

# %% [markdown]
# ### Add incident column

# %%
crimeDF = csvData[["Incident"]]
crimeDF
# Out:
#        Incident
# 0     II1300002
# 1     II1300001
# 2     II1300003
# 3     II1300004
# 4     II1300006
# ...         ...
# 7609  CC1909074
# 7610  IF1901488
# 7611  II1901441
# 7612  II1901442
# 7613  UU1905819
#
# [7443 rows x 1 columns]

# %% [markdown]
# ### Add reportedAt column

# %%
def convertCSVDateToSQLDateFormat(str):
    list = str.split("/")
    res = "20" + list[2] + "-" + list[1] + "-" + list[0]
    return res
convertCSVDateToSQLDateFormat("1/1/13")
# Out:
# '2013-1-1'

# %%
# Add reportedAt column
reportedAt = []
for date in csvData["Date reported"]:
    reportedAt.append(convertCSVDateToSQLDateFormat(date))

index = 0
for time in csvData["Time reported"]:
    reportedAt[index] += " " + time.split(" ")[0]
    index += 1
    
reportedAtDF = pd.DataFrame(reportedAt, columns = ['reportedAt'])
reportedAtDF
# Out:
#              reportedAt
# 0      2013-1-1 1:39:00
# 1     2013-1-1 12:44:00
# 2      2013-1-1 6:25:00
# 3      2013-1-1 9:22:00
# 4     2013-3-1 11:00:00
# ...                 ...
# 7438    2019-14-11 7:00
# 7439   2019-14-11 16:56
# 7440   2019-14-11 16:52
# 7441   2019-14-11 20:10
# 7442    2019-14-11 7:00
#
# [7443 rows x 1 columns]

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,reportedAtDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt
# 0     II1300002   2013-1-1 1:39:00
# 1     II1300001  2013-1-1 12:44:00
# 2     II1300003   2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00
# 4     II1300006  2013-3-1 11:00:00
# ...         ...                ...
# 7609  CC1909074                NaN
# 7610  IF1901488                NaN
# 7611  II1901441                NaN
# 7612  II1901442                NaN
# 7613  UU1905819                NaN
#
# [7610 rows x 2 columns]

# %% [markdown]
# ### Add occuredAt column

# %%
# Add occuredAt column
# print(csvData.isnull())

occurredAt = []
for date in csvData["Date occurred"]:
#     print(date)
#     print(type(date))
    occurredAt.append(convertCSVDateToSQLDateFormat(date))

index = 0
for time in csvData["Time occurred"]:
    occurredAt[index] += " " + time.split(" ")[0]
    index += 1
    
occurredAtDF = pd.DataFrame(occurredAt, columns = ['occurredAt'])
occurredAtDF
# Out:
#               occurredAt
# 0       2013-1-1 1:39:00
# 1      2013-1-1 12:44:00
# 2       2013-1-1 6:25:00
# 3       2013-1-1 2:00:00
# 4     2012-20-12 8:00:00
# ...                  ...
# 7438     2019-14-11 2:37
# 7439    2019-14-11 16:56
# 7440    2019-14-11 16:00
# 7441    2019-14-11 20:05
# 7442    2019-13-11 19:41
#
# [7443 rows x 1 columns]

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,occurredAtDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001  2013-1-1 12:44:00   2013-1-1 12:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-3-1 11:00:00  2012-20-12 8:00:00
# ...         ...                ...                 ...
# 7609  CC1909074                NaN                 NaN
# 7610  IF1901488                NaN                 NaN
# 7611  II1901441                NaN                 NaN
# 7612  II1901442                NaN                 NaN
# 7613  UU1905819                NaN                 NaN
#
# [7610 rows x 3 columns]

# %% [markdown]
# ### Add Disposition column

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,csvData["Disposition"]], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001  2013-1-1 12:44:00   2013-1-1 12:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-3-1 11:00:00  2012-20-12 8:00:00
# ...         ...                ...                 ...
# 7609  CC1909074                NaN                 NaN
# 7610  IF1901488                NaN                 NaN
# 7611  II1901441                NaN                 NaN
# 7612  II1901442                NaN                 NaN
# 7613  UU1905819                NaN                 NaN
#
#                    Disposition
# 0                       ARREST
# 1                       ARREST
# 2                       ARREST
# 3                       ARREST
# 4                 ADMIN. CLOSE
# ...                        ...
# 7609  REPORTED TO OTHER AGENCY
# 7610              ADMIN CLOSED
# 7611              ADMIN. CLOSE
# 7612              ADMIN. CLOSE
# 7613  REPORTED TO OTHER AGENCY
#
# [7610 rows x 4 columns]

# %% [markdown]
# ### Add crimeTypeID column

# %%
crimeTypeID = []
for row in csvData["Crime Description"]:
    crimeTypeStartIndex = 300
    for type in crimeTypeList:
        if(type==row.upper().strip()):
            crimeTypeID.append(crimeTypeStartIndex)
            break;
        crimeTypeStartIndex += 1

crimeTypeIDDF = pd.DataFrame(crimeTypeID, columns = ['crimeTypeID'])
crimeTypeIDDF
# Out:
#       crimeTypeID
# 0             486
# 1             542
# 2             486
# 3             614
# 4             568
# ...           ...
# 7438          514
# 7439          461
# 7440          823
# 7441          421
# 7442          841
#
# [7443 rows x 1 columns]

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,crimeTypeIDDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001  2013-1-1 12:44:00   2013-1-1 12:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-3-1 11:00:00  2012-20-12 8:00:00
# ...         ...                ...                 ...
# 7609  CC1909074                NaN                 NaN
# 7610  IF1901488                NaN                 NaN
# 7611  II1901441                NaN                 NaN
# 7612  II1901442                NaN                 NaN
# 7613  UU1905819                NaN                 NaN
#
#                    Disposition  crimeTypeID
# 0                       ARREST        486.0
# 1                       ARREST        542.0
# 2                       ARREST        486.0
# 3                       ARREST        614.0
# 4                 ADMIN. CLOSE        568.0
# ...                        ...          ...
# 7609  REPORTED TO OTHER AGENCY          NaN
# 7610              ADMIN CLOSED          NaN
# 7611              ADMIN. CLOSE          NaN
# 7612              ADMIN. CLOSE          NaN
# 7613  REPORTED TO OTHER AGENCY          NaN
#
# [7610 rows x 5 columns]

# %%
#Rename columns
crimeDF.columns = ["incidentID", "reportedAt", "occuredAt", "disposition", "crimeTypeID"]
crimeDF
# Out:
#      incidentID         reportedAt           occuredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001  2013-1-1 12:44:00   2013-1-1 12:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-3-1 11:00:00  2012-20-12 8:00:00
# ...         ...                ...                 ...
# 7609  CC1909074                NaN                 NaN
# 7610  IF1901488                NaN                 NaN
# 7611  II1901441                NaN                 NaN
# 7612  II1901442                NaN                 NaN
# 7613  UU1905819                NaN                 NaN
#
#                    disposition  crimeTypeID
# 0                       ARREST        486.0
# 1                       ARREST        542.0
# 2                       ARREST        486.0
# 3                       ARREST        614.0
# 4                 ADMIN. CLOSE        568.0
# ...                        ...          ...
# 7609  REPORTED TO OTHER AGENCY          NaN
# 7610              ADMIN CLOSED          NaN
# 7611              ADMIN. CLOSE          NaN
# 7612              ADMIN. CLOSE          NaN
# 7613  REPORTED TO OTHER AGENCY          NaN
#
# [7610 rows x 5 columns]

# %%
#Flush the dataframe to CSV file

crimeCSVName = "Crime.csv"
    
crimeDF.to_csv(csvFilePath+"\\"+crimeCSVName, encoding='utf-8', index=False)

# %% [markdown]
# # Create happensAt CSV

# %%
csvData
# Out:
#        Incident Date reported   Time reported Date occurred   Time occurred  \
# 0     II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1     II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2     II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3     II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4     II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ...         ...           ...             ...           ...             ...
# 7609  CC1909074      11/14/19            7:00      11/14/19            2:37
# 7610  IF1901488      11/14/19           16:56      11/14/19           16:56
# 7611  II1901441      11/14/19           16:52      11/14/19           16:00
# 7612  II1901442      11/14/19           20:10      11/14/19           20:05
# 7613  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#                General Location                  Crime Description  \
# 0      500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1            600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                      CIRCLE K            DRIVING UNDER THE INFL-
# 3     COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                  KIRK / GERTY                 THEFT FROM COIN-OP
# ...                         ...                                ...
# 7609    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 7610  IUB ADMINISTRATIVE SUITES                            THREATS
# 7611        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 7612      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 7613   102 N GREGORY ST, URBANA                           BURGLARY
#
#                    Disposition  BlockId
# 0                       ARREST        0
# 1                       ARREST       14
# 2                       ARREST        0
# 3                       ARREST        9
# 4                 ADMIN. CLOSE        0
# ...                        ...      ...
# 7609  REPORTED TO OTHER AGENCY       25
# 7610              ADMIN CLOSED       50
# 7611              ADMIN. CLOSE        0
# 7612              ADMIN. CLOSE        0
# 7613  REPORTED TO OTHER AGENCY       36
#
# [7443 rows x 9 columns]

# %%
happensAtDF = csvData[["Incident", "BlockId", "General Location"]]

# %%
#Rename columns
happensAtDF.columns = ["incidentID", "blockID", "genLocation"]
happensAtDF
# Out:
#      incidentID  blockID                genLocation
# 0     II1300002        0   500 blk of JOHN STREET E
# 1     II1300001       14         600 blk of GREEN E
# 2     II1300003        0                   CIRCLE K
# 3     II1300004        9  COMPUTER APPLICATION BLDG
# 4     II1300006        0               KIRK / GERTY
# ...         ...      ...                        ...
# 7609  CC1909074       25    808 S OAK ST, CHAMPAIGN
# 7610  IF1901488       50  IUB ADMINISTRATIVE SUITES
# 7611  II1901441        0        500 blk of ELM ST S
# 7612  II1901442        0      ARCHITECTURE BUILDING
# 7613  UU1905819       36   102 N GREGORY ST, URBANA
#
# [7443 rows x 3 columns]

# %%
#Flush the dataframe to CSV file

happensAtCSVName = "happensAt.csv"
    
happensAtDF.to_csv(csvFilePath+"\\"+happensAtCSVName, encoding='utf-8', index=False)
