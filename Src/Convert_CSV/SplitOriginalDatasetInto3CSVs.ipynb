# %%
import csv
import pandas as pd

# %%
csvFilePath = r"C:\Users\Yash\Desktop\Courses\CS411\Project Track 1\Src\Convert_CSV\Data"
csvList = ["2013new.csv", "2014new.csv", "2015new.csv", "2016new.csv", "2017new.csv", "2018new.csv", "2019new.csv"]

# %%
csvData = pd.DataFrame()
for csvName in csvList:
    csvDataTemp = pd.read_csv(csvFilePath+"\\"+csvName)
    csvData = pd.concat([csvData,csvDataTemp])
listOfcsvDataColumns = list(csvData.columns)
csvData
# Out:
#       Incident Date reported   Time reported Date occurred   Time occurred  \
# 0    II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1    II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2    II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3    II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4    II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ..         ...           ...             ...           ...             ...
# 877  CC1909074      11/14/19            7:00      11/14/19            2:37
# 878  IF1901488      11/14/19           16:56      11/14/19           16:56
# 879  II1901441      11/14/19           16:52      11/14/19           16:00
# 880  II1901442      11/14/19           20:10      11/14/19           20:05
# 881  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#               General Location                  Crime Description  \
# 0     500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1           600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                     CIRCLE K            DRIVING UNDER THE INFL-
# 3    COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                 KIRK / GERTY                 THEFT FROM COIN-OP
# ..                         ...                                ...
# 877    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 878  IUB ADMINISTRATIVE SUITES                            THREATS
# 879        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 880      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 881   102 N GREGORY ST, URBANA                           BURGLARY
#
#                   Disposition  BlockId
# 0                      ARREST        0
# 1                      ARREST       14
# 2                      ARREST        0
# 3                      ARREST        9
# 4                ADMIN. CLOSE        0
# ..                        ...      ...
# 877  REPORTED TO OTHER AGENCY       25
# 878              ADMIN CLOSED       50
# 879              ADMIN. CLOSE        0
# 880              ADMIN. CLOSE        0
# 881  REPORTED TO OTHER AGENCY       36
#
# [7617 rows x 9 columns]

# %%
# csvData = pd.read_csv(csvFilePath+"\\"+csvName)
# listOfcsvDataColumns = list(csvData.columns)
# csvData

# %%
# Drop NaN rows
csvData = csvData.dropna()

# Drop row which has "nan" value
for col in listOfcsvDataColumns:
    csvData = csvData[~csvData[col].isin(["nan", "UNKNOWN", "unknown", ""])]
    
# Replace certain characters from all of the dataframe
for col in listOfcsvDataColumns:
    csvData[col] = csvData[col].replace('\'','', regex=True)
    csvData[col] = csvData[col].replace('\"','', regex=True)

csvData = csvData.reset_index(drop=True)    

csvData
# Out:
#        Incident Date reported   Time reported Date occurred   Time occurred  \
# 0     II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1     II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2     II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3     II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4     II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ...         ...           ...             ...           ...             ...
# 7438  CC1909074      11/14/19            7:00      11/14/19            2:37
# 7439  IF1901488      11/14/19           16:56      11/14/19           16:56
# 7440  II1901441      11/14/19           16:52      11/14/19           16:00
# 7441  II1901442      11/14/19           20:10      11/14/19           20:05
# 7442  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#                General Location                  Crime Description  \
# 0      500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1            600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                      CIRCLE K            DRIVING UNDER THE INFL-
# 3     COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                  KIRK / GERTY                 THEFT FROM COIN-OP
# ...                         ...                                ...
# 7438    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 7439  IUB ADMINISTRATIVE SUITES                            THREATS
# 7440        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 7441      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 7442   102 N GREGORY ST, URBANA                           BURGLARY
#
#                    Disposition  BlockId
# 0                       ARREST        0
# 1                       ARREST       14
# 2                       ARREST        0
# 3                       ARREST        9
# 4                 ADMIN. CLOSE        0
# ...                        ...      ...
# 7438  REPORTED TO OTHER AGENCY       25
# 7439              ADMIN CLOSED       50
# 7440              ADMIN. CLOSE        0
# 7441              ADMIN. CLOSE        0
# 7442  REPORTED TO OTHER AGENCY       36
#
# [7443 rows x 9 columns]

# %% [markdown]
# ## Flush the curated and compiled data into CSV

# %%
#Flush the dataframe to CSV file

processedDatasetCSVName = "processedDatset.csv"
    
csvData.to_csv(csvFilePath+"\\"+processedDatasetCSVName, encoding='utf-8', index=False)

# %% [markdown]
# # Create CrimeType CSV

# %%
#Get unique types of crime
crimeTypeSet = set()
for x in csvData["Crime Description"]:
    crimeTypeSet.add(x.upper().strip())
crimeTypeList = list(crimeTypeSet)
crimeTypeSet
# Out:
# {'ABANDONED JUNK VEHICLES',
#  'ACCIDENT HIT AND RUN',
#  'ACCIDENT INVOLVING NON-INJURY',
#  'ACCIDENT INVOLVING OTHER CITY PROP',
#  'ACCIDENT INVOLVING PEDESTRIAN',
#  'ACCIDENT W/NON-VEH PROP DAMAGE',
#  'ADULT RESPONSIBILITY',
#  'AGG AGASSULT',
#  'AGG ASSAULT',
#  'AGG BATTERY',
#  'AGG DISCHARGE OF FIREARM',
#  'AGG FLEE/ATTEMPT ELUDE OFFICER',
#  'AGGR UNLAWFUL USE OF WEAPON',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATED BATTERY',
#  'AGGRAVATGED ASSAULT',
#  'ALCOHO/LIQ MINOR PRESENT/TEEN EVENT',
#  'ALCOHOL',
#  'ALCOHOL/LIQ SALES INTOX SUBJ OR',
#  'ALCOHOL/LIQUOR BASSET LICENSE REQ',
#  'ALCOHOL/LIQUOR CONSUMPTION EMPLOYEE',
#  'ALCOHOL/LIQUOR LICENSE REQUIRED',
#  'ALCOHOL/LIQUOR SERVER NAME TAG REQ',
#  'ALLOWING A NUISANCE PARTY',
#  'ARMED VIOLENCE',
#  'ARSON',
#  'ASSAULT',
#  'ASSAULT-AGGRAVATED',
#  'ASSIST ATT BURG F/MV',
#  'ASSIST BATTERY',
#  'ASSIST CCSO',
#  'ASSIST CCSO TRAF STOP',
#  'ASSIST CCSO W/ARMED SUBJECT',
#  'ASSIST CCSO W/BMV',
#  'ASSIST CCSO W/K-9',
#  'ASSIST CCSO W/TRAFFIC STOP',
#  'ASSIST CCSO W/TRANSLATION',
#  'ASSIST COUNTY PD W/K9 SWEEP',
#  'ASSIST COUNTY POLICE',
#  'ASSIST COUNTY POLICE W/ARMED SUBJ',
#  'ASSIST CPD',
#  'ASSIST CPD ROBBERY',
#  'ASSIST CPD W/ARMED SUBJECT',
#  'ASSIST CPD W/BANK ROBBERY',
#  'ASSIST CPD W/BATTERY',
#  'ASSIST CPD W/K-9',
#  'ASSIST CPD W/MEDICAL',
#  'ASSIST CPD W/RETAIL THEFT',
#  'ASSIST CPD W/ROBBERY',
#  'ASSIST CPD W/SHOTS FIRED',
#  'ASSIST CPD W/THEFT',
#  'ASSIST CPD W/TRAFFIC STOP',
#  'ASSIST CPD WITH BATTERY',
#  'ASSIST CPD/ROBBERY',
#  'ASSIST DOMESTIC',
#  'ASSIST FIGHT',
#  'ASSIST ISP W/SEARCH',
#  'ASSIST K-9',
#  'ASSIST K9',
#  'ASSIST K9 SEARCH',
#  'ASSIST OTHER GOVT AGENCY/EOD',
#  'ASSIST OTHER PD',
#  'ASSIST OTHER POLICE DEPT',
#  'ASSIST PD W/ACCIDENT',
#  'ASSIST ROBBERY',
#  'ASSIST SICK & INJURED',
#  'ASSIST STATE POLICE',
#  'ASSIST STATE/ACCIDENT',
#  'ASSIST TOW TRUCK',
#  'ASSIST UIPD W/BATTERY',
#  'ASSIST UPD',
#  'ASSIST UPD ON ROBBERY',
#  'ASSIST UPD W/DETAIN SUBJECT',
#  'ASSIST UPD W/DISORDERLY',
#  'ASSIST UPD W/DOMESTIC',
#  'ASSIST UPD W/K-9',
#  'ASSIST UPD W/K9 SWEEP',
#  'ASSIST UPD W/RETAIL THEFT',
#  'ASSIST UPD W/ROBBERY',
#  'ASSIST UPD W/THEFT',
#  'ASSIST UPD WITH K-9',
#  'ASSIST UPD/SHOOTING',
#  'ASSIST URBANA THEFT',
#  'ASSIST W/K-9',
#  'ASSIST W/K9 SWEEP',
#  'ASSIST W/MENTAL HEALTH',
#  'ASSIST W/SEARCH WARRANT',
#  'ASSIST/ACCIDENT',
#  'ASSIST/ACCIDENT UPD',
#  'ASSIST/ARMED SUBJ',
#  'ASSIST/ARMED SUBJECT',
#  'ASSIST/BUILDING CHECK',
#  'ASSIST/BURGLARY',
#  'ASSIST/CHECK WELFARE',
#  'ASSIST/CPD WITH ACCIDENT',
#  'ASSIST/CRIMINAL DAMAGE',
#  'ASSIST/DISORDERLY SUBJ',
#  'ASSIST/DOMESTIC',
#  'ASSIST/DOMESTIC BATTERY',
#  'ASSIST/HARRESSMENT',
#  'ASSIST/K-9',
#  'ASSIST/K9',
#  'ASSIST/K9 SEARCH',
#  'ASSIST/NO TRESPASS',
#  'ASSIST/ROBBERY DETAIL',
#  'ASSIST/SEACH WARRANT',
#  'ASSIST/SEARCH SUBJ',
#  'ASSIST/SHOPLIFTER',
#  'ASSIST/SHOTS FIRED',
#  'ASSIST/STABBING',
#  'ASSIST/THEFT',
#  'ASSIST/TRAFFIC STOP',
#  'ASSIST/TRANSLATOR',
#  'ASSIST/U OF I FOUND PROPERTY',
#  'ASSIST/UNCOOPERATIVE SUBJ',
#  'ASST CPD/ARMED SUBJECT',
#  'ATTEMPTED RAPE',
#  'ATTEMPTED THEFT',
#  'BATTERY',
#  'BATTERY -CITY',
#  'BATTERY-AGG DOMESTIC',
#  'BATTERY-AGGRAVATED',
#  'BATTERY-DOMESTIC',
#  'BATTERY-DOMESTIC & LARCENY',
#  'BEGGERS PROHIBITED',
#  'BICYCLE VIOLATION',
#  'BIKE ENFORCEMENT',
#  'BIKE VIOLATION',
#  'BIKE VIOLATIONS',
#  'BOMB THREAT',
#  'BONFIRES PROHIBITED',
#  'BREATH ALCOHOL OVER LIMIT',
#  'BRINGING CONTRABAND INTO PENAL INST',
#  'BURGLARY',
#  'BURGLARY FROM MOTOR',
#  'BURGLARY FROM MOTOR VEHICLE',
#  'BURGLARY MOTOR VEH PARTS & ACCESS',
#  'BURGLARY OF MOTOR VEHICLE',
#  'BURGLARY RESIDENTIAL',
#  'BURNING PROHIBITED',
#  'CANINE SWEEP - IDOT',
#  'CANNABIS POSS 10 GM OR LESS -ORD',
#  'CANNABIS POSS 30 G AND UNDER - OLD',
#  'CANNABIS POSS MORE THAN 10 LESS',
#  'CANNABIS POSS OVER 10 - 100 G -MISD',
#  'CANNABIS POSS OVER 30 G - OLD',
#  'CANNABIS-DELIVERY 30GM &',
#  'CANNABIS-DELIVERY 30GM & UNDER',
#  'CANNABIS-DELIVERY OVER 30GM',
#  'CANNABIS-POSS 30 GM & UNDER',
#  'CANNABIS-POSSESSION OVER',
#  'CANNABIS-POSSESSION OVER 30GM',
#  'CARRYING ALCOHOL/LIQ OUT OF PREMISE',
#  'CARRYING OUT OF PREMISE',
#  'CHILD PORNOGRAPHY',
#  'COMPUTER FRAUD',
#  'COMPUTER TAMPERING',
#  'CONTRIBUTING CRIM DELINQUENCY JUV',
#  'CONTROLLED SUBSTANCE-',
#  'CONTROLLED SUBSTANCE-LOOK-ALIKE',
#  'CONTROLLED SUBSTANCE-MANUF-',
#  'CONTROLLED SUBSTANCE-MANUF-INTENT',
#  'CONTROLLED SUBSTANCE-POSS',
#  'CONTROLLED SUBSTANCE-POSS W/INTENT',
#  'CONTROLLED SUBSTANCE-POSSESSION',
#  'COUNTED STALKING UNDER C16-0886',
#  'CREDIT CARD FRAUD',
#  'CREDIT CARD FRAUD/FORGERY',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL DAMAGE GOVT',
#  'CRIMINAL DAMAGE GOVT SUPPORT',
#  'CRIMINAL DAMAGE GOVT SUPPORT PROP',
#  'CRIMINAL DAMAGE TO PROPERTY',
#  'CRIMINAL DEFACEMENT OF',
#  'CRIMINAL DEFACEMENT OF PROPERTY',
#  'CRISIS INTERVEN. - ALCOHOL',
#  'CRISIS INTERVEN. - OTHER',
#  'CRUELTY TO ANIMALS',
#  'CURFEW',
#  'CURFEW VIOLATION',
#  'CYBERSTALKING',
#  'DAMAGING PROPERTY',
#  'DATING VIOLENCE',
#  'DEATH INVESTIGATION/ASSIST UPD',
#  'DEC PRACTICE',
#  'DECEPT PRACT',
#  'DECEPT PRACTICE',
#  'DECEPTIVE PRACTCIES',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICES',
#  'DECEPTIVE PRACTICES/EXTORTION',
#  'DECEPTIVE PRACTICES/HARASSMENT BY T',
#  'DECP PRACTICE',
#  'DECPT PRACT',
#  'DECPT PRACTICE',
#  'DECPTIVE PRACTICE',
#  'DEFACING IDENTI.MARKS OF FIREARMS',
#  'DEL/MANUF CANNABIS OVER 30 G -FEL',
#  'DEL/MANUF CANNABIS UNDER 10 G -MISD',
#  'DEL/MANUF CANNABIS UNDER 30 G -',
#  'DEL/MANUF CANNABIS UNDER 30 G -MISD',
#  'DELIVERY CONTROLLED SUB',
#  'DELIVERY OF ALCOHOL/LIQ TO A MINOR',
#  'DEPETIVE PRACTICE/COUNTERFIT',
#  'DESTR/DAMAG/VAND',
#  'DIS CONDUCT',
#  'DISOBEY BIKE CODE',
#  'DISOBEY LIGHT (BIKE)',
#  'DISOBEY STOP',
#  'DISOBEY TRAFFIC (BIKE)',
#  'DISORDERLY',
#  'DISORDERLY CONDUCT',
#  'DISORDERLY CONDUCT-ALL',
#  'DISORDERLY CONDUCT-ALL OTHER',
#  'DISORDERLY SUBJECT',
#  'DISORDERLY/PANDELING',
#  'DISPOSAL ON PUBLIC WAYS',
#  'DOEMSTIC VIOLENCE',
#  'DOGS RUNNING AT LARGE',
#  'DOMESTIC',
#  'DOMESTIC - UNLAWFUL RESTRAINT',
#  'DOMESTIC BATTERY',
#  'DOMESTIC BATTERY/AGG ASSAULT',
#  'DOMESTIC BATTERY/UNLAWFUL',
#  'DOMESTIC DISPUTE',
#  'DOMESTIC DISPUTE - VERBAL ONLY',
#  'DOMESTIC OFFENSE',
#  'DOMESTIC VIOLENCE',
#  'DOMESTIC-INTERFERENCE WITH REPORT',
#  'DOMESTICE VIOLENCE',
#  'DRIVING UNDER INFLUENCE-',
#  'DRIVING UNDER INFLUENCE-DRUGS',
#  'DRIVING UNDER SUSPENDED LICENSE',
#  'DRIVING UNDER THE INFL-',
#  'DRIVING UNDER THE INFL-ALCOHOL',
#  'DRIVING UNDER THE INFLUENCE',
#  'DRUG',
#  'DRUG EQUIPMENT-POSSESSION',
#  'DRUG PARAPHERNALIA-SALE/DELIVERY',
#  'DRUGS',
#  'DRUGS - ILLEGAL TRANSPORTATION OF',
#  'DRUGS/LIQUOR',
#  'DRUGS; COUNTERFEIT MONEY',
#  'DUI',
#  'DUI - ALCOHOL',
#  'DUI - DRUGS',
#  'EAVESDROPPING',
#  'ELECTRICAL FIRE',
#  'ELECTRONIC HARASSMENT',
#  'ENDANG CHILD',
#  'ENDANG LIFE/HEALTH OF CHILD',
#  'EOD CALLOUT',
#  'EOD; ASSIST OTHER',
#  'EXCITED DELIRIUM',
#  'EXPIRED REGISTRATION',
#  'EXTORTION',
#  'FALSE FIRE ALARM',
#  'FALSE ID-POSS (MISC)',
#  'FALSE PERSONATION OF PEACE OFFICER',
#  'FALSE POLICE REPORT',
#  'FELONY - ARREST',
#  'FIGHT',
#  'FIGHT/DISORDERLY',
#  'FIGHTING',
#  'FIREWORKS',
#  'FLEEING/ELUDING',
#  'FONDLING',
#  'FORCIBLE SEX OFFENSE',
#  'FORGERY',
#  'FORGERY/CREDIT CARD FRAUD',
#  'FRAUD - DECEPTION',
#  'FRAUD-CREDIT CARD',
#  'FRAUD-DECEPTION',
#  'FRAUD/DECEPTION',
#  'FUGITIVE FROM JUSTICE',
#  'FURNISHING ALCOHOL TO MINOR',
#  'HARASS BY TX',
#  'HARASSMENT',
#  'HARASSMENT BY ELECTRONIC',
#  'HARASSMENT BY ELECTRONIC COMM',
#  'HARASSMENT BY ELECTRONIC COMMUNICAT',
#  'HARASSMENT BY TELEPHONE',
#  'HARASSMENT BY TX',
#  'HARBOURING A RUNAWAY',
#  'HARRASMENT BY ELECTRONIC',
#  'HARRASSMENT',
#  'HAZING',
#  'HAZING - FRAT/SORORITY',
#  'HEROIN OVERDOSE',
#  'HINDERING POLICE OFFCR',
#  'HIT AND RUN',
#  'HOME INVASION',
#  'HYPODERMIC NEEDLE/SYRINGE-',
#  'HYPODERMIC NEEDLE/SYRINGE-POSS/SALE',
#  'IDENTITY THEFT',
#  'ILLEGAL TRANSPORTATION OF LIQUOR',
#  'IMPOUNDED VEHICLE',
#  'IMPROPER LANE USAGE',
#  'IMPROPER LANE USAGE-ONE-WAY ST',
#  'IMPROPER USE OF SIGNAL',
#  'INDECENT EXPOSURE',
#  'INTIMIDATION',
#  'K9 ASSIST',
#  'K9 ASSIST CCSO',
#  'K9 ASSIST CPD',
#  'LARCENY',
#  'LEAVING SCENE PROPERTY DAMAGE',
#  'LEAVING THE SCENE OF AN ACCIDENT',
#  'LIQOUR',
#  'LIQUOR',
#  'LIQUOR - ADULT RESPONSIBILITY/UNDERAGE',
#  'LIQUOR - CARRYING IN PUBLIC PLACE',
#  'LIQUOR - ILLEGAL TRANSPORTATION',
#  'LIQUOR - OPEN ALCOHOL',
#  'LIQUOR - PUBLIC POSSESSION',
#  'LIQUOR - PUBLIC PROPERTY',
#  'LIQUOR - UNDERAGE',
#  'LIQUOR - UNDERAGE CONSUMPTION',
#  'LIQUOR-ILLEGAL CONSUMPTION',
#  'LIQUOR-ILLEGAL CONSUMPTION BY',
#  'LIQUOR-ILLEGAL CONSUMPTION BY MINOR',
#  'LIQUOR-ILLEGAL POSS. BY MINOR',
#  'LIQUOR-OPEN CONTAINER/PUBLIC PROP.',
#  'LIQUOR-PUBLIC PROP',
#  'LIQUOR-PURCH/POSS/CONSUMP BY',
#  'LIQUOR-PURCH/POSS/CONSUMP BY MINORS',
#  'LIQUOR-SALE TO MINORS,DRUNKS,ETC',
#  'LIQUOR-SALE TO MINORS/DRUNKARDS',
#  'LIQUOR-UNDERAGE',
#  'LIQUOR-UNDERAGE/PUBLIC POSSESSION',
#  'LIQUOR-UNDERAGE; DISORDERLY CONDUCT',
#  'LIQUOR-UNDERAGE; FIGHT',
#  'LIQUOR/THEFT',
#  'LOST ARTICLES',
#  'LOUD NOISE',
#  'MANUFACTURE CONTROLLED SUB',
#  'MENTAL CASE-TRANSPORTATION',
#  'METRO',
#  'METRO ACTIVATION',
#  'METRO/ASSIST OTHER',
#  'MINOR IN POSSESSION',
#  'MINOR PRESENT',
#  'MIP',
#  'MIP ALCOHOL/LIQUOR',
#  'MIP; POSS LIQUOR-PUBLIC PROP',
#  'MISSING PERSON',
#  'MISSING PERSON ADULT/FEMALE',
#  'MISSING PERSON ADULT/MALE',
#  'MOB ACTION',
#  'MOTOR VEHICLE THEFT',
#  'MURDER-FIRST DEGREE',
#  'MURDER/NON-NEG. MANSSL.',
#  'MUTUAL COMBATANTS',
#  'NARCOTICS UNIT',
#  'NO DRIVERS LICENSE',
#  'NO DRIVERS LICENSE; OPERATING',
#  'NO REAR REGISTRATION LIGHT',
#  'NOISE',
#  'NOISE & VIBRATIONS',
#  'NOISE PROHIBITED',
#  'NOISE PROHIBITION',
#  'NOISE VIOLATION',
#  'NON-FORCIBLE SEX OFFENSE',
#  'OBSTRUCTIN JUSTICE',
#  'OBSTRUCTING IDENTIFICATION',
#  'OBSTRUCTING JUSTICE',
#  'OFFICIAL MISCONDUCT',
#  'OPERATE UNINSURED MOTOR VEHICLE',
#  'OTHER CRIMINAL OFFENSES',
#  'OTHER EQUIPMENT VIOLATIONS',
#  'OTHER INVESTIGATION QUASI-CRIMINAL',
#  'OTHER MISC/CPD ORDINANCE',
#  'OTHER TROUBLE/INFO RPT',
#  'PANHANDLE',
#  'PEDESTRIAN STOPS',
#  'PEEPING TOM',
#  'PEEPING TOM (DISORDERLY CONDUCT)',
#  'PIMPING - PROMOTING PROSTITUTION',
#  'POSS ALCOHOL PUB PROP /',
#  'POSS ALCOHOL PUB PROP / PARKING',
#  'POSS ALCOHOL/LIQ PUBLIC PROP/PARKIN',
#  'POSS DRUG PARAPHERNALIA',
#  'POSS LIQUOR-PUBLIC PROP',
#  'POSS OF CANNABIS',
#  'POSS OF CANNABIS UNDER 10 GM &',
#  'POSS OF DRUG PARAPHENALIA',
#  'POSS OF DRUG PARAPHERNALIA -ORD',
#  'POSSESSION OF CANNABIS',
#  'POSSESSION OF DRUG PARAPHERNALIA',
#  'POSSESSION OF STOLEN FIREARM',
#  'POSSESSION OF STOLEN PROP',
#  'POSSESSION STOLEN PROPERTY',
#  'POSSESSION W/INTENT TO DELIVER',
#  'PREDATORY CRIM SEX ASSAULT OF CHILD',
#  'PUBLIC DRUNKENNEESS & TRESPASS',
#  'PUBLIC INDECENCY',
#  'PUBLIC INTOXICATION',
#  'PUBLIC POSSESSION',
#  'PUBLIC POSSESSION OF ALCOHOL',
#  'PUBLIC URINATION',
#  'PUBLIC URINATION (C)',
#  'PUBLIC URINATION-CITY',
#  'PURSE SNATCHING',
#  'RAPE',
#  'RECKLESS CONDUCT',
#  'RECKLESS DRIVING',
#  'RECOVERED PROPERTY ONLY',
#  'RECOVERED STOLEN VEHICLE',
#  'RESIST OBS OFC',
#  'RESIST OFFICER',
#  'RESIST/OBS CORRECT/POLICE/FIRE',
#  'RESIST/OBSTRUCT',
#  'RESIST/OBSTRUCT OFFICER',
#  'RESIST/OBSTRUCT/DISARM AN',
#  'RESIST/OBSTRUCT/DISARM AN OFFICER',
#  'RESIST/OBSTRUCT/DISARM OFFICER',
#  'RESISTING',
#  'RESISTING ARREST',
#  'RESISTING/OBSTR OFFICER',
#  'RESISTING/OBSTR. OFFICER',
#  'RESISTING/OBSTRUCTING',
#  'RETAIL THEFT',
#  'REVENGE PORNOGRAPHY',
#  'RIDING BIKE ON ROAD',
#  'ROBBERY',
#  'ROBBERY-AGGRAVATED',
#  'ROBBERY-ARMED',
#  'RUNAWAY - MINOR REQUIRE AUTH',
#  'RUNAWAY - MINOR REQUIRE AUTH INTER',
#  'SAFEKEEPING',
#  'SALE OF TOBACCO',
#  'SALES OF TOBACCO',
#  'SALES OF TOBACCO TO MINORS',
#  'SEARCH WARRANT',
#  'SEARCH WARRANT ASSIST',
#  'SEARCH WARRANT SERVICE',
#  'SEX HARASSMENT',
#  'SEX OFFENDER REGISTRATION',
#  'SEX OFFENDER-FAIL TO REGISTER',
#  'SEX OFFENSE',
#  'SEX OFFENSE, FORCIBLE',
#  'SEXUAL ABUSE-AGGRAVATED',
#  'SEXUAL ABUSE-CRIMINAL',
#  'SEXUAL ASSAULT',
#  'SEXUAL ASSAULT-AGG CRIMINAL',
#  'SEXUAL HARASSMENT',
#  'SEXUAL-ASSAULT-CRIMINAL',
#  'SIMPLE ASSAULT',
#  'SIMPLE BATTERY',
#  'SPECIFIC NOISE PROHIBITED',
#  'SPEEDING (RADAR)',
#  'SRO - YAC REFERRAL',
#  'STALKING',
#  'STALKING BY ELECTRONIC COMMUNICATIO',
#  'STALKING-AGGRAVATED',
#  'STALKING/CYBERSTALKING',
#  'STALKING/ELECTRONIC HARRASMENT',
#  'STATUTORY RAPE',
#  'STOLEN PROP RECOVERED',
#  'SUICIDAL SUBJECT',
#  'SUICIDE ATTEMPT/DRUGS',
#  'SUSPENDED LICENSE/WARRANT',
#  'SUSPICIOUS ACTIVITIES',
#  'TELEPHONE THREAT',
#  'TELEPHONE THREATS',
#  'TERRORISM-MAKE FALSE TERROR',
#  'TERRORIST THREATS',
#  'THEFT',
#  'THEFT $500 AND UNDER',
#  'THEFT BY LESSEE',
#  'THEFT FROM BUILDING',
#  'THEFT FROM COIN-OP',
#  'THEFT FROM COIN-OP MACHINE/DEVICE',
#  'THEFT FROM MOTOR VEHICLE',
#  'THEFT GENERALLY',
#  'THEFT OF LOST/MISLAID PROP',
#  'THEFT OF LOST/MISLAID PROPERTY',
#  'THEFT OF MOTOR VEH PARTS &',
#  'THEFT OF MOTOR VEH PARTS & ACCESS',
#  'THEFT OF SERVICES',
#  'THEFT OVER',
#  'THEFT OVER $500',
#  'THEFT UNDER',
#  'THEFT-CITY',
#  'THEFT-IDENTITY',
#  'THEFT-LABOR OR SERVICES',
#  'THEFT-LOST/MISLAID PROPERTY',
#  'THEFT-MOTOR VEHICLE',
#  'THEFT-RETAIL',
#  'THEFT-RETAIL-CITY',
#  'THEFT/DECCEPTION',
#  'THREATS',
#  'THROW DANG MATERIAL',
#  'THROW DANG MATERIALS',
#  'THROW DANGEROUS MATERIAL',
#  'THROW DANGEROUS MATERIALS',
#  'THROWING DANGEROUS',
#  'THROWING DANGEROUS MATERIALS',
#  'THROWING ITEMS',
#  'TRAFFIC',
#  'TRAFFIC CITATION/VOP',
#  'TRAFFIC CITATIONS',
#  'TRAFFIC OFFENSE',
#  'TRAFFIC SIGN VIOLATION',
#  'TRAFFIC STOP',
#  'TRANSIENT MERCHANT/LICENSE REQUIRED',
#  'TRANSPORTING ALCOHOL/LIQ IN VEHICLE',
#  'TREPASS',
#  'TRESPASS',
#  'TRESPASS LAND',
#  'TRESPASS NOTICE',
#  'TRESPASS TO HOME',
#  'TRESPASS TO LAND/REAL PROPERTY',
#  'TRESPASS TO PROPERTY',
#  'TRESPASS TO RESIDENCE',
#  'TRESPASS-RESIDENCE',
#  'TRESPASS-STATE SUPPORTED',
#  'TRESPASS-STATE SUPPORTED LAND',
#  'TRESPASS-VEHICLE',
#  'TRESPASS/RESISTING ARREST',
#  'TRESPASSIN',
#  'TRESPASSING',
#  'UNAUTHORIZED ENTRY',
#  'UNAUTHORIZED VIDEOTAPING/LIVE VIDEO',
#  'UNLAW USE ID',
#  'UNLAWFUL POSS FIREARM & AMMUNITION',
#  'UNLAWFUL POSS/USE WEAPON BY',
#  'UNLAWFUL POSS/USE WEAPON BY FELON',
#  'UNLAWFUL POSSESSION OF ID',
#  'UNLAWFUL RESTRAINT',
#  'UNLAWFUL RESTRAINT-AGGRAVATED',
#  'UNLAWFUL TRESPASS',
#  'UNLAWFUL USE ID',
#  'UNLAWFUL USE OF I.D.',
#  'UNLAWFUL USE OF ID',
#  'UNLAWFUL USE OF WEAPONS',
#  'UPD ACCIDENT (FATAL)',
#  'USE OF FORCE BY OFFICER',
#  'VANDALISM-INSTITUTIONAL',
#  'VEHICULAR NOISE',
#  'VERBAL DISPUTE',
#  'VERBAL DOMESTIC',
#  'VIOL BAIL BOND',
#  'VIOLATION OF ORDER OF PROTECTION',
#  'VIOLATION OF ORDER PROTECTION',
#  'VIOLATION ORDER PROTECTION',
#  'VISITATION INTERFERENCE',
#  'VOOP',
#  'WARRANT',
#  'WARRANT ARREST',
#  'WARRANT ARREST/TRAFFIC CITATIONS',
#  'WARRANT-IN STATE',
#  'WARRANT-OUT OF STATE',
#  'WEAPON',
#  'ZERO TOLERANCE'}

# %%
#Convert the set of crime types into a list of dictionary
crimeTypeListOfDicts = []
crimeTypeStartIndex = 300
for type in crimeTypeList:
    crimeTypeDict = {}
    crimeTypeDict["crimeTypeID"] = crimeTypeStartIndex
    crimeTypeDict["type"] = type
    crimeTypeStartIndex += 1
    crimeTypeListOfDicts.append(crimeTypeDict)
crimeTypeListOfDicts
# Out:
# [{'crimeTypeID': 300, 'type': 'ASSIST UPD W/DOMESTIC'},
#  {'crimeTypeID': 301, 'type': 'SEARCH WARRANT SERVICE'},
#  {'crimeTypeID': 302, 'type': 'ASSAULT'},
#  {'crimeTypeID': 303, 'type': 'FRAUD - DECEPTION'},
#  {'crimeTypeID': 304, 'type': 'MENTAL CASE-TRANSPORTATION'},
#  {'crimeTypeID': 305, 'type': 'DOMESTIC DISPUTE - VERBAL ONLY'},
#  {'crimeTypeID': 306, 'type': 'LIQUOR-ILLEGAL CONSUMPTION'},
#  {'crimeTypeID': 307, 'type': 'BURGLARY MOTOR VEH PARTS & ACCESS'},
#  {'crimeTypeID': 308, 'type': 'TRAFFIC STOP'},
#  {'crimeTypeID': 309, 'type': 'HARASSMENT BY ELECTRONIC COMM'},
#  {'crimeTypeID': 310, 'type': 'ALCOHOL'},
#  {'crimeTypeID': 311, 'type': 'DOMESTICE VIOLENCE'},
#  {'crimeTypeID': 312, 'type': 'DISORDERLY CONDUCT-ALL OTHER'},
#  {'crimeTypeID': 313, 'type': 'CRUELTY TO ANIMALS'},
#  {'crimeTypeID': 314, 'type': 'RETAIL THEFT'},
#  {'crimeTypeID': 315, 'type': 'RESIST/OBSTRUCT/DISARM OFFICER'},
#  {'crimeTypeID': 316, 'type': 'OTHER EQUIPMENT VIOLATIONS'},
#  {'crimeTypeID': 317, 'type': 'DRUGS - ILLEGAL TRANSPORTATION OF'},
#  {'crimeTypeID': 318, 'type': 'TRESPASS TO HOME'},
#  {'crimeTypeID': 319, 'type': 'DECPTIVE PRACTICE'},
#  {'crimeTypeID': 320, 'type': 'THEFT-LOST/MISLAID PROPERTY'},
#  {'crimeTypeID': 321, 'type': 'UNLAWFUL TRESPASS'},
#  {'crimeTypeID': 322, 'type': 'SALE OF TOBACCO'},
#  {'crimeTypeID': 323, 'type': 'EXPIRED REGISTRATION'},
#  {'crimeTypeID': 324, 'type': 'VISITATION INTERFERENCE'},
#  {'crimeTypeID': 325, 'type': 'ASSIST UPD WITH K-9'},
#  {'crimeTypeID': 326, 'type': 'ACCIDENT INVOLVING OTHER CITY PROP'},
#  {'crimeTypeID': 327, 'type': 'ASSIST CPD W/ROBBERY'},
#  {'crimeTypeID': 328, 'type': 'FALSE ID-POSS (MISC)'},
#  {'crimeTypeID': 329, 'type': 'UNLAWFUL USE OF WEAPONS'},
#  {'crimeTypeID': 330, 'type': 'BATTERY-DOMESTIC & LARCENY'},
#  {'crimeTypeID': 331, 'type': 'THEFT OF LOST/MISLAID PROP'},
#  {'crimeTypeID': 332, 'type': 'RESIST/OBSTRUCT'},
#  {'crimeTypeID': 333, 'type': 'PUBLIC DRUNKENNEESS & TRESPASS'},
#  {'crimeTypeID': 334, 'type': 'DATING VIOLENCE'},
#  {'crimeTypeID': 335, 'type': 'ASSIST CCSO W/TRAFFIC STOP'},
#  {'crimeTypeID': 336, 'type': 'ALCOHOL/LIQUOR LICENSE REQUIRED'},
#  {'crimeTypeID': 337, 'type': 'TELEPHONE THREAT'},
#  {'crimeTypeID': 338, 'type': 'NO DRIVERS LICENSE; OPERATING'},
#  {'crimeTypeID': 339, 'type': 'CANNABIS-DELIVERY 30GM & UNDER'},
#  {'crimeTypeID': 340, 'type': 'FONDLING'},
#  {'crimeTypeID': 341, 'type': 'CRISIS INTERVEN. - OTHER'},
#  {'crimeTypeID': 342, 'type': 'ACCIDENT HIT AND RUN'},
#  {'crimeTypeID': 343, 'type': 'THEFT-LABOR OR SERVICES'},
#  {'crimeTypeID': 344, 'type': 'HAZING - FRAT/SORORITY'},
#  {'crimeTypeID': 345, 'type': 'TELEPHONE THREATS'},
#  {'crimeTypeID': 346, 'type': 'BURGLARY FROM MOTOR VEHICLE'},
#  {'crimeTypeID': 347, 'type': 'CREDIT CARD FRAUD'},
#  {'crimeTypeID': 348, 'type': 'RIDING BIKE ON ROAD'},
#  {'crimeTypeID': 349, 'type': 'TRESPASS TO RESIDENCE'},
#  {'crimeTypeID': 350, 'type': 'COUNTED STALKING UNDER C16-0886'},
#  {'crimeTypeID': 351, 'type': 'HIT AND RUN'},
#  {'crimeTypeID': 352, 'type': 'LIQUOR-PURCH/POSS/CONSUMP BY'},
#  {'crimeTypeID': 353, 'type': 'MIP ALCOHOL/LIQUOR'},
#  {'crimeTypeID': 354, 'type': 'FURNISHING ALCOHOL TO MINOR'},
#  {'crimeTypeID': 355, 'type': 'CONTROLLED SUBSTANCE-MANUF-INTENT'},
#  {'crimeTypeID': 356, 'type': 'DOMESTIC BATTERY'},
#  {'crimeTypeID': 357, 'type': 'ASSAULT-AGGRAVATED'},
#  {'crimeTypeID': 358, 'type': 'ASSIST/STABBING'},
#  {'crimeTypeID': 359, 'type': 'TRAFFIC'},
#  {'crimeTypeID': 360, 'type': 'ASSIST W/K9 SWEEP'},
#  {'crimeTypeID': 361, 'type': 'TRANSPORTING ALCOHOL/LIQ IN VEHICLE'},
#  {'crimeTypeID': 362, 'type': 'VIOL BAIL BOND'},
#  {'crimeTypeID': 363, 'type': 'BURNING PROHIBITED'},
#  {'crimeTypeID': 364, 'type': 'POSSESSION OF DRUG PARAPHERNALIA'},
#  {'crimeTypeID': 365, 'type': 'FORCIBLE SEX OFFENSE'},
#  {'crimeTypeID': 366, 'type': 'FALSE FIRE ALARM'},
#  {'crimeTypeID': 367, 'type': 'WARRANT ARREST'},
#  {'crimeTypeID': 368, 'type': 'ASSIST CPD W/THEFT'},
#  {'crimeTypeID': 369, 'type': 'UNLAWFUL POSSESSION OF ID'},
#  {'crimeTypeID': 370, 'type': 'HARASSMENT BY ELECTRONIC'},
#  {'crimeTypeID': 371, 'type': 'VOOP'},
#  {'crimeTypeID': 372, 'type': 'UNLAWFUL RESTRAINT'},
#  {'crimeTypeID': 373, 'type': 'STALKING-AGGRAVATED'},
#  {'crimeTypeID': 374, 'type': 'FRAUD-CREDIT CARD'},
#  {'crimeTypeID': 375, 'type': 'DISOBEY LIGHT (BIKE)'},
#  {'crimeTypeID': 376, 'type': 'ELECTRONIC HARASSMENT'},
#  {'crimeTypeID': 377, 'type': 'LIQUOR/THEFT'},
#  {'crimeTypeID': 378, 'type': 'BOMB THREAT'},
#  {'crimeTypeID': 379, 'type': 'FORGERY'},
#  {'crimeTypeID': 380, 'type': 'THEFT OF LOST/MISLAID PROPERTY'},
#  {'crimeTypeID': 381, 'type': 'MURDER-FIRST DEGREE'},
#  {'crimeTypeID': 382, 'type': 'SIMPLE ASSAULT'},
#  {'crimeTypeID': 383, 'type': 'CANNABIS-DELIVERY OVER 30GM'},
#  {'crimeTypeID': 384, 'type': 'CONTROLLED SUBSTANCE-'},
#  {'crimeTypeID': 385, 'type': 'AGG AGASSULT'},
#  {'crimeTypeID': 386, 'type': 'DELIVERY CONTROLLED SUB'},
#  {'crimeTypeID': 387, 'type': 'THEFT-RETAIL'},
#  {'crimeTypeID': 388, 'type': 'SIMPLE BATTERY'},
#  {'crimeTypeID': 389, 'type': 'NOISE PROHIBITION'},
#  {'crimeTypeID': 390, 'type': 'ASSIST CPD WITH BATTERY'},
#  {'crimeTypeID': 391, 'type': 'CONTROLLED SUBSTANCE-POSSESSION'},
#  {'crimeTypeID': 392, 'type': 'VERBAL DOMESTIC'},
#  {'crimeTypeID': 393, 'type': 'DRIVING UNDER SUSPENDED LICENSE'},
#  {'crimeTypeID': 394, 'type': 'SUSPENDED LICENSE/WARRANT'},
#  {'crimeTypeID': 395, 'type': 'LOUD NOISE'},
#  {'crimeTypeID': 396, 'type': 'HARRASMENT BY ELECTRONIC'},
#  {'crimeTypeID': 397, 'type': 'DISORDERLY SUBJECT'},
#  {'crimeTypeID': 398, 'type': 'ASSIST/ACCIDENT UPD'},
#  {'crimeTypeID': 399, 'type': 'LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 400, 'type': 'CANNABIS-POSSESSION OVER'},
#  {'crimeTypeID': 401, 'type': 'THEFT/DECCEPTION'},
#  {'crimeTypeID': 402, 'type': 'ASSIST/BUILDING CHECK'},
#  {'crimeTypeID': 403, 'type': 'DOMESTIC BATTERY/AGG ASSAULT'},
#  {'crimeTypeID': 404, 'type': 'POSS LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 405, 'type': 'LIQUOR - UNDERAGE'},
#  {'crimeTypeID': 406, 'type': 'ALLOWING A NUISANCE PARTY'},
#  {'crimeTypeID': 407, 'type': 'CRIMINAL DAMAGE GOVT'},
#  {'crimeTypeID': 408, 'type': 'THROW DANGEROUS MATERIALS'},
#  {'crimeTypeID': 409, 'type': 'MIP'},
#  {'crimeTypeID': 410, 'type': 'VIOLATION OF ORDER PROTECTION'},
#  {'crimeTypeID': 411, 'type': 'TRESPASS LAND'},
#  {'crimeTypeID': 412, 'type': 'POSS OF DRUG PARAPHERNALIA -ORD'},
#  {'crimeTypeID': 413, 'type': 'DOMESTIC BATTERY/UNLAWFUL'},
#  {'crimeTypeID': 414, 'type': 'RESIST OFFICER'},
#  {'crimeTypeID': 415, 'type': 'ACCIDENT INVOLVING PEDESTRIAN'},
#  {'crimeTypeID': 416, 'type': 'AGGRAVATGED ASSAULT'},
#  {'crimeTypeID': 417, 'type': 'POSS OF CANNABIS'},
#  {'crimeTypeID': 418, 'type': 'DUI - DRUGS'},
#  {'crimeTypeID': 419, 'type': 'ENDANG LIFE/HEALTH OF CHILD'},
#  {'crimeTypeID': 420, 'type': 'DRUGS'},
#  {'crimeTypeID': 421, 'type': 'SALES OF TOBACCO'},
#  {'crimeTypeID': 422, 'type': 'ASST CPD/ARMED SUBJECT'},
#  {'crimeTypeID': 423, 'type': 'HAZING'},
#  {'crimeTypeID': 424, 'type': 'LIQUOR-UNDERAGE; DISORDERLY CONDUCT'},
#  {'crimeTypeID': 425, 'type': 'CONTROLLED SUBSTANCE-POSS'},
#  {'crimeTypeID': 426, 'type': 'SPECIFIC NOISE PROHIBITED'},
#  {'crimeTypeID': 427, 'type': 'ALCOHO/LIQ MINOR PRESENT/TEEN EVENT'},
#  {'crimeTypeID': 428, 'type': 'ASSIST UPD/SHOOTING'},
#  {'crimeTypeID': 429, 'type': 'ASSIST DOMESTIC'},
#  {'crimeTypeID': 430, 'type': 'TRESPASS TO LAND/REAL PROPERTY'},
#  {'crimeTypeID': 431, 'type': 'LIQUOR - PUBLIC PROPERTY'},
#  {'crimeTypeID': 432, 'type': 'SEXUAL ABUSE-AGGRAVATED'},
#  {'crimeTypeID': 433, 'type': 'PUBLIC URINATION'},
#  {'crimeTypeID': 434, 'type': 'RUNAWAY - MINOR REQUIRE AUTH'},
#  {'crimeTypeID': 435, 'type': 'DECEPTIVE PRACTICES'},
#  {'crimeTypeID': 436, 'type': 'UNLAWFUL POSS FIREARM & AMMUNITION'},
#  {'crimeTypeID': 437, 'type': 'COMPUTER FRAUD'},
#  {'crimeTypeID': 438, 'type': 'PURSE SNATCHING'},
#  {'crimeTypeID': 439, 'type': 'THEFT-RETAIL-CITY'},
#  {'crimeTypeID': 440, 'type': 'IMPOUNDED VEHICLE'},
#  {'crimeTypeID': 441, 'type': 'AGG FLEE/ATTEMPT ELUDE OFFICER'},
#  {'crimeTypeID': 442, 'type': 'ASSIST CPD/ROBBERY'},
#  {'crimeTypeID': 443, 'type': 'UNAUTHORIZED VIDEOTAPING/LIVE VIDEO'},
#  {'crimeTypeID': 444, 'type': 'HYPODERMIC NEEDLE/SYRINGE-'},
#  {'crimeTypeID': 445, 'type': 'BURGLARY RESIDENTIAL'},
#  {'crimeTypeID': 446, 'type': 'ASSIST/BURGLARY'},
#  {'crimeTypeID': 447, 'type': 'IMPROPER LANE USAGE-ONE-WAY ST'},
#  {'crimeTypeID': 448, 'type': 'BRINGING CONTRABAND INTO PENAL INST'},
#  {'crimeTypeID': 449, 'type': 'ASSIST STATE/ACCIDENT'},
#  {'crimeTypeID': 450, 'type': 'MUTUAL COMBATANTS'},
#  {'crimeTypeID': 451, 'type': 'DEPETIVE PRACTICE/COUNTERFIT'},
#  {'crimeTypeID': 452, 'type': 'RESISTING'},
#  {'crimeTypeID': 453, 'type': 'DRIVING UNDER THE INFLUENCE'},
#  {'crimeTypeID': 454, 'type': 'IMPROPER USE OF SIGNAL'},
#  {'crimeTypeID': 455, 'type': 'IDENTITY THEFT'},
#  {'crimeTypeID': 456, 'type': 'BIKE VIOLATIONS'},
#  {'crimeTypeID': 457, 'type': 'TRESPASS-RESIDENCE'},
#  {'crimeTypeID': 458, 'type': 'MOTOR VEHICLE THEFT'},
#  {'crimeTypeID': 459, 'type': 'FRAUD-DECEPTION'},
#  {'crimeTypeID': 460, 'type': 'SUSPICIOUS ACTIVITIES'},
#  {'crimeTypeID': 461, 'type': 'ALCOHOL/LIQUOR BASSET LICENSE REQ'},
#  {'crimeTypeID': 462, 'type': 'SEXUAL ASSAULT-AGG CRIMINAL'},
#  {'crimeTypeID': 463, 'type': 'DOGS RUNNING AT LARGE'},
#  {'crimeTypeID': 464, 'type': 'DUI'},
#  {'crimeTypeID': 465, 'type': 'BATTERY'},
#  {'crimeTypeID': 466, 'type': 'EAVESDROPPING'},
#  {'crimeTypeID': 467, 'type': 'TREPASS'},
#  {'crimeTypeID': 468, 'type': 'POSSESSION OF STOLEN FIREARM'},
#  {'crimeTypeID': 469, 'type': 'STALKING/ELECTRONIC HARRASMENT'},
#  {'crimeTypeID': 470, 'type': 'ENDANG CHILD'},
#  {'crimeTypeID': 471, 'type': 'BIKE VIOLATION'},
#  {'crimeTypeID': 472, 'type': 'VERBAL DISPUTE'},
#  {'crimeTypeID': 473, 'type': 'BREATH ALCOHOL OVER LIMIT'},
#  {'crimeTypeID': 474, 'type': 'DEL/MANUF CANNABIS UNDER 10 G -MISD'},
#  {'crimeTypeID': 475, 'type': 'CRIMINAL DEFACEMENT OF'},
#  {'crimeTypeID': 476, 'type': 'ASSIST K-9'},
#  {'crimeTypeID': 477, 'type': 'OTHER INVESTIGATION QUASI-CRIMINAL'},
#  {'crimeTypeID': 478, 'type': 'POSS OF DRUG PARAPHENALIA'},
#  {'crimeTypeID': 479, 'type': 'CRIMINAL DAMAGE TO PROPERTY'},
#  {'crimeTypeID': 480, 'type': 'FUGITIVE FROM JUSTICE'},
#  {'crimeTypeID': 481, 'type': 'ASSIST/K9 SEARCH'},
#  {'crimeTypeID': 482, 'type': 'DISORDERLY/PANDELING'},
#  {'crimeTypeID': 483, 'type': 'ASSIST W/SEARCH WARRANT'},
#  {'crimeTypeID': 484, 'type': 'THEFT OF SERVICES'},
#  {'crimeTypeID': 485, 'type': 'ASSIST/K-9'},
#  {'crimeTypeID': 486, 'type': 'UNLAWFUL POSS/USE WEAPON BY'},
#  {'crimeTypeID': 487, 'type': 'ASSIST/DISORDERLY SUBJ'},
#  {'crimeTypeID': 488, 'type': 'LIQUOR'},
#  {'crimeTypeID': 489, 'type': 'ASSIST UPD W/ROBBERY'},
#  {'crimeTypeID': 490, 'type': 'ASSIST UPD'},
#  {'crimeTypeID': 491, 'type': 'ASSIST CCSO W/K-9'},
#  {'crimeTypeID': 492, 'type': 'UNLAWFUL RESTRAINT-AGGRAVATED'},
#  {'crimeTypeID': 493, 'type': 'SEX OFFENSE'},
#  {'crimeTypeID': 494, 'type': 'LIQUOR - UNDERAGE CONSUMPTION'},
#  {'crimeTypeID': 495, 'type': 'HARBOURING A RUNAWAY'},
#  {'crimeTypeID': 496, 'type': 'ASSIST CPD W/BANK ROBBERY'},
#  {'crimeTypeID': 497, 'type': 'PANHANDLE'},
#  {'crimeTypeID': 498, 'type': 'TRESPASS'},
#  {'crimeTypeID': 499, 'type': 'BEGGERS PROHIBITED'},
#  {'crimeTypeID': 500, 'type': 'UNAUTHORIZED ENTRY'},
#  {'crimeTypeID': 501, 'type': 'ASSIST UPD W/K-9'},
#  {'crimeTypeID': 502, 'type': 'THEFT OVER'},
#  {'crimeTypeID': 503, 'type': 'ASSIST/CHECK WELFARE'},
#  {'crimeTypeID': 504, 'type': 'POSS ALCOHOL/LIQ PUBLIC PROP/PARKIN'},
#  {'crimeTypeID': 505, 'type': 'TRESPASS NOTICE'},
#  {'crimeTypeID': 506, 'type': 'THEFT-MOTOR VEHICLE'},
#  {'crimeTypeID': 507, 'type': 'NO DRIVERS LICENSE'},
#  {'crimeTypeID': 508, 'type': 'FIGHT/DISORDERLY'},
#  {'crimeTypeID': 509, 'type': 'ASSIST CCSO W/TRANSLATION'},
#  {'crimeTypeID': 510, 'type': 'POSSESSION OF CANNABIS'},
#  {'crimeTypeID': 511, 'type': 'DRIVING UNDER INFLUENCE-DRUGS'},
#  {'crimeTypeID': 512, 'type': 'IMPROPER LANE USAGE'},
#  {'crimeTypeID': 513, 'type': 'ASSIST OTHER POLICE DEPT'},
#  {'crimeTypeID': 514, 'type': 'FLEEING/ELUDING'},
#  {'crimeTypeID': 515, 'type': 'NOISE VIOLATION'},
#  {'crimeTypeID': 516, 'type': 'THREATS'},
#  {'crimeTypeID': 517, 'type': 'CANNABIS-POSSESSION OVER 30GM'},
#  {'crimeTypeID': 518, 'type': 'WARRANT'},
#  {'crimeTypeID': 519, 'type': 'LIQUOR-SALE TO MINORS/DRUNKARDS'},
#  {'crimeTypeID': 520, 'type': 'CARRYING OUT OF PREMISE'},
#  {'crimeTypeID': 521, 'type': 'DECEPTIVE PRACTICES/HARASSMENT BY T'},
#  {'crimeTypeID': 522, 'type': 'ASSIST/SHOPLIFTER'},
#  {'crimeTypeID': 523, 'type': 'HARASSMENT BY ELECTRONIC COMMUNICAT'},
#  {'crimeTypeID': 524, 'type': 'VEHICULAR NOISE'},
#  {'crimeTypeID': 525, 'type': 'LIQUOR - ILLEGAL TRANSPORTATION'},
#  {'crimeTypeID': 526, 'type': 'FALSE POLICE REPORT'},
#  {'crimeTypeID': 527, 'type': 'PEEPING TOM (DISORDERLY CONDUCT)'},
#  {'crimeTypeID': 528, 'type': 'ASSIST CPD W/TRAFFIC STOP'},
#  {'crimeTypeID': 529, 'type': 'DOMESTIC'},
#  {'crimeTypeID': 530, 'type': 'ASSIST UPD W/DETAIN SUBJECT'},
#  {'crimeTypeID': 531, 'type': 'STOLEN PROP RECOVERED'},
#  {'crimeTypeID': 532, 'type': 'DECPT PRACTICE'},
#  {'crimeTypeID': 533, 'type': 'THEFT UNDER'},
#  {'crimeTypeID': 534, 'type': 'OTHER CRIMINAL OFFENSES'},
#  {'crimeTypeID': 535, 'type': 'FIREWORKS'},
#  {'crimeTypeID': 536, 'type': 'ASSIST W/K-9'},
#  {'crimeTypeID': 537, 'type': 'TRESPASS-STATE SUPPORTED LAND'},
#  {'crimeTypeID': 538, 'type': 'ASSIST CPD'},
#  {'crimeTypeID': 539, 'type': 'POSSESSION W/INTENT TO DELIVER'},
#  {'crimeTypeID': 540, 'type': 'BIKE ENFORCEMENT'},
#  {'crimeTypeID': 541, 'type': 'CANNABIS POSS 30 G AND UNDER - OLD'},
#  {'crimeTypeID': 542, 'type': 'CRIMINAL DEFACEMENT OF PROPERTY'},
#  {'crimeTypeID': 543, 'type': 'FELONY - ARREST'},
#  {'crimeTypeID': 544, 'type': 'CRIMINAL DAMAGE GOVT SUPPORT'},
#  {'crimeTypeID': 545, 'type': 'DECEPTIVE PRACTICE'},
#  {'crimeTypeID': 546, 'type': 'DESTR/DAMAG/VAND'},
#  {'crimeTypeID': 547, 'type': 'REVENGE PORNOGRAPHY'},
#  {'crimeTypeID': 548, 'type': 'THEFT FROM COIN-OP MACHINE/DEVICE'},
#  {'crimeTypeID': 549, 'type': 'DUI - ALCOHOL'},
#  {'crimeTypeID': 550, 'type': 'AGG BATTERY'},
#  {'crimeTypeID': 551, 'type': 'DOMESTIC - UNLAWFUL RESTRAINT'},
#  {'crimeTypeID': 552, 'type': 'LIQUOR - OPEN ALCOHOL'},
#  {'crimeTypeID': 553, 'type': 'RESIST/OBSTRUCT OFFICER'},
#  {'crimeTypeID': 554, 'type': 'INDECENT EXPOSURE'},
#  {'crimeTypeID': 555, 'type': 'USE OF FORCE BY OFFICER'},
#  {'crimeTypeID': 556, 'type': 'ATTEMPTED THEFT'},
#  {'crimeTypeID': 557, 'type': 'ALCOHOL/LIQ SALES INTOX SUBJ OR'},
#  {'crimeTypeID': 558, 'type': 'OTHER MISC/CPD ORDINANCE'},
#  {'crimeTypeID': 559, 'type': 'SEX OFFENDER-FAIL TO REGISTER'},
#  {'crimeTypeID': 560, 'type': 'DISORDERLY CONDUCT'},
#  {'crimeTypeID': 561, 'type': 'DOMESTIC-INTERFERENCE WITH REPORT'},
#  {'crimeTypeID': 562, 'type': 'DRIVING UNDER THE INFL-'},
#  {'crimeTypeID': 563, 'type': 'TRAFFIC CITATIONS'},
#  {'crimeTypeID': 564, 'type': 'THROWING ITEMS'},
#  {'crimeTypeID': 565, 'type': 'THROW DANG MATERIALS'},
#  {'crimeTypeID': 566, 'type': 'ASSIST/UNCOOPERATIVE SUBJ'},
#  {'crimeTypeID': 567, 'type': 'ASSIST/SEARCH SUBJ'},
#  {'crimeTypeID': 568, 'type': 'RECKLESS DRIVING'},
#  {'crimeTypeID': 569, 'type': 'LEAVING THE SCENE OF AN ACCIDENT'},
#  {'crimeTypeID': 570, 'type': 'CANNABIS POSS OVER 30 G - OLD'},
#  {'crimeTypeID': 571, 'type': 'THEFT OF MOTOR VEH PARTS &'},
#  {'crimeTypeID': 572, 'type': 'K9 ASSIST'},
#  {'crimeTypeID': 573, 'type': 'ASSIST/ARMED SUBJECT'},
#  {'crimeTypeID': 574, 'type': 'MINOR PRESENT'},
#  {'crimeTypeID': 575, 'type': 'BONFIRES PROHIBITED'},
#  {'crimeTypeID': 576, 'type': 'FALSE PERSONATION OF PEACE OFFICER'},
#  {'crimeTypeID': 577, 'type': 'PUBLIC INTOXICATION'},
#  {'crimeTypeID': 578, 'type': 'BATTERY-AGGRAVATED'},
#  {'crimeTypeID': 579, 'type': 'THEFT OF MOTOR VEH PARTS & ACCESS'},
#  {'crimeTypeID': 580, 'type': 'MISSING PERSON ADULT/FEMALE'},
#  {'crimeTypeID': 581, 'type': 'DECPT PRACT'},
#  {'crimeTypeID': 582, 'type': 'THROW DANG MATERIAL'},
#  {'crimeTypeID': 583, 'type': 'DECEPT PRACT'},
#  {'crimeTypeID': 584, 'type': 'MIP; POSS LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 585, 'type': 'DRIVING UNDER INFLUENCE-'},
#  {'crimeTypeID': 586, 'type': 'ASSIST PD W/ACCIDENT'},
#  {'crimeTypeID': 587, 'type': 'ASSIST CPD ROBBERY'},
#  {'crimeTypeID': 588, 'type': 'STALKING'},
#  {'crimeTypeID': 589, 'type': 'SEX OFFENSE, FORCIBLE'},
#  {'crimeTypeID': 590, 'type': 'SEARCH WARRANT ASSIST'},
#  {'crimeTypeID': 591, 'type': 'THEFT FROM BUILDING'},
#  {'crimeTypeID': 592, 'type': 'WARRANT-IN STATE'},
#  {'crimeTypeID': 593, 'type': 'DISOBEY BIKE CODE'},
#  {'crimeTypeID': 594, 'type': 'PUBLIC URINATION (C)'},
#  {'crimeTypeID': 595, 'type': 'SAFEKEEPING'},
#  {'crimeTypeID': 596, 'type': 'BATTERY -CITY'},
#  {'crimeTypeID': 597, 'type': 'NOISE'},
#  {'crimeTypeID': 598, 'type': 'TRANSIENT MERCHANT/LICENSE REQUIRED'},
#  {'crimeTypeID': 599, 'type': 'ASSIST W/MENTAL HEALTH'},
#  {'crimeTypeID': 600, 'type': 'NON-FORCIBLE SEX OFFENSE'},
#  {'crimeTypeID': 601, 'type': 'TRESPASS/RESISTING ARREST'},
#  {'crimeTypeID': 602, 'type': 'SEXUAL ASSAULT'},
#  {'crimeTypeID': 603, 'type': 'CANINE SWEEP - IDOT'},
#  {'crimeTypeID': 604, 'type': 'BATTERY-DOMESTIC'},
#  {'crimeTypeID': 605, 'type': 'ASSIST OTHER GOVT AGENCY/EOD'},
#  {'crimeTypeID': 606, 'type': 'HARASS BY TX'},
#  {'crimeTypeID': 607, 'type': 'STATUTORY RAPE'},
#  {'crimeTypeID': 608, 'type': 'RECOVERED STOLEN VEHICLE'},
#  {'crimeTypeID': 609, 'type': 'ASSIST/TRAFFIC STOP'},
#  {'crimeTypeID': 610, 'type': 'FRAUD/DECEPTION'},
#  {'crimeTypeID': 611, 'type': 'VIOLATION ORDER PROTECTION'},
#  {'crimeTypeID': 612, 'type': 'DOEMSTIC VIOLENCE'},
#  {'crimeTypeID': 613, 'type': 'LOST ARTICLES'},
#  {'crimeTypeID': 614, 'type': 'TRAFFIC CITATION/VOP'},
#  {'crimeTypeID': 615, 'type': 'TRESPASS-VEHICLE'},
#  {'crimeTypeID': 616, 'type': 'ARSON'},
#  {'crimeTypeID': 617, 'type': 'NO REAR REGISTRATION LIGHT'},
#  {'crimeTypeID': 618, 'type': 'NOISE PROHIBITED'},
#  {'crimeTypeID': 619, 'type': 'METRO'},
#  {'crimeTypeID': 620, 'type': 'DELIVERY OF ALCOHOL/LIQ TO A MINOR'},
#  {'crimeTypeID': 621, 'type': 'DEL/MANUF CANNABIS OVER 30 G -FEL'},
#  {'crimeTypeID': 622, 'type': 'ALCOHOL/LIQUOR SERVER NAME TAG REQ'},
#  {'crimeTypeID': 623, 'type': 'ASSIST COUNTY PD W/K9 SWEEP'},
#  {'crimeTypeID': 624, 'type': 'HINDERING POLICE OFFCR'},
#  {'crimeTypeID': 625, 'type': 'THROWING DANGEROUS MATERIALS'},
#  {'crimeTypeID': 626, 'type': 'BURGLARY FROM MOTOR'},
#  {'crimeTypeID': 627, 'type': 'DAMAGING PROPERTY'},
#  {'crimeTypeID': 628, 'type': 'HEROIN OVERDOSE'},
#  {'crimeTypeID': 629, 'type': 'ATTEMPTED RAPE'},
#  {'crimeTypeID': 630, 'type': 'THROW DANGEROUS MATERIAL'},
#  {'crimeTypeID': 631, 'type': 'THEFT GENERALLY'},
#  {'crimeTypeID': 632, 'type': 'CONTRIBUTING CRIM DELINQUENCY JUV'},
#  {'crimeTypeID': 633, 'type': 'COMPUTER TAMPERING'},
#  {'crimeTypeID': 634, 'type': 'ASSIST/SHOTS FIRED'},
#  {'crimeTypeID': 635, 'type': 'INTIMIDATION'},
#  {'crimeTypeID': 636, 'type': 'ASSIST/THEFT'},
#  {'crimeTypeID': 637, 'type': 'ASSIST CPD W/RETAIL THEFT'},
#  {'crimeTypeID': 638, 'type': 'HYPODERMIC NEEDLE/SYRINGE-POSS/SALE'},
#  {'crimeTypeID': 639, 'type': 'MINOR IN POSSESSION'},
#  {'crimeTypeID': 640, 'type': 'ASSIST UPD W/DISORDERLY'},
#  {'crimeTypeID': 641, 'type': 'LIQUOR-SALE TO MINORS,DRUNKS,ETC'},
#  {'crimeTypeID': 642, 'type': 'ASSIST UIPD W/BATTERY'},
#  {'crimeTypeID': 643, 'type': 'ASSIST ROBBERY'},
#  {'crimeTypeID': 644, 'type': 'SEX HARASSMENT'},
#  {'crimeTypeID': 645, 'type': 'DEL/MANUF CANNABIS UNDER 30 G -MISD'},
#  {'crimeTypeID': 646, 'type': 'TRESPASS TO PROPERTY'},
#  {'crimeTypeID': 647, 'type': 'ASSIST K9'},
#  {'crimeTypeID': 648, 'type': 'NARCOTICS UNIT'},
#  {'crimeTypeID': 649, 'type': 'PUBLIC POSSESSION'},
#  {'crimeTypeID': 650, 'type': 'THEFT-CITY'},
#  {'crimeTypeID': 651, 'type': 'CONTROLLED SUBSTANCE-MANUF-'},
#  {'crimeTypeID': 652, 'type': 'THEFT'},
#  {'crimeTypeID': 653, 'type': 'PREDATORY CRIM SEX ASSAULT OF CHILD'},
#  {'crimeTypeID': 654, 'type': 'DRUGS; COUNTERFEIT MONEY'},
#  {'crimeTypeID': 655, 'type': 'RUNAWAY - MINOR REQUIRE AUTH INTER'},
#  {'crimeTypeID': 656, 'type': 'TRESPASSIN'},
#  {'crimeTypeID': 657, 'type': 'TRESPASSING'},
#  {'crimeTypeID': 658, 'type': 'LARCENY'},
#  {'crimeTypeID': 659, 'type': 'AGGR UNLAWFUL USE OF WEAPON'},
#  {'crimeTypeID': 660, 'type': 'ASSIST SICK & INJURED'},
#  {'crimeTypeID': 661, 'type': 'TERRORIST THREATS'},
#  {'crimeTypeID': 662, 'type': 'AGGRAVATED BATTERY'},
#  {'crimeTypeID': 663, 'type': 'LIQUOR - PUBLIC POSSESSION'},
#  {'crimeTypeID': 664, 'type': 'ASSIST CCSO W/BMV'},
#  {'crimeTypeID': 665, 'type': 'BICYCLE VIOLATION'},
#  {'crimeTypeID': 666, 'type': 'AGG DISCHARGE OF FIREARM'},
#  {'crimeTypeID': 667, 'type': 'NOISE & VIBRATIONS'},
#  {'crimeTypeID': 668, 'type': 'ASSIST STATE POLICE'},
#  {'crimeTypeID': 669, 'type': 'ASSIST/CPD WITH ACCIDENT'},
#  {'crimeTypeID': 670, 'type': 'ASSIST/TRANSLATOR'},
#  {'crimeTypeID': 671, 'type': 'FORGERY/CREDIT CARD FRAUD'},
#  {'crimeTypeID': 672, 'type': 'CARRYING ALCOHOL/LIQ OUT OF PREMISE'},
#  {'crimeTypeID': 673, 'type': 'DECP PRACTICE'},
#  {'crimeTypeID': 674, 'type': 'MURDER/NON-NEG. MANSSL.'},
#  {'crimeTypeID': 675, 'type': 'THEFT FROM MOTOR VEHICLE'},
#  {'crimeTypeID': 676, 'type': 'ASSIST COUNTY POLICE'},
#  {'crimeTypeID': 677, 'type': 'LIQOUR'},
#  {'crimeTypeID': 678, 'type': 'RECKLESS CONDUCT'},
#  {'crimeTypeID': 679, 'type': 'DISOBEY STOP'},
#  {'crimeTypeID': 680, 'type': 'ASSIST K9 SEARCH'},
#  {'crimeTypeID': 681, 'type': 'CANNABIS-DELIVERY 30GM &'},
#  {'crimeTypeID': 682, 'type': 'METRO/ASSIST OTHER'},
#  {'crimeTypeID': 683, 'type': 'ASSIST OTHER PD'},
#  {'crimeTypeID': 684, 'type': 'LIQUOR-PURCH/POSS/CONSUMP BY MINORS'},
#  {'crimeTypeID': 685, 'type': 'ASSIST/NO TRESPASS'},
#  {'crimeTypeID': 686, 'type': 'FIGHT'},
#  {'crimeTypeID': 687, 'type': 'MISSING PERSON'},
#  {'crimeTypeID': 688, 'type': 'DIS CONDUCT'},
#  {'crimeTypeID': 689, 'type': 'ASSIST UPD W/RETAIL THEFT'},
#  {'crimeTypeID': 690, 'type': 'LIQUOR-ILLEGAL CONSUMPTION BY MINOR'},
#  {'crimeTypeID': 691, 'type': 'ASSIST CPD W/K-9'},
#  {'crimeTypeID': 692, 'type': 'CRISIS INTERVEN. - ALCOHOL'},
#  {'crimeTypeID': 693, 'type': 'CURFEW VIOLATION'},
#  {'crimeTypeID': 694, 'type': 'ASSIST/DOMESTIC BATTERY'},
#  {'crimeTypeID': 695, 'type': 'LIQUOR-ILLEGAL CONSUMPTION BY'},
#  {'crimeTypeID': 696, 'type': 'ACCIDENT W/NON-VEH PROP DAMAGE'},
#  {'crimeTypeID': 697, 'type': 'TRESPASS-STATE SUPPORTED'},
#  {'crimeTypeID': 698, 'type': 'RESIST/OBS CORRECT/POLICE/FIRE'},
#  {'crimeTypeID': 699, 'type': 'THEFT FROM COIN-OP'},
#  {'crimeTypeID': 700, 'type': 'HARASSMENT BY TELEPHONE'},
#  {'crimeTypeID': 701, 'type': 'ASSIST UPD W/K9 SWEEP'},
#  {'crimeTypeID': 702, 'type': 'SUICIDAL SUBJECT'},
#  {'crimeTypeID': 703, 'type': 'ASSIST/K9'},
#  {'crimeTypeID': 704, 'type': 'POSS ALCOHOL PUB PROP /'},
#  {'crimeTypeID': 705, 'type': 'OPERATE UNINSURED MOTOR VEHICLE'},
#  {'crimeTypeID': 706, 'type': 'LIQUOR - ADULT RESPONSIBILITY/UNDERAGE'},
#  {'crimeTypeID': 707, 'type': 'ASSIST/HARRESSMENT'},
#  {'crimeTypeID': 708, 'type': 'ABANDONED JUNK VEHICLES'},
#  {'crimeTypeID': 709, 'type': 'PUBLIC URINATION-CITY'},
#  {'crimeTypeID': 710, 'type': 'LIQUOR-OPEN CONTAINER/PUBLIC PROP.'},
#  {'crimeTypeID': 711, 'type': 'DOMESTIC VIOLENCE'},
#  {'crimeTypeID': 712, 'type': 'SEARCH WARRANT'},
#  {'crimeTypeID': 713, 'type': 'ASSIST TOW TRUCK'},
#  {'crimeTypeID': 714, 'type': 'DEATH INVESTIGATION/ASSIST UPD'},
#  {'crimeTypeID': 715, 'type': 'ALCOHOL/LIQUOR CONSUMPTION EMPLOYEE'},
#  {'crimeTypeID': 716, 'type': 'ASSIST UPD ON ROBBERY'},
#  {'crimeTypeID': 717, 'type': 'BURGLARY OF MOTOR VEHICLE'},
#  {'crimeTypeID': 718, 'type': 'ASSIST COUNTY POLICE W/ARMED SUBJ'},
#  {'crimeTypeID': 719, 'type': 'CRIMINAL DAMAGE GOVT SUPPORT PROP'},
#  {'crimeTypeID': 720, 'type': 'DISPOSAL ON PUBLIC WAYS'},
#  {'crimeTypeID': 721, 'type': 'ELECTRICAL FIRE'},
#  {'crimeTypeID': 722, 'type': 'SEXUAL ABUSE-CRIMINAL'},
#  {'crimeTypeID': 723, 'type': 'ASSIST ISP W/SEARCH'},
#  {'crimeTypeID': 724, 'type': 'THEFT BY LESSEE'},
#  {'crimeTypeID': 725, 'type': 'PEEPING TOM'},
#  {'crimeTypeID': 726, 'type': 'SEXUAL-ASSAULT-CRIMINAL'},
#  {'crimeTypeID': 727, 'type': 'AGG ASSAULT'},
#  {'crimeTypeID': 728, 'type': 'PIMPING - PROMOTING PROSTITUTION'},
#  {'crimeTypeID': 729, 'type': 'TRAFFIC SIGN VIOLATION'},
#  {'crimeTypeID': 730, 'type': 'CANNABIS-POSS 30 GM & UNDER'},
#  {'crimeTypeID': 731, 'type': 'LIQUOR-ILLEGAL POSS. BY MINOR'},
#  {'crimeTypeID': 732, 'type': 'HARASSMENT'},
#  {'crimeTypeID': 733, 'type': 'CONTROLLED SUBSTANCE-POSS W/INTENT'},
#  {'crimeTypeID': 734, 'type': 'SUICIDE ATTEMPT/DRUGS'},
#  {'crimeTypeID': 735, 'type': 'DOMESTIC OFFENSE'},
#  {'crimeTypeID': 736, 'type': 'DRIVING UNDER THE INFL-ALCOHOL'},
#  {'crimeTypeID': 737, 'type': 'POSS OF CANNABIS UNDER 10 GM &'},
#  {'crimeTypeID': 738, 'type': 'ASSIST/U OF I FOUND PROPERTY'},
#  {'crimeTypeID': 739, 'type': 'CANNABIS POSS 10 GM OR LESS -ORD'},
#  {'crimeTypeID': 740, 'type': 'DRUG'},
#  {'crimeTypeID': 741, 'type': 'DEC PRACTICE'},
#  {'crimeTypeID': 742, 'type': 'TRAFFIC OFFENSE'},
#  {'crimeTypeID': 743, 'type': 'RESISTING ARREST'},
#  {'crimeTypeID': 744, 'type': 'PUBLIC INDECENCY'},
#  {'crimeTypeID': 745, 'type': 'K9 ASSIST CCSO'},
#  {'crimeTypeID': 746, 'type': 'OFFICIAL MISCONDUCT'},
#  {'crimeTypeID': 747, 'type': 'ASSIST CPD W/MEDICAL'},
#  {'crimeTypeID': 748, 'type': 'ASSIST/DOMESTIC'},
#  {'crimeTypeID': 749, 'type': 'ASSIST BATTERY'},
#  {'crimeTypeID': 750, 'type': 'DRUGS/LIQUOR'},
#  {'crimeTypeID': 751, 'type': 'SRO - YAC REFERRAL'},
#  {'crimeTypeID': 752, 'type': 'WARRANT ARREST/TRAFFIC CITATIONS'},
#  {'crimeTypeID': 753, 'type': 'HOME INVASION'},
#  {'crimeTypeID': 754, 'type': 'TERRORISM-MAKE FALSE TERROR'},
#  {'crimeTypeID': 755, 'type': 'AGGRAVATED ASSAULT'},
#  {'crimeTypeID': 756, 'type': 'ARMED VIOLENCE'},
#  {'crimeTypeID': 757, 'type': 'ROBBERY'},
#  {'crimeTypeID': 758, 'type': 'CANNABIS POSS MORE THAN 10 LESS'},
#  {'crimeTypeID': 759, 'type': 'CYBERSTALKING'},
#  {'crimeTypeID': 760, 'type': 'DEFACING IDENTI.MARKS OF FIREARMS'},
#  {'crimeTypeID': 761, 'type': 'ASSIST/ACCIDENT'},
#  {'crimeTypeID': 762, 'type': 'DRUG PARAPHERNALIA-SALE/DELIVERY'},
#  {'crimeTypeID': 763, 'type': 'OBSTRUCTING IDENTIFICATION'},
#  {'crimeTypeID': 764, 'type': 'ADULT RESPONSIBILITY'},
#  {'crimeTypeID': 765, 'type': 'RESISTING/OBSTR OFFICER'},
#  {'crimeTypeID': 766, 'type': 'STALKING/CYBERSTALKING'},
#  {'crimeTypeID': 767, 'type': 'METRO ACTIVATION'},
#  {'crimeTypeID': 768, 'type': 'ASSIST CCSO W/ARMED SUBJECT'},
#  {'crimeTypeID': 769, 'type': 'DISOBEY TRAFFIC (BIKE)'},
#  {'crimeTypeID': 770, 'type': 'CHILD PORNOGRAPHY'},
#  {'crimeTypeID': 771, 'type': 'OBSTRUCTING JUSTICE'},
#  {'crimeTypeID': 772, 'type': 'ASSIST CCSO TRAF STOP'},
#  {'crimeTypeID': 773, 'type': 'LIQUOR - CARRYING IN PUBLIC PLACE'},
#  {'crimeTypeID': 774, 'type': 'DISORDERLY'},
#  {'crimeTypeID': 775, 'type': 'DECEPTIVE PRACTCIES'},
#  {'crimeTypeID': 776, 'type': 'DECEPTIVE PRACTICES/EXTORTION'},
#  {'crimeTypeID': 777, 'type': 'OTHER TROUBLE/INFO RPT'},
#  {'crimeTypeID': 778, 'type': 'CONTROLLED SUBSTANCE-LOOK-ALIKE'},
#  {'crimeTypeID': 779, 'type': 'WARRANT-OUT OF STATE'},
#  {'crimeTypeID': 780, 'type': 'VIOLATION OF ORDER OF PROTECTION'},
#  {'crimeTypeID': 781, 'type': 'UNLAWFUL USE ID'},
#  {'crimeTypeID': 782, 'type': 'LIQUOR-UNDERAGE/PUBLIC POSSESSION'},
#  {'crimeTypeID': 783, 'type': 'ASSIST CPD W/SHOTS FIRED'},
#  {'crimeTypeID': 784, 'type': 'EOD; ASSIST OTHER'},
#  {'crimeTypeID': 785, 'type': 'EXCITED DELIRIUM'},
#  {'crimeTypeID': 786, 'type': 'ASSIST/ARMED SUBJ'},
#  {'crimeTypeID': 787, 'type': 'EXTORTION'},
#  {'crimeTypeID': 788, 'type': 'MOB ACTION'},
#  {'crimeTypeID': 789, 'type': 'K9 ASSIST CPD'},
#  {'crimeTypeID': 790, 'type': 'ROBBERY-AGGRAVATED'},
#  {'crimeTypeID': 791, 'type': 'LIQUOR-UNDERAGE'},
#  {'crimeTypeID': 792, 'type': 'FIGHTING'},
#  {'crimeTypeID': 793, 'type': 'ASSIST FIGHT'},
#  {'crimeTypeID': 794, 'type': 'WEAPON'},
#  {'crimeTypeID': 795, 'type': 'DISORDERLY CONDUCT-ALL'},
#  {'crimeTypeID': 796, 'type': 'THROWING DANGEROUS'},
#  {'crimeTypeID': 797, 'type': 'ASSIST URBANA THEFT'},
#  {'crimeTypeID': 798, 'type': 'ILLEGAL TRANSPORTATION OF LIQUOR'},
#  {'crimeTypeID': 799, 'type': 'DRUG EQUIPMENT-POSSESSION'},
#  {'crimeTypeID': 800, 'type': 'BURGLARY'},
#  {'crimeTypeID': 801, 'type': 'BATTERY-AGG DOMESTIC'},
#  {'crimeTypeID': 802, 'type': 'ASSIST CCSO'},
#  {'crimeTypeID': 803, 'type': 'LIQUOR-UNDERAGE; FIGHT'},
#  {'crimeTypeID': 804, 'type': 'POSSESSION OF STOLEN PROP'},
#  {'crimeTypeID': 805, 'type': 'SALES OF TOBACCO TO MINORS'},
#  {'crimeTypeID': 806, 'type': 'ASSIST/ROBBERY DETAIL'},
#  {'crimeTypeID': 807, 'type': 'POSSESSION STOLEN PROPERTY'},
#  {'crimeTypeID': 808, 'type': 'RESISTING/OBSTRUCTING'},
#  {'crimeTypeID': 809, 'type': 'STALKING BY ELECTRONIC COMMUNICATIO'},
#  {'crimeTypeID': 810, 'type': 'HARASSMENT BY TX'},
#  {'crimeTypeID': 811, 'type': 'UPD ACCIDENT (FATAL)'},
#  {'crimeTypeID': 812, 'type': 'UNLAWFUL USE OF ID'},
#  {'crimeTypeID': 813, 'type': 'ASSIST/CRIMINAL DAMAGE'},
#  {'crimeTypeID': 814, 'type': 'DEL/MANUF CANNABIS UNDER 30 G -'},
#  {'crimeTypeID': 815, 'type': 'SEX OFFENDER REGISTRATION'},
#  {'crimeTypeID': 816, 'type': 'MISSING PERSON ADULT/MALE'},
#  {'crimeTypeID': 817, 'type': 'RAPE'},
#  {'crimeTypeID': 818, 'type': 'ASSIST CPD W/BATTERY'},
#  {'crimeTypeID': 819, 'type': 'DOMESTIC DISPUTE'},
#  {'crimeTypeID': 820, 'type': 'OBSTRUCTIN JUSTICE'},
#  {'crimeTypeID': 821, 'type': 'DECEPT PRACTICE'},
#  {'crimeTypeID': 822, 'type': 'UNLAWFUL USE OF I.D.'},
#  {'crimeTypeID': 823, 'type': 'HARRASSMENT'},
#  {'crimeTypeID': 824, 'type': 'MANUFACTURE CONTROLLED SUB'},
#  {'crimeTypeID': 825, 'type': 'ASSIST ATT BURG F/MV'},
#  {'crimeTypeID': 826, 'type': 'PUBLIC POSSESSION OF ALCOHOL'},
#  {'crimeTypeID': 827, 'type': 'SEXUAL HARASSMENT'},
#  {'crimeTypeID': 828, 'type': 'PEDESTRIAN STOPS'},
#  {'crimeTypeID': 829, 'type': 'RESIST/OBSTRUCT/DISARM AN'},
#  {'crimeTypeID': 830, 'type': 'ASSIST CPD W/ARMED SUBJECT'},
#  {'crimeTypeID': 831, 'type': 'ZERO TOLERANCE'},
#  {'crimeTypeID': 832, 'type': 'SPEEDING (RADAR)'},
#  {'crimeTypeID': 833, 'type': 'UNLAW USE ID'},
#  {'crimeTypeID': 834, 'type': 'UNLAWFUL POSS/USE WEAPON BY FELON'},
#  {'crimeTypeID': 835, 'type': 'RESIST/OBSTRUCT/DISARM AN OFFICER'},
#  {'crimeTypeID': 836, 'type': 'LEAVING SCENE PROPERTY DAMAGE'},
#  {'crimeTypeID': 837, 'type': 'RESISTING/OBSTR. OFFICER'},
#  {'crimeTypeID': 838, 'type': 'RECOVERED PROPERTY ONLY'},
#  {'crimeTypeID': 839, 'type': 'CANNABIS POSS OVER 10 - 100 G -MISD'},
#  {'crimeTypeID': 840, 'type': 'POSS DRUG PARAPHERNALIA'},
#  {'crimeTypeID': 841, 'type': 'VANDALISM-INSTITUTIONAL'},
#  {'crimeTypeID': 842, 'type': 'ROBBERY-ARMED'},
#  {'crimeTypeID': 843, 'type': 'CURFEW'},
#  {'crimeTypeID': 844, 'type': 'THEFT OVER $500'},
#  {'crimeTypeID': 845, 'type': 'EOD CALLOUT'},
#  {'crimeTypeID': 846, 'type': 'RESIST OBS OFC'},
#  {'crimeTypeID': 847, 'type': 'CRIMINAL DAMAGE'},
#  {'crimeTypeID': 848, 'type': 'ACCIDENT INVOLVING NON-INJURY'},
#  {'crimeTypeID': 849, 'type': 'CREDIT CARD FRAUD/FORGERY'},
#  {'crimeTypeID': 850, 'type': 'POSS ALCOHOL PUB PROP / PARKING'},
#  {'crimeTypeID': 851, 'type': 'THEFT $500 AND UNDER'},
#  {'crimeTypeID': 852, 'type': 'ASSIST/SEACH WARRANT'},
#  {'crimeTypeID': 853, 'type': 'ASSIST UPD W/THEFT'},
#  {'crimeTypeID': 854, 'type': 'THEFT-IDENTITY'}]

# %%
#Flush the list of dictionary to CSV file
crimeTypeColumns = ['crimeTypeID','type']

crimeTypeCSVName = "CrimeType.csv"

try:
    with open(csvFilePath+"\\"+crimeTypeCSVName, 'w', newline="") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=crimeTypeColumns)
        writer.writeheader()
        for data in crimeTypeListOfDicts:
            writer.writerow(data)
except IOError:
    print("I/O error")

# %% [markdown]
# # Create Crime CSV

# %% [markdown]
# ### Add incident column

# %%
crimeDF = csvData[["Incident"]]
crimeDF
# Out:
#        Incident
# 0     II1300002
# 1     II1300001
# 2     II1300003
# 3     II1300004
# 4     II1300006
# ...         ...
# 7438  CC1909074
# 7439  IF1901488
# 7440  II1901441
# 7441  II1901442
# 7442  UU1905819
#
# [7443 rows x 1 columns]

# %% [markdown]
# ### Add reportedAt column

# %%
def convertCSVDateToSQLDateFormat(str):
    list = str.split("/")
    res = "20" + list[2] + "-" + list[0] + "-" + list[1]
    return res

def convertCSVTimeToSQLTimeFormat(time):
    timeSplit = time.split(" ")
    if(len(timeSplit)==3) and (timeSplit[1] == "p."): #am or pm
        timeSplit[0] = str((int(timeSplit[0].split(":",1)[0])+12)%24) + ":" + timeSplit[0].split(":",1)[1]
    if(len(timeSplit)==3) and (timeSplit[1] == "a."): #am or pm
        timeSplit[0] = str((int(timeSplit[0].split(":",1)[0])+0)%12) + ":" + timeSplit[0].split(":",1)[1]
    return timeSplit[0]

# %%
# Add reportedAt column
reportedAt = []
for date in csvData["Date reported"]:
    reportedAt.append(convertCSVDateToSQLDateFormat(date))

index = 0
for time in csvData["Time reported"]:
    reportedAt[index] += " " + convertCSVTimeToSQLTimeFormat(time)
    index += 1
    
reportedAtDF = pd.DataFrame(reportedAt, columns = ['reportedAt'])
reportedAtDF.head(20)
# Out:
#             reportedAt
# 0     2013-1-1 1:39:00
# 1     2013-1-1 0:44:00
# 2     2013-1-1 6:25:00
# 3     2013-1-1 9:22:00
# 4    2013-1-3 11:00:00
# 5     2013-1-3 0:43:00
# 6    2013-1-3 14:47:00
# 7    2013-1-3 14:46:00
# 8    2013-1-3 14:44:00
# 9    2013-1-3 14:39:00
# 10   2013-1-3 14:37:00
# 11    2013-1-5 0:00:00
# 12   2013-1-6 16:49:00
# 13   2013-1-6 22:47:00
# 14    2013-1-8 0:00:00
# 15    2013-1-9 2:21:00
# 16   2013-1-9 15:26:00
# 17   2013-1-10 2:32:00
# 18  2013-1-10 11:07:00
# 19   2013-1-11 2:41:00

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,reportedAtDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt
# 0     II1300002   2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00
# 4     II1300006  2013-1-3 11:00:00
# ...         ...                ...
# 7438  CC1909074    2019-11-14 7:00
# 7439  IF1901488   2019-11-14 16:56
# 7440  II1901441   2019-11-14 16:52
# 7441  II1901442   2019-11-14 20:10
# 7442  UU1905819    2019-11-14 7:00
#
# [7443 rows x 2 columns]

# %% [markdown]
# ### Add occuredAt column

# %%
# Add occuredAt column
# print(csvData.isnull())

occurredAt = []
for date in csvData["Date occurred"]:
#     print(date)
#     print(type(date))
    occurredAt.append(convertCSVDateToSQLDateFormat(date))

index = 0
for time in csvData["Time occurred"]:
    occurredAt[index] += " " + convertCSVTimeToSQLTimeFormat(time)
    index += 1
    
occurredAtDF = pd.DataFrame(occurredAt, columns = ['occurredAt'])
occurredAtDF.tail(20)
# Out:
#             occurredAt
# 7423   2019-11-10 1:35
# 7424   2019-11-10 2:08
# 7425   2019-11-10 1:27
# 7426   2019-11-10 2:20
# 7427  2019-11-10 15:32
# 7428  2019-11-10 14:30
# 7429   2019-11-10 2:08
# 7430   2019-11-9 23:39
# 7431  2019-10-19 23:45
# 7432   2019-11-12 1:11
# 7433   2019-11-12 7:59
# 7434   2019-11-12 9:10
# 7435  2019-11-12 15:14
# 7436  2019-11-13 13:44
# 7437  2019-11-13 16:16
# 7438   2019-11-14 2:37
# 7439  2019-11-14 16:56
# 7440  2019-11-14 16:00
# 7441  2019-11-14 20:05
# 7442  2019-11-13 19:41

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,occurredAtDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00    2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-1-3 11:00:00  2012-12-20 8:00:00
# ...         ...                ...                 ...
# 7438  CC1909074    2019-11-14 7:00     2019-11-14 2:37
# 7439  IF1901488   2019-11-14 16:56    2019-11-14 16:56
# 7440  II1901441   2019-11-14 16:52    2019-11-14 16:00
# 7441  II1901442   2019-11-14 20:10    2019-11-14 20:05
# 7442  UU1905819    2019-11-14 7:00    2019-11-13 19:41
#
# [7443 rows x 3 columns]

# %% [markdown]
# ### Add Disposition column

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,csvData["Disposition"]], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00    2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-1-3 11:00:00  2012-12-20 8:00:00
# ...         ...                ...                 ...
# 7438  CC1909074    2019-11-14 7:00     2019-11-14 2:37
# 7439  IF1901488   2019-11-14 16:56    2019-11-14 16:56
# 7440  II1901441   2019-11-14 16:52    2019-11-14 16:00
# 7441  II1901442   2019-11-14 20:10    2019-11-14 20:05
# 7442  UU1905819    2019-11-14 7:00    2019-11-13 19:41
#
#                    Disposition
# 0                       ARREST
# 1                       ARREST
# 2                       ARREST
# 3                       ARREST
# 4                 ADMIN. CLOSE
# ...                        ...
# 7438  REPORTED TO OTHER AGENCY
# 7439              ADMIN CLOSED
# 7440              ADMIN. CLOSE
# 7441              ADMIN. CLOSE
# 7442  REPORTED TO OTHER AGENCY
#
# [7443 rows x 4 columns]

# %% [markdown]
# ### Add crimeTypeID column

# %%
crimeTypeID = []
for row in csvData["Crime Description"]:
    crimeTypeStartIndex = 300
    for type in crimeTypeList:
        if(type==row.upper().strip()):
            crimeTypeID.append(crimeTypeStartIndex)
            break;
        crimeTypeStartIndex += 1

crimeTypeIDDF = pd.DataFrame(crimeTypeID, columns = ['crimeTypeID'])
crimeTypeIDDF
# Out:
#       crimeTypeID
# 0             562
# 1             510
# 2             562
# 3             407
# 4             699
# ...           ...
# 7438          529
# 7439          516
# 7440          513
# 7441          719
# 7442          800
#
# [7443 rows x 1 columns]

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,crimeTypeIDDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00    2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-1-3 11:00:00  2012-12-20 8:00:00
# ...         ...                ...                 ...
# 7438  CC1909074    2019-11-14 7:00     2019-11-14 2:37
# 7439  IF1901488   2019-11-14 16:56    2019-11-14 16:56
# 7440  II1901441   2019-11-14 16:52    2019-11-14 16:00
# 7441  II1901442   2019-11-14 20:10    2019-11-14 20:05
# 7442  UU1905819    2019-11-14 7:00    2019-11-13 19:41
#
#                    Disposition  crimeTypeID
# 0                       ARREST          562
# 1                       ARREST          510
# 2                       ARREST          562
# 3                       ARREST          407
# 4                 ADMIN. CLOSE          699
# ...                        ...          ...
# 7438  REPORTED TO OTHER AGENCY          529
# 7439              ADMIN CLOSED          516
# 7440              ADMIN. CLOSE          513
# 7441              ADMIN. CLOSE          719
# 7442  REPORTED TO OTHER AGENCY          800
#
# [7443 rows x 5 columns]

# %%
#Rename columns
crimeDF.columns = ["incidentID", "reportedAt", "occuredAt", "disposition", "crimeTypeID"]
crimeDF
# Out:
#      incidentID         reportedAt           occuredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00    2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-1-3 11:00:00  2012-12-20 8:00:00
# ...         ...                ...                 ...
# 7438  CC1909074    2019-11-14 7:00     2019-11-14 2:37
# 7439  IF1901488   2019-11-14 16:56    2019-11-14 16:56
# 7440  II1901441   2019-11-14 16:52    2019-11-14 16:00
# 7441  II1901442   2019-11-14 20:10    2019-11-14 20:05
# 7442  UU1905819    2019-11-14 7:00    2019-11-13 19:41
#
#                    disposition  crimeTypeID
# 0                       ARREST          562
# 1                       ARREST          510
# 2                       ARREST          562
# 3                       ARREST          407
# 4                 ADMIN. CLOSE          699
# ...                        ...          ...
# 7438  REPORTED TO OTHER AGENCY          529
# 7439              ADMIN CLOSED          516
# 7440              ADMIN. CLOSE          513
# 7441              ADMIN. CLOSE          719
# 7442  REPORTED TO OTHER AGENCY          800
#
# [7443 rows x 5 columns]

# %%
#Flush the dataframe to CSV file

crimeCSVName = "Crime.csv"
    
crimeDF.to_csv(csvFilePath+"\\"+crimeCSVName, encoding='utf-8', index=False)

# %% [markdown]
# # Create happensAt CSV

# %%
csvData
# Out:
#        Incident Date reported   Time reported Date occurred   Time occurred  \
# 0     II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1     II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2     II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3     II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4     II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ...         ...           ...             ...           ...             ...
# 7438  CC1909074      11/14/19            7:00      11/14/19            2:37
# 7439  IF1901488      11/14/19           16:56      11/14/19           16:56
# 7440  II1901441      11/14/19           16:52      11/14/19           16:00
# 7441  II1901442      11/14/19           20:10      11/14/19           20:05
# 7442  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#                General Location                  Crime Description  \
# 0      500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1            600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                      CIRCLE K            DRIVING UNDER THE INFL-
# 3     COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                  KIRK / GERTY                 THEFT FROM COIN-OP
# ...                         ...                                ...
# 7438    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 7439  IUB ADMINISTRATIVE SUITES                            THREATS
# 7440        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 7441      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 7442   102 N GREGORY ST, URBANA                           BURGLARY
#
#                    Disposition  BlockId
# 0                       ARREST        0
# 1                       ARREST       14
# 2                       ARREST        0
# 3                       ARREST        9
# 4                 ADMIN. CLOSE        0
# ...                        ...      ...
# 7438  REPORTED TO OTHER AGENCY       25
# 7439              ADMIN CLOSED       50
# 7440              ADMIN. CLOSE        0
# 7441              ADMIN. CLOSE        0
# 7442  REPORTED TO OTHER AGENCY       36
#
# [7443 rows x 9 columns]

# %%
happensAtDF = csvData[["Incident", "BlockId", "General Location"]]

# %%
#Rename columns
happensAtDF.columns = ["incidentID", "blockID", "genLocation"]
happensAtDF
# Out:
#      incidentID  blockID                genLocation
# 0     II1300002        0   500 blk of JOHN STREET E
# 1     II1300001       14         600 blk of GREEN E
# 2     II1300003        0                   CIRCLE K
# 3     II1300004        9  COMPUTER APPLICATION BLDG
# 4     II1300006        0               KIRK / GERTY
# ...         ...      ...                        ...
# 7438  CC1909074       25    808 S OAK ST, CHAMPAIGN
# 7439  IF1901488       50  IUB ADMINISTRATIVE SUITES
# 7440  II1901441        0        500 blk of ELM ST S
# 7441  II1901442        0      ARCHITECTURE BUILDING
# 7442  UU1905819       36   102 N GREGORY ST, URBANA
#
# [7443 rows x 3 columns]

# %%
#Flush the dataframe to CSV file

happensAtCSVName = "happensAt.csv"
    
happensAtDF.to_csv(csvFilePath+"\\"+happensAtCSVName, encoding='utf-8', index=False)
