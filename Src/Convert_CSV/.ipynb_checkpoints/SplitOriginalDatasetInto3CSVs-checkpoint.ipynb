# %%
import csv
import pandas as pd

# %%
csvFilePath = r"C:\Users\Yash\Desktop\Courses\CS411\Project Track 1\Src\Convert_CSV\Data"
csvList = ["2013new.csv", "2014new.csv", "2015new.csv", "2016new.csv", "2017new.csv", "2018new.csv", "2019new.csv"]

# %%
csvData = pd.DataFrame()
for csvName in csvList:
    csvDataTemp = pd.read_csv(csvFilePath+"\\"+csvName)
    csvData = pd.concat([csvData,csvDataTemp])
listOfcsvDataColumns = list(csvData.columns)
csvData
# Out:
#       Incident Date reported   Time reported Date occurred   Time occurred  \
# 0    II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1    II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2    II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3    II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4    II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ..         ...           ...             ...           ...             ...
# 877  CC1909074      11/14/19            7:00      11/14/19            2:37
# 878  IF1901488      11/14/19           16:56      11/14/19           16:56
# 879  II1901441      11/14/19           16:52      11/14/19           16:00
# 880  II1901442      11/14/19           20:10      11/14/19           20:05
# 881  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#               General Location                  Crime Description  \
# 0     500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1           600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                     CIRCLE K            DRIVING UNDER THE INFL-
# 3    COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                 KIRK / GERTY                 THEFT FROM COIN-OP
# ..                         ...                                ...
# 877    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 878  IUB ADMINISTRATIVE SUITES                            THREATS
# 879        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 880      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 881   102 N GREGORY ST, URBANA                           BURGLARY
#
#                   Disposition  BlockId
# 0                      ARREST        0
# 1                      ARREST       14
# 2                      ARREST        0
# 3                      ARREST        9
# 4                ADMIN. CLOSE        0
# ..                        ...      ...
# 877  REPORTED TO OTHER AGENCY       25
# 878              ADMIN CLOSED       50
# 879              ADMIN. CLOSE        0
# 880              ADMIN. CLOSE        0
# 881  REPORTED TO OTHER AGENCY       36
#
# [7617 rows x 9 columns]

# %%
# csvData = pd.read_csv(csvFilePath+"\\"+csvName)
# listOfcsvDataColumns = list(csvData.columns)
# csvData

# %%
# Drop NaN rows
csvData = csvData.dropna()
csvData = csvData.reset_index(drop=True)

# Drop row which has "nan" value
for col in listOfcsvDataColumns:
    csvData = csvData[~csvData[col].isin(["nan", "UNKNOWN", "unknown", ""])]
    
# Replace certain characters from all of the dataframe
for col in listOfcsvDataColumns:
    csvData[col] = csvData[col].replace('\'','', regex=True)
    csvData[col] = csvData[col].replace('\"','', regex=True)

csvData
# Out:
#        Incident Date reported   Time reported Date occurred   Time occurred  \
# 0     II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1     II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2     II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3     II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4     II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ...         ...           ...             ...           ...             ...
# 7609  CC1909074      11/14/19            7:00      11/14/19            2:37
# 7610  IF1901488      11/14/19           16:56      11/14/19           16:56
# 7611  II1901441      11/14/19           16:52      11/14/19           16:00
# 7612  II1901442      11/14/19           20:10      11/14/19           20:05
# 7613  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#                General Location                  Crime Description  \
# 0      500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1            600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                      CIRCLE K            DRIVING UNDER THE INFL-
# 3     COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                  KIRK / GERTY                 THEFT FROM COIN-OP
# ...                         ...                                ...
# 7609    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 7610  IUB ADMINISTRATIVE SUITES                            THREATS
# 7611        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 7612      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 7613   102 N GREGORY ST, URBANA                           BURGLARY
#
#                    Disposition  BlockId
# 0                       ARREST        0
# 1                       ARREST       14
# 2                       ARREST        0
# 3                       ARREST        9
# 4                 ADMIN. CLOSE        0
# ...                        ...      ...
# 7609  REPORTED TO OTHER AGENCY       25
# 7610              ADMIN CLOSED       50
# 7611              ADMIN. CLOSE        0
# 7612              ADMIN. CLOSE        0
# 7613  REPORTED TO OTHER AGENCY       36
#
# [7443 rows x 9 columns]

# %% [markdown]
# ## Flush the curated and compiled data into CSV

# %%
#Flush the dataframe to CSV file

processedDatasetCSVName = "processedDatset.csv"
    
csvData.to_csv(csvFilePath+"\\"+processedDatasetCSVName, encoding='utf-8', index=False)

# %% [markdown]
# # Create CrimeType CSV

# %%
#Get unique types of crime
crimeTypeSet = set()
for x in csvData["Crime Description"]:
    crimeTypeSet.add(x.upper().strip())
crimeTypeList = list(crimeTypeSet)
crimeTypeSet
# Out:
# {'ABANDONED JUNK VEHICLES',
#  'ACCIDENT HIT AND RUN',
#  'ACCIDENT INVOLVING NON-INJURY',
#  'ACCIDENT INVOLVING OTHER CITY PROP',
#  'ACCIDENT INVOLVING PEDESTRIAN',
#  'ACCIDENT W/NON-VEH PROP DAMAGE',
#  'ADULT RESPONSIBILITY',
#  'AGG AGASSULT',
#  'AGG ASSAULT',
#  'AGG BATTERY',
#  'AGG DISCHARGE OF FIREARM',
#  'AGG FLEE/ATTEMPT ELUDE OFFICER',
#  'AGGR UNLAWFUL USE OF WEAPON',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATED BATTERY',
#  'AGGRAVATGED ASSAULT',
#  'ALCOHO/LIQ MINOR PRESENT/TEEN EVENT',
#  'ALCOHOL',
#  'ALCOHOL/LIQ SALES INTOX SUBJ OR',
#  'ALCOHOL/LIQUOR BASSET LICENSE REQ',
#  'ALCOHOL/LIQUOR CONSUMPTION EMPLOYEE',
#  'ALCOHOL/LIQUOR LICENSE REQUIRED',
#  'ALCOHOL/LIQUOR SERVER NAME TAG REQ',
#  'ALLOWING A NUISANCE PARTY',
#  'ARMED VIOLENCE',
#  'ARSON',
#  'ASSAULT',
#  'ASSAULT-AGGRAVATED',
#  'ASSIST ATT BURG F/MV',
#  'ASSIST BATTERY',
#  'ASSIST CCSO',
#  'ASSIST CCSO TRAF STOP',
#  'ASSIST CCSO W/ARMED SUBJECT',
#  'ASSIST CCSO W/BMV',
#  'ASSIST CCSO W/K-9',
#  'ASSIST CCSO W/TRAFFIC STOP',
#  'ASSIST CCSO W/TRANSLATION',
#  'ASSIST COUNTY PD W/K9 SWEEP',
#  'ASSIST COUNTY POLICE',
#  'ASSIST COUNTY POLICE W/ARMED SUBJ',
#  'ASSIST CPD',
#  'ASSIST CPD ROBBERY',
#  'ASSIST CPD W/ARMED SUBJECT',
#  'ASSIST CPD W/BANK ROBBERY',
#  'ASSIST CPD W/BATTERY',
#  'ASSIST CPD W/K-9',
#  'ASSIST CPD W/MEDICAL',
#  'ASSIST CPD W/RETAIL THEFT',
#  'ASSIST CPD W/ROBBERY',
#  'ASSIST CPD W/SHOTS FIRED',
#  'ASSIST CPD W/THEFT',
#  'ASSIST CPD W/TRAFFIC STOP',
#  'ASSIST CPD WITH BATTERY',
#  'ASSIST CPD/ROBBERY',
#  'ASSIST DOMESTIC',
#  'ASSIST FIGHT',
#  'ASSIST ISP W/SEARCH',
#  'ASSIST K-9',
#  'ASSIST K9',
#  'ASSIST K9 SEARCH',
#  'ASSIST OTHER GOVT AGENCY/EOD',
#  'ASSIST OTHER PD',
#  'ASSIST OTHER POLICE DEPT',
#  'ASSIST PD W/ACCIDENT',
#  'ASSIST ROBBERY',
#  'ASSIST SICK & INJURED',
#  'ASSIST STATE POLICE',
#  'ASSIST STATE/ACCIDENT',
#  'ASSIST TOW TRUCK',
#  'ASSIST UIPD W/BATTERY',
#  'ASSIST UPD',
#  'ASSIST UPD ON ROBBERY',
#  'ASSIST UPD W/DETAIN SUBJECT',
#  'ASSIST UPD W/DISORDERLY',
#  'ASSIST UPD W/DOMESTIC',
#  'ASSIST UPD W/K-9',
#  'ASSIST UPD W/K9 SWEEP',
#  'ASSIST UPD W/RETAIL THEFT',
#  'ASSIST UPD W/ROBBERY',
#  'ASSIST UPD W/THEFT',
#  'ASSIST UPD WITH K-9',
#  'ASSIST UPD/SHOOTING',
#  'ASSIST URBANA THEFT',
#  'ASSIST W/K-9',
#  'ASSIST W/K9 SWEEP',
#  'ASSIST W/MENTAL HEALTH',
#  'ASSIST W/SEARCH WARRANT',
#  'ASSIST/ACCIDENT',
#  'ASSIST/ACCIDENT UPD',
#  'ASSIST/ARMED SUBJ',
#  'ASSIST/ARMED SUBJECT',
#  'ASSIST/BUILDING CHECK',
#  'ASSIST/BURGLARY',
#  'ASSIST/CHECK WELFARE',
#  'ASSIST/CPD WITH ACCIDENT',
#  'ASSIST/CRIMINAL DAMAGE',
#  'ASSIST/DISORDERLY SUBJ',
#  'ASSIST/DOMESTIC',
#  'ASSIST/DOMESTIC BATTERY',
#  'ASSIST/HARRESSMENT',
#  'ASSIST/K-9',
#  'ASSIST/K9',
#  'ASSIST/K9 SEARCH',
#  'ASSIST/NO TRESPASS',
#  'ASSIST/ROBBERY DETAIL',
#  'ASSIST/SEACH WARRANT',
#  'ASSIST/SEARCH SUBJ',
#  'ASSIST/SHOPLIFTER',
#  'ASSIST/SHOTS FIRED',
#  'ASSIST/STABBING',
#  'ASSIST/THEFT',
#  'ASSIST/TRAFFIC STOP',
#  'ASSIST/TRANSLATOR',
#  'ASSIST/U OF I FOUND PROPERTY',
#  'ASSIST/UNCOOPERATIVE SUBJ',
#  'ASST CPD/ARMED SUBJECT',
#  'ATTEMPTED RAPE',
#  'ATTEMPTED THEFT',
#  'BATTERY',
#  'BATTERY -CITY',
#  'BATTERY-AGG DOMESTIC',
#  'BATTERY-AGGRAVATED',
#  'BATTERY-DOMESTIC',
#  'BATTERY-DOMESTIC & LARCENY',
#  'BEGGERS PROHIBITED',
#  'BICYCLE VIOLATION',
#  'BIKE ENFORCEMENT',
#  'BIKE VIOLATION',
#  'BIKE VIOLATIONS',
#  'BOMB THREAT',
#  'BONFIRES PROHIBITED',
#  'BREATH ALCOHOL OVER LIMIT',
#  'BRINGING CONTRABAND INTO PENAL INST',
#  'BURGLARY',
#  'BURGLARY FROM MOTOR',
#  'BURGLARY FROM MOTOR VEHICLE',
#  'BURGLARY MOTOR VEH PARTS & ACCESS',
#  'BURGLARY OF MOTOR VEHICLE',
#  'BURGLARY RESIDENTIAL',
#  'BURNING PROHIBITED',
#  'CANINE SWEEP - IDOT',
#  'CANNABIS POSS 10 GM OR LESS -ORD',
#  'CANNABIS POSS 30 G AND UNDER - OLD',
#  'CANNABIS POSS MORE THAN 10 LESS',
#  'CANNABIS POSS OVER 10 - 100 G -MISD',
#  'CANNABIS POSS OVER 30 G - OLD',
#  'CANNABIS-DELIVERY 30GM &',
#  'CANNABIS-DELIVERY 30GM & UNDER',
#  'CANNABIS-DELIVERY OVER 30GM',
#  'CANNABIS-POSS 30 GM & UNDER',
#  'CANNABIS-POSSESSION OVER',
#  'CANNABIS-POSSESSION OVER 30GM',
#  'CARRYING ALCOHOL/LIQ OUT OF PREMISE',
#  'CARRYING OUT OF PREMISE',
#  'CHILD PORNOGRAPHY',
#  'COMPUTER FRAUD',
#  'COMPUTER TAMPERING',
#  'CONTRIBUTING CRIM DELINQUENCY JUV',
#  'CONTROLLED SUBSTANCE-',
#  'CONTROLLED SUBSTANCE-LOOK-ALIKE',
#  'CONTROLLED SUBSTANCE-MANUF-',
#  'CONTROLLED SUBSTANCE-MANUF-INTENT',
#  'CONTROLLED SUBSTANCE-POSS',
#  'CONTROLLED SUBSTANCE-POSS W/INTENT',
#  'CONTROLLED SUBSTANCE-POSSESSION',
#  'COUNTED STALKING UNDER C16-0886',
#  'CREDIT CARD FRAUD',
#  'CREDIT CARD FRAUD/FORGERY',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL DAMAGE GOVT',
#  'CRIMINAL DAMAGE GOVT SUPPORT',
#  'CRIMINAL DAMAGE GOVT SUPPORT PROP',
#  'CRIMINAL DAMAGE TO PROPERTY',
#  'CRIMINAL DEFACEMENT OF',
#  'CRIMINAL DEFACEMENT OF PROPERTY',
#  'CRISIS INTERVEN. - ALCOHOL',
#  'CRISIS INTERVEN. - OTHER',
#  'CRUELTY TO ANIMALS',
#  'CURFEW',
#  'CURFEW VIOLATION',
#  'CYBERSTALKING',
#  'DAMAGING PROPERTY',
#  'DATING VIOLENCE',
#  'DEATH INVESTIGATION/ASSIST UPD',
#  'DEC PRACTICE',
#  'DECEPT PRACT',
#  'DECEPT PRACTICE',
#  'DECEPTIVE PRACTCIES',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICES',
#  'DECEPTIVE PRACTICES/EXTORTION',
#  'DECEPTIVE PRACTICES/HARASSMENT BY T',
#  'DECP PRACTICE',
#  'DECPT PRACT',
#  'DECPT PRACTICE',
#  'DECPTIVE PRACTICE',
#  'DEFACING IDENTI.MARKS OF FIREARMS',
#  'DEL/MANUF CANNABIS OVER 30 G -FEL',
#  'DEL/MANUF CANNABIS UNDER 10 G -MISD',
#  'DEL/MANUF CANNABIS UNDER 30 G -',
#  'DEL/MANUF CANNABIS UNDER 30 G -MISD',
#  'DELIVERY CONTROLLED SUB',
#  'DELIVERY OF ALCOHOL/LIQ TO A MINOR',
#  'DEPETIVE PRACTICE/COUNTERFIT',
#  'DESTR/DAMAG/VAND',
#  'DIS CONDUCT',
#  'DISOBEY BIKE CODE',
#  'DISOBEY LIGHT (BIKE)',
#  'DISOBEY STOP',
#  'DISOBEY TRAFFIC (BIKE)',
#  'DISORDERLY',
#  'DISORDERLY CONDUCT',
#  'DISORDERLY CONDUCT-ALL',
#  'DISORDERLY CONDUCT-ALL OTHER',
#  'DISORDERLY SUBJECT',
#  'DISORDERLY/PANDELING',
#  'DISPOSAL ON PUBLIC WAYS',
#  'DOEMSTIC VIOLENCE',
#  'DOGS RUNNING AT LARGE',
#  'DOMESTIC',
#  'DOMESTIC - UNLAWFUL RESTRAINT',
#  'DOMESTIC BATTERY',
#  'DOMESTIC BATTERY/AGG ASSAULT',
#  'DOMESTIC BATTERY/UNLAWFUL',
#  'DOMESTIC DISPUTE',
#  'DOMESTIC DISPUTE - VERBAL ONLY',
#  'DOMESTIC OFFENSE',
#  'DOMESTIC VIOLENCE',
#  'DOMESTIC-INTERFERENCE WITH REPORT',
#  'DOMESTICE VIOLENCE',
#  'DRIVING UNDER INFLUENCE-',
#  'DRIVING UNDER INFLUENCE-DRUGS',
#  'DRIVING UNDER SUSPENDED LICENSE',
#  'DRIVING UNDER THE INFL-',
#  'DRIVING UNDER THE INFL-ALCOHOL',
#  'DRIVING UNDER THE INFLUENCE',
#  'DRUG',
#  'DRUG EQUIPMENT-POSSESSION',
#  'DRUG PARAPHERNALIA-SALE/DELIVERY',
#  'DRUGS',
#  'DRUGS - ILLEGAL TRANSPORTATION OF',
#  'DRUGS/LIQUOR',
#  'DRUGS; COUNTERFEIT MONEY',
#  'DUI',
#  'DUI - ALCOHOL',
#  'DUI - DRUGS',
#  'EAVESDROPPING',
#  'ELECTRICAL FIRE',
#  'ELECTRONIC HARASSMENT',
#  'ENDANG CHILD',
#  'ENDANG LIFE/HEALTH OF CHILD',
#  'EOD CALLOUT',
#  'EOD; ASSIST OTHER',
#  'EXCITED DELIRIUM',
#  'EXPIRED REGISTRATION',
#  'EXTORTION',
#  'FALSE FIRE ALARM',
#  'FALSE ID-POSS (MISC)',
#  'FALSE PERSONATION OF PEACE OFFICER',
#  'FALSE POLICE REPORT',
#  'FELONY - ARREST',
#  'FIGHT',
#  'FIGHT/DISORDERLY',
#  'FIGHTING',
#  'FIREWORKS',
#  'FLEEING/ELUDING',
#  'FONDLING',
#  'FORCIBLE SEX OFFENSE',
#  'FORGERY',
#  'FORGERY/CREDIT CARD FRAUD',
#  'FRAUD - DECEPTION',
#  'FRAUD-CREDIT CARD',
#  'FRAUD-DECEPTION',
#  'FRAUD/DECEPTION',
#  'FUGITIVE FROM JUSTICE',
#  'FURNISHING ALCOHOL TO MINOR',
#  'HARASS BY TX',
#  'HARASSMENT',
#  'HARASSMENT BY ELECTRONIC',
#  'HARASSMENT BY ELECTRONIC COMM',
#  'HARASSMENT BY ELECTRONIC COMMUNICAT',
#  'HARASSMENT BY TELEPHONE',
#  'HARASSMENT BY TX',
#  'HARBOURING A RUNAWAY',
#  'HARRASMENT BY ELECTRONIC',
#  'HARRASSMENT',
#  'HAZING',
#  'HAZING - FRAT/SORORITY',
#  'HEROIN OVERDOSE',
#  'HINDERING POLICE OFFCR',
#  'HIT AND RUN',
#  'HOME INVASION',
#  'HYPODERMIC NEEDLE/SYRINGE-',
#  'HYPODERMIC NEEDLE/SYRINGE-POSS/SALE',
#  'IDENTITY THEFT',
#  'ILLEGAL TRANSPORTATION OF LIQUOR',
#  'IMPOUNDED VEHICLE',
#  'IMPROPER LANE USAGE',
#  'IMPROPER LANE USAGE-ONE-WAY ST',
#  'IMPROPER USE OF SIGNAL',
#  'INDECENT EXPOSURE',
#  'INTIMIDATION',
#  'K9 ASSIST',
#  'K9 ASSIST CCSO',
#  'K9 ASSIST CPD',
#  'LARCENY',
#  'LEAVING SCENE PROPERTY DAMAGE',
#  'LEAVING THE SCENE OF AN ACCIDENT',
#  'LIQOUR',
#  'LIQUOR',
#  'LIQUOR - ADULT RESPONSIBILITY/UNDERAGE',
#  'LIQUOR - CARRYING IN PUBLIC PLACE',
#  'LIQUOR - ILLEGAL TRANSPORTATION',
#  'LIQUOR - OPEN ALCOHOL',
#  'LIQUOR - PUBLIC POSSESSION',
#  'LIQUOR - PUBLIC PROPERTY',
#  'LIQUOR - UNDERAGE',
#  'LIQUOR - UNDERAGE CONSUMPTION',
#  'LIQUOR-ILLEGAL CONSUMPTION',
#  'LIQUOR-ILLEGAL CONSUMPTION BY',
#  'LIQUOR-ILLEGAL CONSUMPTION BY MINOR',
#  'LIQUOR-ILLEGAL POSS. BY MINOR',
#  'LIQUOR-OPEN CONTAINER/PUBLIC PROP.',
#  'LIQUOR-PUBLIC PROP',
#  'LIQUOR-PURCH/POSS/CONSUMP BY',
#  'LIQUOR-PURCH/POSS/CONSUMP BY MINORS',
#  'LIQUOR-SALE TO MINORS,DRUNKS,ETC',
#  'LIQUOR-SALE TO MINORS/DRUNKARDS',
#  'LIQUOR-UNDERAGE',
#  'LIQUOR-UNDERAGE/PUBLIC POSSESSION',
#  'LIQUOR-UNDERAGE; DISORDERLY CONDUCT',
#  'LIQUOR-UNDERAGE; FIGHT',
#  'LIQUOR/THEFT',
#  'LOST ARTICLES',
#  'LOUD NOISE',
#  'MANUFACTURE CONTROLLED SUB',
#  'MENTAL CASE-TRANSPORTATION',
#  'METRO',
#  'METRO ACTIVATION',
#  'METRO/ASSIST OTHER',
#  'MINOR IN POSSESSION',
#  'MINOR PRESENT',
#  'MIP',
#  'MIP ALCOHOL/LIQUOR',
#  'MIP; POSS LIQUOR-PUBLIC PROP',
#  'MISSING PERSON',
#  'MISSING PERSON ADULT/FEMALE',
#  'MISSING PERSON ADULT/MALE',
#  'MOB ACTION',
#  'MOTOR VEHICLE THEFT',
#  'MURDER-FIRST DEGREE',
#  'MURDER/NON-NEG. MANSSL.',
#  'MUTUAL COMBATANTS',
#  'NARCOTICS UNIT',
#  'NO DRIVERS LICENSE',
#  'NO DRIVERS LICENSE; OPERATING',
#  'NO REAR REGISTRATION LIGHT',
#  'NOISE',
#  'NOISE & VIBRATIONS',
#  'NOISE PROHIBITED',
#  'NOISE PROHIBITION',
#  'NOISE VIOLATION',
#  'NON-FORCIBLE SEX OFFENSE',
#  'OBSTRUCTIN JUSTICE',
#  'OBSTRUCTING IDENTIFICATION',
#  'OBSTRUCTING JUSTICE',
#  'OFFICIAL MISCONDUCT',
#  'OPERATE UNINSURED MOTOR VEHICLE',
#  'OTHER CRIMINAL OFFENSES',
#  'OTHER EQUIPMENT VIOLATIONS',
#  'OTHER INVESTIGATION QUASI-CRIMINAL',
#  'OTHER MISC/CPD ORDINANCE',
#  'OTHER TROUBLE/INFO RPT',
#  'PANHANDLE',
#  'PEDESTRIAN STOPS',
#  'PEEPING TOM',
#  'PEEPING TOM (DISORDERLY CONDUCT)',
#  'PIMPING - PROMOTING PROSTITUTION',
#  'POSS ALCOHOL PUB PROP /',
#  'POSS ALCOHOL PUB PROP / PARKING',
#  'POSS ALCOHOL/LIQ PUBLIC PROP/PARKIN',
#  'POSS DRUG PARAPHERNALIA',
#  'POSS LIQUOR-PUBLIC PROP',
#  'POSS OF CANNABIS',
#  'POSS OF CANNABIS UNDER 10 GM &',
#  'POSS OF DRUG PARAPHENALIA',
#  'POSS OF DRUG PARAPHERNALIA -ORD',
#  'POSSESSION OF CANNABIS',
#  'POSSESSION OF DRUG PARAPHERNALIA',
#  'POSSESSION OF STOLEN FIREARM',
#  'POSSESSION OF STOLEN PROP',
#  'POSSESSION STOLEN PROPERTY',
#  'POSSESSION W/INTENT TO DELIVER',
#  'PREDATORY CRIM SEX ASSAULT OF CHILD',
#  'PUBLIC DRUNKENNEESS & TRESPASS',
#  'PUBLIC INDECENCY',
#  'PUBLIC INTOXICATION',
#  'PUBLIC POSSESSION',
#  'PUBLIC POSSESSION OF ALCOHOL',
#  'PUBLIC URINATION',
#  'PUBLIC URINATION (C)',
#  'PUBLIC URINATION-CITY',
#  'PURSE SNATCHING',
#  'RAPE',
#  'RECKLESS CONDUCT',
#  'RECKLESS DRIVING',
#  'RECOVERED PROPERTY ONLY',
#  'RECOVERED STOLEN VEHICLE',
#  'RESIST OBS OFC',
#  'RESIST OFFICER',
#  'RESIST/OBS CORRECT/POLICE/FIRE',
#  'RESIST/OBSTRUCT',
#  'RESIST/OBSTRUCT OFFICER',
#  'RESIST/OBSTRUCT/DISARM AN',
#  'RESIST/OBSTRUCT/DISARM AN OFFICER',
#  'RESIST/OBSTRUCT/DISARM OFFICER',
#  'RESISTING',
#  'RESISTING ARREST',
#  'RESISTING/OBSTR OFFICER',
#  'RESISTING/OBSTR. OFFICER',
#  'RESISTING/OBSTRUCTING',
#  'RETAIL THEFT',
#  'REVENGE PORNOGRAPHY',
#  'RIDING BIKE ON ROAD',
#  'ROBBERY',
#  'ROBBERY-AGGRAVATED',
#  'ROBBERY-ARMED',
#  'RUNAWAY - MINOR REQUIRE AUTH',
#  'RUNAWAY - MINOR REQUIRE AUTH INTER',
#  'SAFEKEEPING',
#  'SALE OF TOBACCO',
#  'SALES OF TOBACCO',
#  'SALES OF TOBACCO TO MINORS',
#  'SEARCH WARRANT',
#  'SEARCH WARRANT ASSIST',
#  'SEARCH WARRANT SERVICE',
#  'SEX HARASSMENT',
#  'SEX OFFENDER REGISTRATION',
#  'SEX OFFENDER-FAIL TO REGISTER',
#  'SEX OFFENSE',
#  'SEX OFFENSE, FORCIBLE',
#  'SEXUAL ABUSE-AGGRAVATED',
#  'SEXUAL ABUSE-CRIMINAL',
#  'SEXUAL ASSAULT',
#  'SEXUAL ASSAULT-AGG CRIMINAL',
#  'SEXUAL HARASSMENT',
#  'SEXUAL-ASSAULT-CRIMINAL',
#  'SIMPLE ASSAULT',
#  'SIMPLE BATTERY',
#  'SPECIFIC NOISE PROHIBITED',
#  'SPEEDING (RADAR)',
#  'SRO - YAC REFERRAL',
#  'STALKING',
#  'STALKING BY ELECTRONIC COMMUNICATIO',
#  'STALKING-AGGRAVATED',
#  'STALKING/CYBERSTALKING',
#  'STALKING/ELECTRONIC HARRASMENT',
#  'STATUTORY RAPE',
#  'STOLEN PROP RECOVERED',
#  'SUICIDAL SUBJECT',
#  'SUICIDE ATTEMPT/DRUGS',
#  'SUSPENDED LICENSE/WARRANT',
#  'SUSPICIOUS ACTIVITIES',
#  'TELEPHONE THREAT',
#  'TELEPHONE THREATS',
#  'TERRORISM-MAKE FALSE TERROR',
#  'TERRORIST THREATS',
#  'THEFT',
#  'THEFT $500 AND UNDER',
#  'THEFT BY LESSEE',
#  'THEFT FROM BUILDING',
#  'THEFT FROM COIN-OP',
#  'THEFT FROM COIN-OP MACHINE/DEVICE',
#  'THEFT FROM MOTOR VEHICLE',
#  'THEFT GENERALLY',
#  'THEFT OF LOST/MISLAID PROP',
#  'THEFT OF LOST/MISLAID PROPERTY',
#  'THEFT OF MOTOR VEH PARTS &',
#  'THEFT OF MOTOR VEH PARTS & ACCESS',
#  'THEFT OF SERVICES',
#  'THEFT OVER',
#  'THEFT OVER $500',
#  'THEFT UNDER',
#  'THEFT-CITY',
#  'THEFT-IDENTITY',
#  'THEFT-LABOR OR SERVICES',
#  'THEFT-LOST/MISLAID PROPERTY',
#  'THEFT-MOTOR VEHICLE',
#  'THEFT-RETAIL',
#  'THEFT-RETAIL-CITY',
#  'THEFT/DECCEPTION',
#  'THREATS',
#  'THROW DANG MATERIAL',
#  'THROW DANG MATERIALS',
#  'THROW DANGEROUS MATERIAL',
#  'THROW DANGEROUS MATERIALS',
#  'THROWING DANGEROUS',
#  'THROWING DANGEROUS MATERIALS',
#  'THROWING ITEMS',
#  'TRAFFIC',
#  'TRAFFIC CITATION/VOP',
#  'TRAFFIC CITATIONS',
#  'TRAFFIC OFFENSE',
#  'TRAFFIC SIGN VIOLATION',
#  'TRAFFIC STOP',
#  'TRANSIENT MERCHANT/LICENSE REQUIRED',
#  'TRANSPORTING ALCOHOL/LIQ IN VEHICLE',
#  'TREPASS',
#  'TRESPASS',
#  'TRESPASS LAND',
#  'TRESPASS NOTICE',
#  'TRESPASS TO HOME',
#  'TRESPASS TO LAND/REAL PROPERTY',
#  'TRESPASS TO PROPERTY',
#  'TRESPASS TO RESIDENCE',
#  'TRESPASS-RESIDENCE',
#  'TRESPASS-STATE SUPPORTED',
#  'TRESPASS-STATE SUPPORTED LAND',
#  'TRESPASS-VEHICLE',
#  'TRESPASS/RESISTING ARREST',
#  'TRESPASSIN',
#  'TRESPASSING',
#  'UNAUTHORIZED ENTRY',
#  'UNAUTHORIZED VIDEOTAPING/LIVE VIDEO',
#  'UNLAW USE ID',
#  'UNLAWFUL POSS FIREARM & AMMUNITION',
#  'UNLAWFUL POSS/USE WEAPON BY',
#  'UNLAWFUL POSS/USE WEAPON BY FELON',
#  'UNLAWFUL POSSESSION OF ID',
#  'UNLAWFUL RESTRAINT',
#  'UNLAWFUL RESTRAINT-AGGRAVATED',
#  'UNLAWFUL TRESPASS',
#  'UNLAWFUL USE ID',
#  'UNLAWFUL USE OF I.D.',
#  'UNLAWFUL USE OF ID',
#  'UNLAWFUL USE OF WEAPONS',
#  'UPD ACCIDENT (FATAL)',
#  'USE OF FORCE BY OFFICER',
#  'VANDALISM-INSTITUTIONAL',
#  'VEHICULAR NOISE',
#  'VERBAL DISPUTE',
#  'VERBAL DOMESTIC',
#  'VIOL BAIL BOND',
#  'VIOLATION OF ORDER OF PROTECTION',
#  'VIOLATION OF ORDER PROTECTION',
#  'VIOLATION ORDER PROTECTION',
#  'VISITATION INTERFERENCE',
#  'VOOP',
#  'WARRANT',
#  'WARRANT ARREST',
#  'WARRANT ARREST/TRAFFIC CITATIONS',
#  'WARRANT-IN STATE',
#  'WARRANT-OUT OF STATE',
#  'WEAPON',
#  'ZERO TOLERANCE'}

# %%
#Convert the set of crime types into a list of dictionary
crimeTypeListOfDicts = []
crimeTypeStartIndex = 300
for type in crimeTypeList:
    crimeTypeDict = {}
    crimeTypeDict["crimeTypeID"] = crimeTypeStartIndex
    crimeTypeDict["type"] = type
    crimeTypeStartIndex += 1
    crimeTypeListOfDicts.append(crimeTypeDict)
crimeTypeListOfDicts
# Out:
# [{'crimeTypeID': 300, 'type': 'DECPTIVE PRACTICE'},
#  {'crimeTypeID': 301, 'type': 'ASSIST COUNTY POLICE W/ARMED SUBJ'},
#  {'crimeTypeID': 302, 'type': 'ASSIST/DISORDERLY SUBJ'},
#  {'crimeTypeID': 303, 'type': 'POSS OF DRUG PARAPHERNALIA -ORD'},
#  {'crimeTypeID': 304, 'type': 'ASSIST CCSO W/ARMED SUBJECT'},
#  {'crimeTypeID': 305, 'type': 'LIQUOR-UNDERAGE'},
#  {'crimeTypeID': 306, 'type': 'DOMESTIC VIOLENCE'},
#  {'crimeTypeID': 307, 'type': 'SEXUAL ABUSE-AGGRAVATED'},
#  {'crimeTypeID': 308, 'type': 'DECEPTIVE PRACTICES/EXTORTION'},
#  {'crimeTypeID': 309, 'type': 'VERBAL DOMESTIC'},
#  {'crimeTypeID': 310, 'type': 'DATING VIOLENCE'},
#  {'crimeTypeID': 311, 'type': 'ASSIST CCSO W/TRANSLATION'},
#  {'crimeTypeID': 312, 'type': 'RESISTING/OBSTR. OFFICER'},
#  {'crimeTypeID': 313, 'type': 'LIQUOR - UNDERAGE'},
#  {'crimeTypeID': 314, 'type': 'COUNTED STALKING UNDER C16-0886'},
#  {'crimeTypeID': 315, 'type': 'DISOBEY BIKE CODE'},
#  {'crimeTypeID': 316, 'type': 'INDECENT EXPOSURE'},
#  {'crimeTypeID': 317, 'type': 'AGG AGASSULT'},
#  {'crimeTypeID': 318, 'type': 'ELECTRONIC HARASSMENT'},
#  {'crimeTypeID': 319, 'type': 'ASSIST/THEFT'},
#  {'crimeTypeID': 320, 'type': 'TREPASS'},
#  {'crimeTypeID': 321, 'type': 'MENTAL CASE-TRANSPORTATION'},
#  {'crimeTypeID': 322, 'type': 'VIOLATION OF ORDER PROTECTION'},
#  {'crimeTypeID': 323, 'type': 'BIKE VIOLATION'},
#  {'crimeTypeID': 324, 'type': 'THEFT-LOST/MISLAID PROPERTY'},
#  {'crimeTypeID': 325, 'type': 'ASSIST CCSO'},
#  {'crimeTypeID': 326, 'type': 'SEX OFFENSE, FORCIBLE'},
#  {'crimeTypeID': 327, 'type': 'DEATH INVESTIGATION/ASSIST UPD'},
#  {'crimeTypeID': 328, 'type': 'AGGRAVATED BATTERY'},
#  {'crimeTypeID': 329, 'type': 'ASSIST/U OF I FOUND PROPERTY'},
#  {'crimeTypeID': 330, 'type': 'TRESPASSING'},
#  {'crimeTypeID': 331, 'type': 'CONTROLLED SUBSTANCE-'},
#  {'crimeTypeID': 332, 'type': 'RECKLESS DRIVING'},
#  {'crimeTypeID': 333, 'type': 'TRAFFIC OFFENSE'},
#  {'crimeTypeID': 334, 'type': 'FALSE PERSONATION OF PEACE OFFICER'},
#  {'crimeTypeID': 335, 'type': 'THEFT UNDER'},
#  {'crimeTypeID': 336, 'type': 'AGGR UNLAWFUL USE OF WEAPON'},
#  {'crimeTypeID': 337, 'type': 'POSSESSION W/INTENT TO DELIVER'},
#  {'crimeTypeID': 338, 'type': 'RESISTING/OBSTR OFFICER'},
#  {'crimeTypeID': 339, 'type': 'TRESPASS LAND'},
#  {'crimeTypeID': 340, 'type': 'POSS ALCOHOL PUB PROP / PARKING'},
#  {'crimeTypeID': 341, 'type': 'ASSIST CPD W/BATTERY'},
#  {'crimeTypeID': 342, 'type': 'TRESPASS-STATE SUPPORTED LAND'},
#  {'crimeTypeID': 343, 'type': 'TRESPASS-VEHICLE'},
#  {'crimeTypeID': 344, 'type': 'ASSIST UPD W/K-9'},
#  {'crimeTypeID': 345, 'type': 'ASSIST/CRIMINAL DAMAGE'},
#  {'crimeTypeID': 346, 'type': 'DRUGS/LIQUOR'},
#  {'crimeTypeID': 347, 'type': 'PEEPING TOM (DISORDERLY CONDUCT)'},
#  {'crimeTypeID': 348, 'type': 'PUBLIC URINATION-CITY'},
#  {'crimeTypeID': 349, 'type': 'ILLEGAL TRANSPORTATION OF LIQUOR'},
#  {'crimeTypeID': 350, 'type': 'ASSIST/TRANSLATOR'},
#  {'crimeTypeID': 351, 'type': 'ACCIDENT HIT AND RUN'},
#  {'crimeTypeID': 352, 'type': 'CANNABIS-DELIVERY OVER 30GM'},
#  {'crimeTypeID': 353, 'type': 'ASSIST COUNTY PD W/K9 SWEEP'},
#  {'crimeTypeID': 354, 'type': 'CARRYING ALCOHOL/LIQ OUT OF PREMISE'},
#  {'crimeTypeID': 355, 'type': 'ASSIST UPD W/DETAIN SUBJECT'},
#  {'crimeTypeID': 356, 'type': 'RESIST OBS OFC'},
#  {'crimeTypeID': 357, 'type': 'DOMESTIC DISPUTE'},
#  {'crimeTypeID': 358, 'type': 'VIOLATION ORDER PROTECTION'},
#  {'crimeTypeID': 359, 'type': 'ASSIST CPD ROBBERY'},
#  {'crimeTypeID': 360, 'type': 'ASSIST CPD'},
#  {'crimeTypeID': 361, 'type': 'ALCOHOL/LIQ SALES INTOX SUBJ OR'},
#  {'crimeTypeID': 362, 'type': 'PREDATORY CRIM SEX ASSAULT OF CHILD'},
#  {'crimeTypeID': 363, 'type': 'THEFT-MOTOR VEHICLE'},
#  {'crimeTypeID': 364, 'type': 'STALKING/ELECTRONIC HARRASMENT'},
#  {'crimeTypeID': 365, 'type': 'DESTR/DAMAG/VAND'},
#  {'crimeTypeID': 366, 'type': 'BATTERY-AGG DOMESTIC'},
#  {'crimeTypeID': 367, 'type': 'ASSIST W/MENTAL HEALTH'},
#  {'crimeTypeID': 368, 'type': 'ASSIST/K9 SEARCH'},
#  {'crimeTypeID': 369, 'type': 'THEFT OF LOST/MISLAID PROP'},
#  {'crimeTypeID': 370, 'type': 'ATTEMPTED THEFT'},
#  {'crimeTypeID': 371, 'type': 'HEROIN OVERDOSE'},
#  {'crimeTypeID': 372, 'type': 'NARCOTICS UNIT'},
#  {'crimeTypeID': 373, 'type': 'PEEPING TOM'},
#  {'crimeTypeID': 374, 'type': 'AGG FLEE/ATTEMPT ELUDE OFFICER'},
#  {'crimeTypeID': 375, 'type': 'BURGLARY RESIDENTIAL'},
#  {'crimeTypeID': 376, 'type': 'DOMESTICE VIOLENCE'},
#  {'crimeTypeID': 377, 'type': 'DISORDERLY SUBJECT'},
#  {'crimeTypeID': 378, 'type': 'NOISE'},
#  {'crimeTypeID': 379, 'type': 'DRUGS - ILLEGAL TRANSPORTATION OF'},
#  {'crimeTypeID': 380, 'type': 'ASSIST TOW TRUCK'},
#  {'crimeTypeID': 381, 'type': 'ASSIST FIGHT'},
#  {'crimeTypeID': 382, 'type': 'ASSIST/UNCOOPERATIVE SUBJ'},
#  {'crimeTypeID': 383, 'type': 'FIGHT/DISORDERLY'},
#  {'crimeTypeID': 384, 'type': 'TRAFFIC SIGN VIOLATION'},
#  {'crimeTypeID': 385, 'type': 'UNLAWFUL USE ID'},
#  {'crimeTypeID': 386, 'type': 'FRAUD - DECEPTION'},
#  {'crimeTypeID': 387, 'type': 'BATTERY'},
#  {'crimeTypeID': 388, 'type': 'DECEPTIVE PRACTICE'},
#  {'crimeTypeID': 389, 'type': 'DUI - DRUGS'},
#  {'crimeTypeID': 390, 'type': 'WARRANT'},
#  {'crimeTypeID': 391, 'type': 'ALCOHO/LIQ MINOR PRESENT/TEEN EVENT'},
#  {'crimeTypeID': 392, 'type': 'DISORDERLY/PANDELING'},
#  {'crimeTypeID': 393, 'type': 'ROBBERY'},
#  {'crimeTypeID': 394, 'type': 'BURGLARY'},
#  {'crimeTypeID': 395, 'type': 'ASSIST/K9'},
#  {'crimeTypeID': 396, 'type': 'RESIST/OBSTRUCT'},
#  {'crimeTypeID': 397, 'type': 'RESIST/OBSTRUCT OFFICER'},
#  {'crimeTypeID': 398, 'type': 'LOUD NOISE'},
#  {'crimeTypeID': 399, 'type': 'ASSAULT-AGGRAVATED'},
#  {'crimeTypeID': 400, 'type': 'DOMESTIC OFFENSE'},
#  {'crimeTypeID': 401, 'type': 'ASSIST URBANA THEFT'},
#  {'crimeTypeID': 402, 'type': 'BURGLARY FROM MOTOR VEHICLE'},
#  {'crimeTypeID': 403, 'type': 'CURFEW'},
#  {'crimeTypeID': 404, 'type': 'MUTUAL COMBATANTS'},
#  {'crimeTypeID': 405, 'type': 'DUI'},
#  {'crimeTypeID': 406, 'type': 'UNLAWFUL USE OF ID'},
#  {'crimeTypeID': 407, 'type': 'TRESPASS TO PROPERTY'},
#  {'crimeTypeID': 408, 'type': 'DECEPT PRACTICE'},
#  {'crimeTypeID': 409, 'type': 'ASSIST BATTERY'},
#  {'crimeTypeID': 410, 'type': 'BIKE VIOLATIONS'},
#  {'crimeTypeID': 411, 'type': 'ALCOHOL/LIQUOR BASSET LICENSE REQ'},
#  {'crimeTypeID': 412, 'type': 'HARRASSMENT'},
#  {'crimeTypeID': 413, 'type': 'DOMESTIC-INTERFERENCE WITH REPORT'},
#  {'crimeTypeID': 414, 'type': 'NOISE & VIBRATIONS'},
#  {'crimeTypeID': 415, 'type': 'WARRANT ARREST'},
#  {'crimeTypeID': 416, 'type': 'CRIMINAL DAMAGE GOVT SUPPORT'},
#  {'crimeTypeID': 417, 'type': 'ALCOHOL'},
#  {'crimeTypeID': 418, 'type': 'CREDIT CARD FRAUD'},
#  {'crimeTypeID': 419, 'type': 'CHILD PORNOGRAPHY'},
#  {'crimeTypeID': 420, 'type': 'ABANDONED JUNK VEHICLES'},
#  {'crimeTypeID': 421, 'type': 'THEFT-LABOR OR SERVICES'},
#  {'crimeTypeID': 422, 'type': 'FORGERY/CREDIT CARD FRAUD'},
#  {'crimeTypeID': 423, 'type': 'POSSESSION OF STOLEN PROP'},
#  {'crimeTypeID': 424, 'type': 'DOEMSTIC VIOLENCE'},
#  {'crimeTypeID': 425, 'type': 'SALES OF TOBACCO TO MINORS'},
#  {'crimeTypeID': 426, 'type': 'ASSIST CCSO W/K-9'},
#  {'crimeTypeID': 427, 'type': 'RESISTING'},
#  {'crimeTypeID': 428, 'type': 'ASSIST SICK & INJURED'},
#  {'crimeTypeID': 429, 'type': 'THEFT FROM COIN-OP MACHINE/DEVICE'},
#  {'crimeTypeID': 430, 'type': 'ASSIST CPD W/SHOTS FIRED'},
#  {'crimeTypeID': 431, 'type': 'ASSIST/DOMESTIC BATTERY'},
#  {'crimeTypeID': 432, 'type': 'ARMED VIOLENCE'},
#  {'crimeTypeID': 433, 'type': 'POSS OF CANNABIS UNDER 10 GM &'},
#  {'crimeTypeID': 434, 'type': 'ASSIST CPD W/THEFT'},
#  {'crimeTypeID': 435, 'type': 'VISITATION INTERFERENCE'},
#  {'crimeTypeID': 436, 'type': 'VIOL BAIL BOND'},
#  {'crimeTypeID': 437, 'type': 'ACCIDENT INVOLVING NON-INJURY'},
#  {'crimeTypeID': 438, 'type': 'ACCIDENT W/NON-VEH PROP DAMAGE'},
#  {'crimeTypeID': 439, 'type': 'ASSIST CPD W/ROBBERY'},
#  {'crimeTypeID': 440, 'type': 'MIP ALCOHOL/LIQUOR'},
#  {'crimeTypeID': 441, 'type': 'ALCOHOL/LIQUOR SERVER NAME TAG REQ'},
#  {'crimeTypeID': 442, 'type': 'SUSPICIOUS ACTIVITIES'},
#  {'crimeTypeID': 443, 'type': 'STALKING'},
#  {'crimeTypeID': 444, 'type': 'WEAPON'},
#  {'crimeTypeID': 445, 'type': 'SEX HARASSMENT'},
#  {'crimeTypeID': 446, 'type': 'FRAUD/DECEPTION'},
#  {'crimeTypeID': 447, 'type': 'SPECIFIC NOISE PROHIBITED'},
#  {'crimeTypeID': 448, 'type': 'METRO/ASSIST OTHER'},
#  {'crimeTypeID': 449, 'type': 'SEARCH WARRANT ASSIST'},
#  {'crimeTypeID': 450, 'type': 'LIQUOR/THEFT'},
#  {'crimeTypeID': 451, 'type': 'THROWING ITEMS'},
#  {'crimeTypeID': 452, 'type': 'MURDER/NON-NEG. MANSSL.'},
#  {'crimeTypeID': 453, 'type': 'LIQUOR - PUBLIC PROPERTY'},
#  {'crimeTypeID': 454, 'type': 'UNLAW USE ID'},
#  {'crimeTypeID': 455, 'type': 'ASSIST/SHOPLIFTER'},
#  {'crimeTypeID': 456, 'type': 'TRAFFIC CITATIONS'},
#  {'crimeTypeID': 457, 'type': 'SEXUAL ASSAULT'},
#  {'crimeTypeID': 458, 'type': 'PUBLIC POSSESSION'},
#  {'crimeTypeID': 459, 'type': 'DECPT PRACT'},
#  {'crimeTypeID': 460, 'type': 'RIDING BIKE ON ROAD'},
#  {'crimeTypeID': 461, 'type': 'CRIMINAL DAMAGE TO PROPERTY'},
#  {'crimeTypeID': 462, 'type': 'TRAFFIC'},
#  {'crimeTypeID': 463, 'type': 'AGG BATTERY'},
#  {'crimeTypeID': 464, 'type': 'THEFT OF LOST/MISLAID PROPERTY'},
#  {'crimeTypeID': 465, 'type': 'THEFT FROM BUILDING'},
#  {'crimeTypeID': 466, 'type': 'STALKING/CYBERSTALKING'},
#  {'crimeTypeID': 467, 'type': 'TRESPASS TO RESIDENCE'},
#  {'crimeTypeID': 468, 'type': 'THROW DANGEROUS MATERIAL'},
#  {'crimeTypeID': 469, 'type': 'MURDER-FIRST DEGREE'},
#  {'crimeTypeID': 470, 'type': 'LOST ARTICLES'},
#  {'crimeTypeID': 471, 'type': 'DEL/MANUF CANNABIS OVER 30 G -FEL'},
#  {'crimeTypeID': 472, 'type': 'UNLAWFUL USE OF WEAPONS'},
#  {'crimeTypeID': 473, 'type': 'ASSIST CPD W/ARMED SUBJECT'},
#  {'crimeTypeID': 474, 'type': 'DRIVING UNDER INFLUENCE-'},
#  {'crimeTypeID': 475, 'type': 'HARASSMENT BY TELEPHONE'},
#  {'crimeTypeID': 476, 'type': 'POSS ALCOHOL PUB PROP /'},
#  {'crimeTypeID': 477, 'type': 'TRESPASS-STATE SUPPORTED'},
#  {'crimeTypeID': 478, 'type': 'USE OF FORCE BY OFFICER'},
#  {'crimeTypeID': 479, 'type': 'MISSING PERSON ADULT/FEMALE'},
#  {'crimeTypeID': 480, 'type': 'THROW DANG MATERIALS'},
#  {'crimeTypeID': 481, 'type': 'ASSIST UPD W/DOMESTIC'},
#  {'crimeTypeID': 482, 'type': 'PIMPING - PROMOTING PROSTITUTION'},
#  {'crimeTypeID': 483, 'type': 'PUBLIC DRUNKENNEESS & TRESPASS'},
#  {'crimeTypeID': 484, 'type': 'HARASSMENT BY ELECTRONIC COMM'},
#  {'crimeTypeID': 485, 'type': 'ASSIST CCSO W/TRAFFIC STOP'},
#  {'crimeTypeID': 486, 'type': 'ATTEMPTED RAPE'},
#  {'crimeTypeID': 487, 'type': 'DECEPTIVE PRACTICES/HARASSMENT BY T'},
#  {'crimeTypeID': 488, 'type': 'EOD CALLOUT'},
#  {'crimeTypeID': 489, 'type': 'DRUG PARAPHERNALIA-SALE/DELIVERY'},
#  {'crimeTypeID': 490, 'type': 'RECOVERED STOLEN VEHICLE'},
#  {'crimeTypeID': 491, 'type': 'CONTROLLED SUBSTANCE-LOOK-ALIKE'},
#  {'crimeTypeID': 492, 'type': 'CONTROLLED SUBSTANCE-MANUF-INTENT'},
#  {'crimeTypeID': 493, 'type': 'FRAUD-DECEPTION'},
#  {'crimeTypeID': 494, 'type': 'EOD; ASSIST OTHER'},
#  {'crimeTypeID': 495, 'type': 'ASSIST STATE POLICE'},
#  {'crimeTypeID': 496, 'type': 'POSSESSION STOLEN PROPERTY'},
#  {'crimeTypeID': 497, 'type': 'OBSTRUCTIN JUSTICE'},
#  {'crimeTypeID': 498, 'type': 'VERBAL DISPUTE'},
#  {'crimeTypeID': 499, 'type': 'DEPETIVE PRACTICE/COUNTERFIT'},
#  {'crimeTypeID': 500, 'type': 'PURSE SNATCHING'},
#  {'crimeTypeID': 501, 'type': 'DRIVING UNDER THE INFLUENCE'},
#  {'crimeTypeID': 502, 'type': 'UNAUTHORIZED VIDEOTAPING/LIVE VIDEO'},
#  {'crimeTypeID': 503, 'type': 'BEGGERS PROHIBITED'},
#  {'crimeTypeID': 504, 'type': 'DELIVERY OF ALCOHOL/LIQ TO A MINOR'},
#  {'crimeTypeID': 505, 'type': 'THEFT GENERALLY'},
#  {'crimeTypeID': 506, 'type': 'RESIST/OBSTRUCT/DISARM AN'},
#  {'crimeTypeID': 507, 'type': 'MINOR IN POSSESSION'},
#  {'crimeTypeID': 508, 'type': 'CREDIT CARD FRAUD/FORGERY'},
#  {'crimeTypeID': 509, 'type': 'DISOBEY LIGHT (BIKE)'},
#  {'crimeTypeID': 510, 'type': 'ASSIST PD W/ACCIDENT'},
#  {'crimeTypeID': 511, 'type': 'PUBLIC URINATION'},
#  {'crimeTypeID': 512, 'type': 'THEFT $500 AND UNDER'},
#  {'crimeTypeID': 513, 'type': 'FRAUD-CREDIT CARD'},
#  {'crimeTypeID': 514, 'type': 'ASSIST CPD W/K-9'},
#  {'crimeTypeID': 515, 'type': 'TRESPASS-RESIDENCE'},
#  {'crimeTypeID': 516, 'type': 'RUNAWAY - MINOR REQUIRE AUTH'},
#  {'crimeTypeID': 517, 'type': 'EXPIRED REGISTRATION'},
#  {'crimeTypeID': 518, 'type': 'MIP; POSS LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 519, 'type': 'SALE OF TOBACCO'},
#  {'crimeTypeID': 520, 'type': 'POSSESSION OF DRUG PARAPHERNALIA'},
#  {'crimeTypeID': 521, 'type': 'OTHER INVESTIGATION QUASI-CRIMINAL'},
#  {'crimeTypeID': 522, 'type': 'FLEEING/ELUDING'},
#  {'crimeTypeID': 523, 'type': 'K9 ASSIST CPD'},
#  {'crimeTypeID': 524, 'type': 'PANHANDLE'},
#  {'crimeTypeID': 525, 'type': 'ASSIST/SHOTS FIRED'},
#  {'crimeTypeID': 526, 'type': 'METRO ACTIVATION'},
#  {'crimeTypeID': 527, 'type': 'FONDLING'},
#  {'crimeTypeID': 528, 'type': 'HYPODERMIC NEEDLE/SYRINGE-'},
#  {'crimeTypeID': 529, 'type': 'MANUFACTURE CONTROLLED SUB'},
#  {'crimeTypeID': 530, 'type': 'FORGERY'},
#  {'crimeTypeID': 531, 'type': 'EAVESDROPPING'},
#  {'crimeTypeID': 532, 'type': 'RETAIL THEFT'},
#  {'crimeTypeID': 533, 'type': 'DECEPTIVE PRACTICES'},
#  {'crimeTypeID': 534, 'type': 'LIQUOR - UNDERAGE CONSUMPTION'},
#  {'crimeTypeID': 535, 'type': 'TELEPHONE THREAT'},
#  {'crimeTypeID': 536, 'type': 'DOMESTIC BATTERY/AGG ASSAULT'},
#  {'crimeTypeID': 537, 'type': 'OBSTRUCTING JUSTICE'},
#  {'crimeTypeID': 538, 'type': 'SEX OFFENSE'},
#  {'crimeTypeID': 539, 'type': 'DEL/MANUF CANNABIS UNDER 30 G -'},
#  {'crimeTypeID': 540, 'type': 'ASSIST STATE/ACCIDENT'},
#  {'crimeTypeID': 541, 'type': 'PEDESTRIAN STOPS'},
#  {'crimeTypeID': 542, 'type': 'LIQUOR-ILLEGAL CONSUMPTION BY MINOR'},
#  {'crimeTypeID': 543, 'type': 'THROW DANGEROUS MATERIALS'},
#  {'crimeTypeID': 544, 'type': 'ASSIST/SEARCH SUBJ'},
#  {'crimeTypeID': 545, 'type': 'THEFT-RETAIL'},
#  {'crimeTypeID': 546, 'type': 'BOMB THREAT'},
#  {'crimeTypeID': 547, 'type': 'OPERATE UNINSURED MOTOR VEHICLE'},
#  {'crimeTypeID': 548, 'type': 'ASSIST CPD W/RETAIL THEFT'},
#  {'crimeTypeID': 549, 'type': 'TRESPASS TO HOME'},
#  {'crimeTypeID': 550, 'type': 'SALES OF TOBACCO'},
#  {'crimeTypeID': 551, 'type': 'LIQUOR - ILLEGAL TRANSPORTATION'},
#  {'crimeTypeID': 552, 'type': 'VEHICULAR NOISE'},
#  {'crimeTypeID': 553, 'type': 'ASSIST/HARRESSMENT'},
#  {'crimeTypeID': 554, 'type': 'CRUELTY TO ANIMALS'},
#  {'crimeTypeID': 555, 'type': 'FURNISHING ALCOHOL TO MINOR'},
#  {'crimeTypeID': 556, 'type': 'LIQUOR-SALE TO MINORS/DRUNKARDS'},
#  {'crimeTypeID': 557, 'type': 'THREATS'},
#  {'crimeTypeID': 558, 'type': 'LIQUOR-ILLEGAL CONSUMPTION'},
#  {'crimeTypeID': 559, 'type': 'HARASSMENT BY ELECTRONIC COMMUNICAT'},
#  {'crimeTypeID': 560, 'type': 'ALCOHOL/LIQUOR LICENSE REQUIRED'},
#  {'crimeTypeID': 561, 'type': 'ASSIST/DOMESTIC'},
#  {'crimeTypeID': 562, 'type': 'POSS LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 563, 'type': 'UNLAWFUL POSS FIREARM & AMMUNITION'},
#  {'crimeTypeID': 564, 'type': 'PUBLIC INTOXICATION'},
#  {'crimeTypeID': 565, 'type': 'HARASSMENT BY ELECTRONIC'},
#  {'crimeTypeID': 566, 'type': 'COMPUTER TAMPERING'},
#  {'crimeTypeID': 567, 'type': 'K9 ASSIST'},
#  {'crimeTypeID': 568, 'type': 'TRESPASSIN'},
#  {'crimeTypeID': 569, 'type': 'BIKE ENFORCEMENT'},
#  {'crimeTypeID': 570, 'type': 'RESIST OFFICER'},
#  {'crimeTypeID': 571, 'type': 'BURGLARY OF MOTOR VEHICLE'},
#  {'crimeTypeID': 572, 'type': 'POSSESSION OF CANNABIS'},
#  {'crimeTypeID': 573, 'type': 'FIGHTING'},
#  {'crimeTypeID': 574, 'type': 'MOTOR VEHICLE THEFT'},
#  {'crimeTypeID': 575, 'type': 'CRIMINAL DAMAGE GOVT'},
#  {'crimeTypeID': 576, 'type': 'ASSIST UIPD W/BATTERY'},
#  {'crimeTypeID': 577, 'type': 'RESIST/OBSTRUCT/DISARM AN OFFICER'},
#  {'crimeTypeID': 578, 'type': 'BATTERY-AGGRAVATED'},
#  {'crimeTypeID': 579, 'type': 'THEFT OVER'},
#  {'crimeTypeID': 580, 'type': 'CONTROLLED SUBSTANCE-POSS'},
#  {'crimeTypeID': 581, 'type': 'NO DRIVERS LICENSE; OPERATING'},
#  {'crimeTypeID': 582, 'type': 'AGG DISCHARGE OF FIREARM'},
#  {'crimeTypeID': 583, 'type': 'ASSIST UPD W/THEFT'},
#  {'crimeTypeID': 584, 'type': 'REVENGE PORNOGRAPHY'},
#  {'crimeTypeID': 585, 'type': 'ASSIST/SEACH WARRANT'},
#  {'crimeTypeID': 586, 'type': 'DAMAGING PROPERTY'},
#  {'crimeTypeID': 587, 'type': 'FUGITIVE FROM JUSTICE'},
#  {'crimeTypeID': 588, 'type': 'COMPUTER FRAUD'},
#  {'crimeTypeID': 589, 'type': 'IMPROPER LANE USAGE-ONE-WAY ST'},
#  {'crimeTypeID': 590, 'type': 'ROBBERY-ARMED'},
#  {'crimeTypeID': 591, 'type': 'MINOR PRESENT'},
#  {'crimeTypeID': 592, 'type': 'OTHER TROUBLE/INFO RPT'},
#  {'crimeTypeID': 593, 'type': 'CONTROLLED SUBSTANCE-POSSESSION'},
#  {'crimeTypeID': 594, 'type': 'SEXUAL-ASSAULT-CRIMINAL'},
#  {'crimeTypeID': 595, 'type': 'LIQUOR - CARRYING IN PUBLIC PLACE'},
#  {'crimeTypeID': 596, 'type': 'NOISE PROHIBITION'},
#  {'crimeTypeID': 597, 'type': 'CANNABIS-DELIVERY 30GM & UNDER'},
#  {'crimeTypeID': 598, 'type': 'LIQUOR - OPEN ALCOHOL'},
#  {'crimeTypeID': 599, 'type': 'ASSIST/TRAFFIC STOP'},
#  {'crimeTypeID': 600, 'type': 'MOB ACTION'},
#  {'crimeTypeID': 601, 'type': 'THEFT OF SERVICES'},
#  {'crimeTypeID': 602, 'type': 'CYBERSTALKING'},
#  {'crimeTypeID': 603, 'type': 'TRANSPORTING ALCOHOL/LIQ IN VEHICLE'},
#  {'crimeTypeID': 604, 'type': 'PUBLIC URINATION (C)'},
#  {'crimeTypeID': 605, 'type': 'DISOBEY TRAFFIC (BIKE)'},
#  {'crimeTypeID': 606, 'type': 'UNAUTHORIZED ENTRY'},
#  {'crimeTypeID': 607, 'type': 'DECPT PRACTICE'},
#  {'crimeTypeID': 608, 'type': 'DOMESTIC - UNLAWFUL RESTRAINT'},
#  {'crimeTypeID': 609, 'type': 'CONTRIBUTING CRIM DELINQUENCY JUV'},
#  {'crimeTypeID': 610, 'type': 'LIQUOR-SALE TO MINORS,DRUNKS,ETC'},
#  {'crimeTypeID': 611, 'type': 'DOGS RUNNING AT LARGE'},
#  {'crimeTypeID': 612, 'type': 'SUICIDE ATTEMPT/DRUGS'},
#  {'crimeTypeID': 613, 'type': 'NO REAR REGISTRATION LIGHT'},
#  {'crimeTypeID': 614, 'type': 'ADULT RESPONSIBILITY'},
#  {'crimeTypeID': 615, 'type': 'EXCITED DELIRIUM'},
#  {'crimeTypeID': 616, 'type': 'AGG ASSAULT'},
#  {'crimeTypeID': 617, 'type': 'THEFT FROM COIN-OP'},
#  {'crimeTypeID': 618, 'type': 'DRIVING UNDER SUSPENDED LICENSE'},
#  {'crimeTypeID': 619, 'type': 'BATTERY-DOMESTIC'},
#  {'crimeTypeID': 620, 'type': 'SEX OFFENDER-FAIL TO REGISTER'},
#  {'crimeTypeID': 621, 'type': 'THROWING DANGEROUS'},
#  {'crimeTypeID': 622, 'type': 'FORCIBLE SEX OFFENSE'},
#  {'crimeTypeID': 623, 'type': 'BURNING PROHIBITED'},
#  {'crimeTypeID': 624, 'type': 'ASSIST DOMESTIC'},
#  {'crimeTypeID': 625, 'type': 'LIQUOR - PUBLIC POSSESSION'},
#  {'crimeTypeID': 626, 'type': 'FELONY - ARREST'},
#  {'crimeTypeID': 627, 'type': 'SPEEDING (RADAR)'},
#  {'crimeTypeID': 628, 'type': 'CRIMINAL DEFACEMENT OF PROPERTY'},
#  {'crimeTypeID': 629, 'type': 'ASSIST K9'},
#  {'crimeTypeID': 630, 'type': 'ASSIST/ACCIDENT'},
#  {'crimeTypeID': 631, 'type': 'ASSIST W/K-9'},
#  {'crimeTypeID': 632, 'type': 'LIQUOR-OPEN CONTAINER/PUBLIC PROP.'},
#  {'crimeTypeID': 633, 'type': 'ZERO TOLERANCE'},
#  {'crimeTypeID': 634, 'type': 'NON-FORCIBLE SEX OFFENSE'},
#  {'crimeTypeID': 635, 'type': 'HINDERING POLICE OFFCR'},
#  {'crimeTypeID': 636, 'type': 'THEFT FROM MOTOR VEHICLE'},
#  {'crimeTypeID': 637, 'type': 'BREATH ALCOHOL OVER LIMIT'},
#  {'crimeTypeID': 638, 'type': 'CRIMINAL DAMAGE GOVT SUPPORT PROP'},
#  {'crimeTypeID': 639, 'type': 'ASSIST CCSO W/BMV'},
#  {'crimeTypeID': 640, 'type': 'CRIMINAL DAMAGE'},
#  {'crimeTypeID': 641, 'type': 'HIT AND RUN'},
#  {'crimeTypeID': 642, 'type': 'RUNAWAY - MINOR REQUIRE AUTH INTER'},
#  {'crimeTypeID': 643, 'type': 'RECOVERED PROPERTY ONLY'},
#  {'crimeTypeID': 644, 'type': 'NO DRIVERS LICENSE'},
#  {'crimeTypeID': 645, 'type': 'RAPE'},
#  {'crimeTypeID': 646, 'type': 'MISSING PERSON'},
#  {'crimeTypeID': 647, 'type': 'ASSIST/ARMED SUBJECT'},
#  {'crimeTypeID': 648, 'type': 'LEAVING THE SCENE OF AN ACCIDENT'},
#  {'crimeTypeID': 649, 'type': 'POSS OF CANNABIS'},
#  {'crimeTypeID': 650, 'type': 'UNLAWFUL POSS/USE WEAPON BY FELON'},
#  {'crimeTypeID': 651, 'type': 'IMPROPER USE OF SIGNAL'},
#  {'crimeTypeID': 652, 'type': 'LIQUOR-ILLEGAL POSS. BY MINOR'},
#  {'crimeTypeID': 653, 'type': 'IMPROPER LANE USAGE'},
#  {'crimeTypeID': 654, 'type': 'HARASSMENT'},
#  {'crimeTypeID': 655, 'type': 'MISSING PERSON ADULT/MALE'},
#  {'crimeTypeID': 656, 'type': 'CURFEW VIOLATION'},
#  {'crimeTypeID': 657, 'type': 'OTHER MISC/CPD ORDINANCE'},
#  {'crimeTypeID': 658, 'type': 'DISORDERLY CONDUCT-ALL'},
#  {'crimeTypeID': 659, 'type': 'UNLAWFUL USE OF I.D.'},
#  {'crimeTypeID': 660, 'type': 'CANNABIS POSS 10 GM OR LESS -ORD'},
#  {'crimeTypeID': 661, 'type': 'TRESPASS NOTICE'},
#  {'crimeTypeID': 662, 'type': 'DISORDERLY CONDUCT-ALL OTHER'},
#  {'crimeTypeID': 663, 'type': 'ENDANG LIFE/HEALTH OF CHILD'},
#  {'crimeTypeID': 664, 'type': 'LIQUOR-PURCH/POSS/CONSUMP BY MINORS'},
#  {'crimeTypeID': 665, 'type': 'AGGRAVATED ASSAULT'},
#  {'crimeTypeID': 666, 'type': 'ASSIST CPD WITH BATTERY'},
#  {'crimeTypeID': 667, 'type': 'DRIVING UNDER INFLUENCE-DRUGS'},
#  {'crimeTypeID': 668, 'type': 'ASSIST COUNTY POLICE'},
#  {'crimeTypeID': 669, 'type': 'DUI - ALCOHOL'},
#  {'crimeTypeID': 670, 'type': 'TRESPASS/RESISTING ARREST'},
#  {'crimeTypeID': 671, 'type': 'ASSIST/K-9'},
#  {'crimeTypeID': 672, 'type': 'DECEPTIVE PRACTCIES'},
#  {'crimeTypeID': 673, 'type': 'LIQUOR'},
#  {'crimeTypeID': 674, 'type': 'CANNABIS-POSS 30 GM & UNDER'},
#  {'crimeTypeID': 675, 'type': 'DELIVERY CONTROLLED SUB'},
#  {'crimeTypeID': 676, 'type': 'CANINE SWEEP - IDOT'},
#  {'crimeTypeID': 677, 'type': 'ASSIST CPD/ROBBERY'},
#  {'crimeTypeID': 678, 'type': 'OTHER EQUIPMENT VIOLATIONS'},
#  {'crimeTypeID': 679, 'type': 'SRO - YAC REFERRAL'},
#  {'crimeTypeID': 680, 'type': 'THEFT-IDENTITY'},
#  {'crimeTypeID': 681, 'type': 'ASSIST UPD W/RETAIL THEFT'},
#  {'crimeTypeID': 682, 'type': 'ASSIST/ARMED SUBJ'},
#  {'crimeTypeID': 683, 'type': 'DOMESTIC'},
#  {'crimeTypeID': 684, 'type': 'CONTROLLED SUBSTANCE-POSS W/INTENT'},
#  {'crimeTypeID': 685, 'type': 'MIP'},
#  {'crimeTypeID': 686, 'type': 'STATUTORY RAPE'},
#  {'crimeTypeID': 687, 'type': 'DISPOSAL ON PUBLIC WAYS'},
#  {'crimeTypeID': 688, 'type': 'NOISE VIOLATION'},
#  {'crimeTypeID': 689, 'type': 'ASSIST CPD W/MEDICAL'},
#  {'crimeTypeID': 690, 'type': 'BRINGING CONTRABAND INTO PENAL INST'},
#  {'crimeTypeID': 691, 'type': 'ELECTRICAL FIRE'},
#  {'crimeTypeID': 692, 'type': 'INTIMIDATION'},
#  {'crimeTypeID': 693, 'type': 'PUBLIC INDECENCY'},
#  {'crimeTypeID': 694, 'type': 'LIQUOR-ILLEGAL CONSUMPTION BY'},
#  {'crimeTypeID': 695, 'type': 'POSS ALCOHOL/LIQ PUBLIC PROP/PARKIN'},
#  {'crimeTypeID': 696, 'type': 'SEARCH WARRANT'},
#  {'crimeTypeID': 697, 'type': 'BONFIRES PROHIBITED'},
#  {'crimeTypeID': 698, 'type': 'FALSE FIRE ALARM'},
#  {'crimeTypeID': 699, 'type': 'FIREWORKS'},
#  {'crimeTypeID': 700, 'type': 'LIQUOR-UNDERAGE; DISORDERLY CONDUCT'},
#  {'crimeTypeID': 701, 'type': 'K9 ASSIST CCSO'},
#  {'crimeTypeID': 702, 'type': 'DRUG EQUIPMENT-POSSESSION'},
#  {'crimeTypeID': 703, 'type': 'TERRORISM-MAKE FALSE TERROR'},
#  {'crimeTypeID': 704, 'type': 'THEFT OF MOTOR VEH PARTS & ACCESS'},
#  {'crimeTypeID': 705, 'type': 'VANDALISM-INSTITUTIONAL'},
#  {'crimeTypeID': 706, 'type': 'SUSPENDED LICENSE/WARRANT'},
#  {'crimeTypeID': 707, 'type': 'DISORDERLY'},
#  {'crimeTypeID': 708, 'type': 'ASSAULT'},
#  {'crimeTypeID': 709, 'type': 'ASSIST/ACCIDENT UPD'},
#  {'crimeTypeID': 710, 'type': 'ASSIST UPD'},
#  {'crimeTypeID': 711, 'type': 'LIQUOR - ADULT RESPONSIBILITY/UNDERAGE'},
#  {'crimeTypeID': 712, 'type': 'BICYCLE VIOLATION'},
#  {'crimeTypeID': 713, 'type': 'TRESPASS'},
#  {'crimeTypeID': 714, 'type': 'HARBOURING A RUNAWAY'},
#  {'crimeTypeID': 715, 'type': 'UNLAWFUL TRESPASS'},
#  {'crimeTypeID': 716, 'type': 'DECEPT PRACT'},
#  {'crimeTypeID': 717, 'type': 'HARASS BY TX'},
#  {'crimeTypeID': 718, 'type': 'CRISIS INTERVEN. - ALCOHOL'},
#  {'crimeTypeID': 719, 'type': 'VIOLATION OF ORDER OF PROTECTION'},
#  {'crimeTypeID': 720, 'type': 'UNLAWFUL RESTRAINT'},
#  {'crimeTypeID': 721, 'type': 'SIMPLE ASSAULT'},
#  {'crimeTypeID': 722, 'type': 'ASSIST ROBBERY'},
#  {'crimeTypeID': 723, 'type': 'RESIST/OBS CORRECT/POLICE/FIRE'},
#  {'crimeTypeID': 724, 'type': 'BATTERY -CITY'},
#  {'crimeTypeID': 725, 'type': 'SEXUAL ASSAULT-AGG CRIMINAL'},
#  {'crimeTypeID': 726, 'type': 'CANNABIS POSS 30 G AND UNDER - OLD'},
#  {'crimeTypeID': 727, 'type': 'SUICIDAL SUBJECT'},
#  {'crimeTypeID': 728, 'type': 'DEFACING IDENTI.MARKS OF FIREARMS'},
#  {'crimeTypeID': 729, 'type': 'DRUG'},
#  {'crimeTypeID': 730, 'type': 'BURGLARY FROM MOTOR'},
#  {'crimeTypeID': 731, 'type': 'DOMESTIC BATTERY'},
#  {'crimeTypeID': 732, 'type': 'ARSON'},
#  {'crimeTypeID': 733, 'type': 'ALLOWING A NUISANCE PARTY'},
#  {'crimeTypeID': 734, 'type': 'ASSIST/ROBBERY DETAIL'},
#  {'crimeTypeID': 735, 'type': 'VOOP'},
#  {'crimeTypeID': 736, 'type': 'SAFEKEEPING'},
#  {'crimeTypeID': 737, 'type': 'LIQUOR-UNDERAGE; FIGHT'},
#  {'crimeTypeID': 738, 'type': 'THEFT BY LESSEE'},
#  {'crimeTypeID': 739, 'type': 'TERRORIST THREATS'},
#  {'crimeTypeID': 740, 'type': 'DISOBEY STOP'},
#  {'crimeTypeID': 741, 'type': 'DEL/MANUF CANNABIS UNDER 10 G -MISD'},
#  {'crimeTypeID': 742, 'type': 'POSS OF DRUG PARAPHENALIA'},
#  {'crimeTypeID': 743, 'type': 'TRANSIENT MERCHANT/LICENSE REQUIRED'},
#  {'crimeTypeID': 744, 'type': 'ASSIST ATT BURG F/MV'},
#  {'crimeTypeID': 745, 'type': 'HYPODERMIC NEEDLE/SYRINGE-POSS/SALE'},
#  {'crimeTypeID': 746, 'type': 'THEFT/DECCEPTION'},
#  {'crimeTypeID': 747, 'type': 'WARRANT-OUT OF STATE'},
#  {'crimeTypeID': 748, 'type': 'ASSIST W/K9 SWEEP'},
#  {'crimeTypeID': 749, 'type': 'LIQUOR-PURCH/POSS/CONSUMP BY'},
#  {'crimeTypeID': 750, 'type': 'PUBLIC POSSESSION OF ALCOHOL'},
#  {'crimeTypeID': 751, 'type': 'FIGHT'},
#  {'crimeTypeID': 752, 'type': 'TELEPHONE THREATS'},
#  {'crimeTypeID': 753, 'type': 'THEFT OF MOTOR VEH PARTS &'},
#  {'crimeTypeID': 754, 'type': 'ASSIST UPD WITH K-9'},
#  {'crimeTypeID': 755, 'type': 'ASSIST OTHER GOVT AGENCY/EOD'},
#  {'crimeTypeID': 756, 'type': 'FALSE ID-POSS (MISC)'},
#  {'crimeTypeID': 757, 'type': 'RESISTING ARREST'},
#  {'crimeTypeID': 758, 'type': 'DISORDERLY CONDUCT'},
#  {'crimeTypeID': 759, 'type': 'THROW DANG MATERIAL'},
#  {'crimeTypeID': 760, 'type': 'ASSIST UPD/SHOOTING'},
#  {'crimeTypeID': 761, 'type': 'THEFT-CITY'},
#  {'crimeTypeID': 762, 'type': 'CRIMINAL DEFACEMENT OF'},
#  {'crimeTypeID': 763, 'type': 'ASSIST/CHECK WELFARE'},
#  {'crimeTypeID': 764, 'type': 'THEFT OVER $500'},
#  {'crimeTypeID': 765, 'type': 'CANNABIS POSS OVER 30 G - OLD'},
#  {'crimeTypeID': 766, 'type': 'LARCENY'},
#  {'crimeTypeID': 767, 'type': 'OBSTRUCTING IDENTIFICATION'},
#  {'crimeTypeID': 768, 'type': 'BURGLARY MOTOR VEH PARTS & ACCESS'},
#  {'crimeTypeID': 769, 'type': 'DOMESTIC BATTERY/UNLAWFUL'},
#  {'crimeTypeID': 770, 'type': 'CANNABIS-POSSESSION OVER 30GM'},
#  {'crimeTypeID': 771, 'type': 'RESISTING/OBSTRUCTING'},
#  {'crimeTypeID': 772, 'type': 'UPD ACCIDENT (FATAL)'},
#  {'crimeTypeID': 773, 'type': 'DRIVING UNDER THE INFL-ALCOHOL'},
#  {'crimeTypeID': 774, 'type': 'SEX OFFENDER REGISTRATION'},
#  {'crimeTypeID': 775, 'type': 'HAZING - FRAT/SORORITY'},
#  {'crimeTypeID': 776, 'type': 'ASSIST CCSO TRAF STOP'},
#  {'crimeTypeID': 777, 'type': 'THEFT'},
#  {'crimeTypeID': 778, 'type': 'ASSIST/CPD WITH ACCIDENT'},
#  {'crimeTypeID': 779, 'type': 'METRO'},
#  {'crimeTypeID': 780, 'type': 'DOMESTIC DISPUTE - VERBAL ONLY'},
#  {'crimeTypeID': 781, 'type': 'ASSIST UPD ON ROBBERY'},
#  {'crimeTypeID': 782, 'type': 'UNLAWFUL POSSESSION OF ID'},
#  {'crimeTypeID': 783, 'type': 'ASSIST/STABBING'},
#  {'crimeTypeID': 784, 'type': 'DECP PRACTICE'},
#  {'crimeTypeID': 785, 'type': 'DRUGS; COUNTERFEIT MONEY'},
#  {'crimeTypeID': 786, 'type': 'DEL/MANUF CANNABIS UNDER 30 G -MISD'},
#  {'crimeTypeID': 787, 'type': 'LIQUOR-PUBLIC PROP'},
#  {'crimeTypeID': 788, 'type': 'TRAFFIC STOP'},
#  {'crimeTypeID': 789, 'type': 'POSSESSION OF STOLEN FIREARM'},
#  {'crimeTypeID': 790, 'type': 'WARRANT-IN STATE'},
#  {'crimeTypeID': 791, 'type': 'FALSE POLICE REPORT'},
#  {'crimeTypeID': 792, 'type': 'LIQOUR'},
#  {'crimeTypeID': 793, 'type': 'TRESPASS TO LAND/REAL PROPERTY'},
#  {'crimeTypeID': 794, 'type': 'ASSIST CPD W/BANK ROBBERY'},
#  {'crimeTypeID': 795, 'type': 'ASSIST W/SEARCH WARRANT'},
#  {'crimeTypeID': 796, 'type': 'HARASSMENT BY TX'},
#  {'crimeTypeID': 797, 'type': 'NOISE PROHIBITED'},
#  {'crimeTypeID': 798, 'type': 'ACCIDENT INVOLVING PEDESTRIAN'},
#  {'crimeTypeID': 799, 'type': 'RESIST/OBSTRUCT/DISARM OFFICER'},
#  {'crimeTypeID': 800, 'type': 'CANNABIS POSS MORE THAN 10 LESS'},
#  {'crimeTypeID': 801, 'type': 'DEC PRACTICE'},
#  {'crimeTypeID': 802, 'type': 'DRIVING UNDER THE INFL-'},
#  {'crimeTypeID': 803, 'type': 'ASSIST OTHER POLICE DEPT'},
#  {'crimeTypeID': 804, 'type': 'STALKING BY ELECTRONIC COMMUNICATIO'},
#  {'crimeTypeID': 805, 'type': 'CONTROLLED SUBSTANCE-MANUF-'},
#  {'crimeTypeID': 806, 'type': 'HARRASMENT BY ELECTRONIC'},
#  {'crimeTypeID': 807, 'type': 'HOME INVASION'},
#  {'crimeTypeID': 808, 'type': 'LEAVING SCENE PROPERTY DAMAGE'},
#  {'crimeTypeID': 809, 'type': 'OFFICIAL MISCONDUCT'},
#  {'crimeTypeID': 810, 'type': 'ASSIST/BURGLARY'},
#  {'crimeTypeID': 811, 'type': 'ACCIDENT INVOLVING OTHER CITY PROP'},
#  {'crimeTypeID': 812, 'type': 'DIS CONDUCT'},
#  {'crimeTypeID': 813, 'type': 'ASST CPD/ARMED SUBJECT'},
#  {'crimeTypeID': 814, 'type': 'IDENTITY THEFT'},
#  {'crimeTypeID': 815, 'type': 'ASSIST OTHER PD'},
#  {'crimeTypeID': 816, 'type': 'SIMPLE BATTERY'},
#  {'crimeTypeID': 817, 'type': 'CANNABIS POSS OVER 10 - 100 G -MISD'},
#  {'crimeTypeID': 818, 'type': 'TRAFFIC CITATION/VOP'},
#  {'crimeTypeID': 819, 'type': 'WARRANT ARREST/TRAFFIC CITATIONS'},
#  {'crimeTypeID': 820, 'type': 'THEFT-RETAIL-CITY'},
#  {'crimeTypeID': 821, 'type': 'ASSIST K-9'},
#  {'crimeTypeID': 822, 'type': 'SEXUAL HARASSMENT'},
#  {'crimeTypeID': 823, 'type': 'ASSIST UPD W/DISORDERLY'},
#  {'crimeTypeID': 824, 'type': 'ENDANG CHILD'},
#  {'crimeTypeID': 825, 'type': 'AGGRAVATGED ASSAULT'},
#  {'crimeTypeID': 826, 'type': 'STALKING-AGGRAVATED'},
#  {'crimeTypeID': 827, 'type': 'DRUGS'},
#  {'crimeTypeID': 828, 'type': 'ASSIST ISP W/SEARCH'},
#  {'crimeTypeID': 829, 'type': 'SEARCH WARRANT SERVICE'},
#  {'crimeTypeID': 830, 'type': 'ASSIST UPD W/ROBBERY'},
#  {'crimeTypeID': 831, 'type': 'LIQUOR-UNDERAGE/PUBLIC POSSESSION'},
#  {'crimeTypeID': 832, 'type': 'STOLEN PROP RECOVERED'},
#  {'crimeTypeID': 833, 'type': 'CANNABIS-DELIVERY 30GM &'},
#  {'crimeTypeID': 834, 'type': 'EXTORTION'},
#  {'crimeTypeID': 835, 'type': 'UNLAWFUL POSS/USE WEAPON BY'},
#  {'crimeTypeID': 836, 'type': 'BATTERY-DOMESTIC & LARCENY'},
#  {'crimeTypeID': 837, 'type': 'ALCOHOL/LIQUOR CONSUMPTION EMPLOYEE'},
#  {'crimeTypeID': 838, 'type': 'CARRYING OUT OF PREMISE'},
#  {'crimeTypeID': 839, 'type': 'UNLAWFUL RESTRAINT-AGGRAVATED'},
#  {'crimeTypeID': 840, 'type': 'ASSIST CPD W/TRAFFIC STOP'},
#  {'crimeTypeID': 841, 'type': 'ASSIST K9 SEARCH'},
#  {'crimeTypeID': 842, 'type': 'IMPOUNDED VEHICLE'},
#  {'crimeTypeID': 843, 'type': 'POSS DRUG PARAPHERNALIA'},
#  {'crimeTypeID': 844, 'type': 'SEXUAL ABUSE-CRIMINAL'},
#  {'crimeTypeID': 845, 'type': 'CANNABIS-POSSESSION OVER'},
#  {'crimeTypeID': 846, 'type': 'ASSIST/BUILDING CHECK'},
#  {'crimeTypeID': 847, 'type': 'ROBBERY-AGGRAVATED'},
#  {'crimeTypeID': 848, 'type': 'HAZING'},
#  {'crimeTypeID': 849, 'type': 'ASSIST UPD W/K9 SWEEP'},
#  {'crimeTypeID': 850, 'type': 'OTHER CRIMINAL OFFENSES'},
#  {'crimeTypeID': 851, 'type': 'THROWING DANGEROUS MATERIALS'},
#  {'crimeTypeID': 852, 'type': 'RECKLESS CONDUCT'},
#  {'crimeTypeID': 853, 'type': 'CRISIS INTERVEN. - OTHER'},
#  {'crimeTypeID': 854, 'type': 'ASSIST/NO TRESPASS'}]

# %%
#Flush the list of dictionary to CSV file
crimeTypeColumns = ['crimeTypeID','type']

crimeTypeCSVName = "CrimeType.csv"

try:
    with open(csvFilePath+"\\"+crimeTypeCSVName, 'w', newline="") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=crimeTypeColumns)
        writer.writeheader()
        for data in crimeTypeListOfDicts:
            writer.writerow(data)
except IOError:
    print("I/O error")

# %% [markdown]
# # Create Crime CSV

# %% [markdown]
# ### Add incident column

# %%
crimeDF = csvData[["Incident"]]
crimeDF
# Out:
#        Incident
# 0     II1300002
# 1     II1300001
# 2     II1300003
# 3     II1300004
# 4     II1300006
# ...         ...
# 7609  CC1909074
# 7610  IF1901488
# 7611  II1901441
# 7612  II1901442
# 7613  UU1905819
#
# [7443 rows x 1 columns]

# %% [markdown]
# ### Add reportedAt column

# %%
def convertCSVDateToSQLDateFormat(str):
    list = str.split("/")
    res = "20" + list[2] + "-" + list[1] + "-" + list[0]
    return res
convertCSVDateToSQLDateFormat("1/1/13")
# Out:
# '2013-1-1'

# %%
# Add reportedAt column
reportedAt = []
for date in csvData["Date reported"]:
    reportedAt.append(convertCSVDateToSQLDateFormat(date))

index = 0
for time in csvData["Time reported"]:
    timeSplit = time.split(" ")
    if(len(timeSplit)==3) and (timeSplit[1] == "p."): #am or pm
        timeSplit[0] = str((int(timeSplit[0].split(":",1)[0])+12)%24) + ":" + timeSplit[0].split(":",1)[1]
    if(len(timeSplit)==3) and (timeSplit[1] == "a."): #am or pm
        timeSplit[0] = str((int(timeSplit[0].split(":",1)[0])+0)%12) + ":" + timeSplit[0].split(":",1)[1]
    reportedAt[index] += " " + timeSplit[0]
    index += 1
    
reportedAtDF = pd.DataFrame(reportedAt, columns = ['reportedAt'])
reportedAtDF.head(20)
# Out:
#             reportedAt
# 0     2013-1-1 1:39:00
# 1     2013-1-1 0:44:00
# 2     2013-1-1 6:25:00
# 3     2013-1-1 9:22:00
# 4    2013-3-1 11:00:00
# 5     2013-3-1 0:43:00
# 6    2013-3-1 14:47:00
# 7    2013-3-1 14:46:00
# 8    2013-3-1 14:44:00
# 9    2013-3-1 14:39:00
# 10   2013-3-1 14:37:00
# 11    2013-5-1 0:00:00
# 12   2013-6-1 16:49:00
# 13   2013-6-1 22:47:00
# 14    2013-8-1 0:00:00
# 15    2013-9-1 2:21:00
# 16   2013-9-1 15:26:00
# 17   2013-10-1 2:32:00
# 18  2013-10-1 11:07:00
# 19   2013-11-1 2:41:00

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,reportedAtDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt
# 0     II1300002   2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00
# 4     II1300006  2013-3-1 11:00:00
# ...         ...                ...
# 7609  CC1909074                NaN
# 7610  IF1901488                NaN
# 7611  II1901441                NaN
# 7612  II1901442                NaN
# 7613  UU1905819                NaN
#
# [7610 rows x 2 columns]

# %% [markdown]
# ### Add occuredAt column

# %%
# Add occuredAt column
# print(csvData.isnull())

occurredAt = []
for date in csvData["Date occurred"]:
#     print(date)
#     print(type(date))
    occurredAt.append(convertCSVDateToSQLDateFormat(date))

index = 0
for time in csvData["Time occurred"]:
    timeSplit = time.split(" ")
    if(len(timeSplit)==3) and (timeSplit[1] == "p."): #am or pm
        timeSplit[0] = str((int(timeSplit[0].split(":",1)[0])+12)%24) + ":" + timeSplit[0].split(":",1)[1]
    if(len(timeSplit)==3) and (timeSplit[1] == "a."): #am or pm
        timeSplit[0] = str((int(timeSplit[0].split(":",1)[0])+0)%12) + ":" + timeSplit[0].split(":",1)[1]
    occurredAt[index] += " " + timeSplit[0]
    index += 1
    
occurredAtDF = pd.DataFrame(occurredAt, columns = ['occurredAt'])
occurredAtDF.head(20)
# Out:
#              occurredAt
# 0      2013-1-1 1:39:00
# 1      2013-1-1 0:44:00
# 2      2013-1-1 6:25:00
# 3      2013-1-1 2:00:00
# 4    2012-20-12 8:00:00
# 5    2012-28-11 0:00:00
# 6   2012-22-12 15:30:00
# 7    2012-18-12 3:10:00
# 8    2002-19-12 3:10:00
# 9   2012-20-12 22:35:00
# 10   2012-21-12 3:00:00
# 11  2012-23-12 18:25:00
# 12    2013-6-1 16:49:00
# 13    2013-6-1 22:47:00
# 14    2013-4-1 16:45:00
# 15     2013-9-1 2:21:00
# 16    2013-9-1 15:26:00
# 17    2013-10-1 2:32:00
# 18    2013-10-1 9:22:00
# 19    2013-11-1 2:41:00

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,occurredAtDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00    2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-3-1 11:00:00  2012-20-12 8:00:00
# ...         ...                ...                 ...
# 7609  CC1909074                NaN                 NaN
# 7610  IF1901488                NaN                 NaN
# 7611  II1901441                NaN                 NaN
# 7612  II1901442                NaN                 NaN
# 7613  UU1905819                NaN                 NaN
#
# [7610 rows x 3 columns]

# %% [markdown]
# ### Add Disposition column

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,csvData["Disposition"]], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00    2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-3-1 11:00:00  2012-20-12 8:00:00
# ...         ...                ...                 ...
# 7609  CC1909074                NaN                 NaN
# 7610  IF1901488                NaN                 NaN
# 7611  II1901441                NaN                 NaN
# 7612  II1901442                NaN                 NaN
# 7613  UU1905819                NaN                 NaN
#
#                    Disposition
# 0                       ARREST
# 1                       ARREST
# 2                       ARREST
# 3                       ARREST
# 4                 ADMIN. CLOSE
# ...                        ...
# 7609  REPORTED TO OTHER AGENCY
# 7610              ADMIN CLOSED
# 7611              ADMIN. CLOSE
# 7612              ADMIN. CLOSE
# 7613  REPORTED TO OTHER AGENCY
#
# [7610 rows x 4 columns]

# %% [markdown]
# ### Add crimeTypeID column

# %%
crimeTypeID = []
for row in csvData["Crime Description"]:
    crimeTypeStartIndex = 300
    for type in crimeTypeList:
        if(type==row.upper().strip()):
            crimeTypeID.append(crimeTypeStartIndex)
            break;
        crimeTypeStartIndex += 1

crimeTypeIDDF = pd.DataFrame(crimeTypeID, columns = ['crimeTypeID'])
crimeTypeIDDF
# Out:
#       crimeTypeID
# 0             802
# 1             572
# 2             802
# 3             575
# 4             617
# ...           ...
# 7438          683
# 7439          557
# 7440          803
# 7441          638
# 7442          394
#
# [7443 rows x 1 columns]

# %%
#Combine it with crimeDF
crimeDF = pd.concat([crimeDF,crimeTypeIDDF], axis=1)
crimeDF
# Out:
#        Incident         reportedAt          occurredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00    2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-3-1 11:00:00  2012-20-12 8:00:00
# ...         ...                ...                 ...
# 7609  CC1909074                NaN                 NaN
# 7610  IF1901488                NaN                 NaN
# 7611  II1901441                NaN                 NaN
# 7612  II1901442                NaN                 NaN
# 7613  UU1905819                NaN                 NaN
#
#                    Disposition  crimeTypeID
# 0                       ARREST        802.0
# 1                       ARREST        572.0
# 2                       ARREST        802.0
# 3                       ARREST        575.0
# 4                 ADMIN. CLOSE        617.0
# ...                        ...          ...
# 7609  REPORTED TO OTHER AGENCY          NaN
# 7610              ADMIN CLOSED          NaN
# 7611              ADMIN. CLOSE          NaN
# 7612              ADMIN. CLOSE          NaN
# 7613  REPORTED TO OTHER AGENCY          NaN
#
# [7610 rows x 5 columns]

# %%
#Rename columns
crimeDF.columns = ["incidentID", "reportedAt", "occuredAt", "disposition", "crimeTypeID"]
crimeDF
# Out:
#      incidentID         reportedAt           occuredAt  \
# 0     II1300002   2013-1-1 1:39:00    2013-1-1 1:39:00
# 1     II1300001   2013-1-1 0:44:00    2013-1-1 0:44:00
# 2     II1300003   2013-1-1 6:25:00    2013-1-1 6:25:00
# 3     II1300004   2013-1-1 9:22:00    2013-1-1 2:00:00
# 4     II1300006  2013-3-1 11:00:00  2012-20-12 8:00:00
# ...         ...                ...                 ...
# 7609  CC1909074                NaN                 NaN
# 7610  IF1901488                NaN                 NaN
# 7611  II1901441                NaN                 NaN
# 7612  II1901442                NaN                 NaN
# 7613  UU1905819                NaN                 NaN
#
#                    disposition  crimeTypeID
# 0                       ARREST        802.0
# 1                       ARREST        572.0
# 2                       ARREST        802.0
# 3                       ARREST        575.0
# 4                 ADMIN. CLOSE        617.0
# ...                        ...          ...
# 7609  REPORTED TO OTHER AGENCY          NaN
# 7610              ADMIN CLOSED          NaN
# 7611              ADMIN. CLOSE          NaN
# 7612              ADMIN. CLOSE          NaN
# 7613  REPORTED TO OTHER AGENCY          NaN
#
# [7610 rows x 5 columns]

# %%
#Flush the dataframe to CSV file

crimeCSVName = "Crime.csv"
    
crimeDF.to_csv(csvFilePath+"\\"+crimeCSVName, encoding='utf-8', index=False)

# %% [markdown]
# # Create happensAt CSV

# %%
csvData
# Out:
#        Incident Date reported   Time reported Date occurred   Time occurred  \
# 0     II1300002        1/1/13   1:39:00 a. m.        1/1/13   1:39:00 a. m.
# 1     II1300001        1/1/13  12:44:00 a. m.        1/1/13  12:44:00 a. m.
# 2     II1300003        1/1/13   6:25:00 a. m.        1/1/13   6:25:00 a. m.
# 3     II1300004        1/1/13   9:22:00 a. m.        1/1/13   2:00:00 a. m.
# 4     II1300006        1/3/13  11:00:00 a. m.      12/20/12   8:00:00 a. m.
# ...         ...           ...             ...           ...             ...
# 7609  CC1909074      11/14/19            7:00      11/14/19            2:37
# 7610  IF1901488      11/14/19           16:56      11/14/19           16:56
# 7611  II1901441      11/14/19           16:52      11/14/19           16:00
# 7612  II1901442      11/14/19           20:10      11/14/19           20:05
# 7613  UU1905819      11/14/19            7:00      11/13/19           19:41
#
#                General Location                  Crime Description  \
# 0      500 blk of JOHN STREET E            DRIVING UNDER THE INFL-
# 1            600 blk of GREEN E             POSSESSION OF CANNABIS
# 2                      CIRCLE K            DRIVING UNDER THE INFL-
# 3     COMPUTER APPLICATION BLDG               CRIMINAL DAMAGE GOVT
# 4                  KIRK / GERTY                 THEFT FROM COIN-OP
# ...                         ...                                ...
# 7609    808 S OAK ST, CHAMPAIGN                           DOMESTIC
# 7610  IUB ADMINISTRATIVE SUITES                            THREATS
# 7611        500 blk of ELM ST S           ASSIST OTHER POLICE DEPT
# 7612      ARCHITECTURE BUILDING  CRIMINAL DAMAGE GOVT SUPPORT PROP
# 7613   102 N GREGORY ST, URBANA                           BURGLARY
#
#                    Disposition  BlockId
# 0                       ARREST        0
# 1                       ARREST       14
# 2                       ARREST        0
# 3                       ARREST        9
# 4                 ADMIN. CLOSE        0
# ...                        ...      ...
# 7609  REPORTED TO OTHER AGENCY       25
# 7610              ADMIN CLOSED       50
# 7611              ADMIN. CLOSE        0
# 7612              ADMIN. CLOSE        0
# 7613  REPORTED TO OTHER AGENCY       36
#
# [7443 rows x 9 columns]

# %%
happensAtDF = csvData[["Incident", "BlockId", "General Location"]]

# %%
#Rename columns
happensAtDF.columns = ["incidentID", "blockID", "genLocation"]
happensAtDF
# Out:
#      incidentID  blockID                genLocation
# 0     II1300002        0   500 blk of JOHN STREET E
# 1     II1300001       14         600 blk of GREEN E
# 2     II1300003        0                   CIRCLE K
# 3     II1300004        9  COMPUTER APPLICATION BLDG
# 4     II1300006        0               KIRK / GERTY
# ...         ...      ...                        ...
# 7609  CC1909074       25    808 S OAK ST, CHAMPAIGN
# 7610  IF1901488       50  IUB ADMINISTRATIVE SUITES
# 7611  II1901441        0        500 blk of ELM ST S
# 7612  II1901442        0      ARCHITECTURE BUILDING
# 7613  UU1905819       36   102 N GREGORY ST, URBANA
#
# [7443 rows x 3 columns]

# %%
#Flush the dataframe to CSV file

happensAtCSVName = "happensAt.csv"
    
happensAtDF.to_csv(csvFilePath+"\\"+happensAtCSVName, encoding='utf-8', index=False)
